# %%
#  !pip install -U albumentations

# %%
import albumentations as A        # For data augmentation
import cv2                        # For loading images
import matplotlib.pyplot as plt   # For plotting images
import numpy as np

# %%
from PIL import Image

# %%
# %cd archive
# Out:
# C:\Users\Rohith\mern\archive

# %%
# %cd imgs
# Out:
# C:\Users\Rohith\mern\imgs

# %%
# %cd ..
# Out:
# C:\Users\Rohith\mern

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Rohith\\mern'

# %%
for i in os.listdir():
    print(i)
# Out:
# abomasnow.png
# abra.png
# absol.png
# accelgor.png
# aegislash-blade.png
# aerodactyl.png
# aggron.png
# aipom.png
# alakazam.png
# alomomola.png
# altaria.png
# amaura.png
# ambipom.png
# amoonguss.png
# ampharos.png
# anorith.png
# araquanid.jpg
# arbok.png
# arcanine.png
# arceus.png
# archen.png
# archeops.png
# ariados.png
# armaldo.png
# aromatisse.png
# aron.png
# articuno.png
# audino.png
# aurorus.png
# avalugg.png
# axew.png
# azelf.png
# azumarill.png
# azurill.png
# bagon.png
# baltoy.png
# banette.png
# barbaracle.png
# barboach.png
# basculin-red-striped.png
# bastiodon.png
# bayleef.png
# beartic.png
# beautifly.png
# beedrill.png
# beheeyem.png
# beldum.png
# bellossom.png
# bellsprout.png
# bergmite.png
# bewear.jpg
# bibarel.png
# bidoof.png
# binacle.png
# bisharp.png
# blacephalon.jpg
# blastoise.png
# blaziken.png
# blissey.png
# blitzle.png
# boldore.png
# bonsly.png
# bouffalant.png
# bounsweet.jpg
# braixen.png
# braviary.png
# breloom.png
# brionne.jpg
# bronzong.png
# bronzor.png
# bruxish.jpg
# budew.png
# buizel.png
# bulbasaur.png
# buneary.png
# bunnelby.png
# burmy.png
# butterfree.png
# buzzwole.jpg
# cacnea.png
# cacturne.png
# camerupt.png
# carbink.png
# carnivine.png
# carracosta.png
# carvanha.png
# cascoon.png
# castform.png
# caterpie.png
# celebi.png
# celesteela.jpg
# chandelure.png
# chansey.png
# charizard.png
# charjabug.jpg
# charmander.png
# charmeleon.png
# chatot.png
# cherrim.png
# cherubi.png
# chesnaught.png
# chespin.png
# chikorita.png
# chimchar.png
# chimecho.png
# chinchou.png
# chingling.png
# cinccino.png
# clamperl.png
# clauncher.png
# clawitzer.png
# claydol.png
# clefable.png
# clefairy.png
# cleffa.png
# cloyster.png
# cobalion.png
# cofagrigus.png
# combee.png
# combusken.png
# comfey.jpg
# conkeldurr.png
# corphish.png
# corsola.png
# cosmoem.jpg
# cosmog.jpg
# cottonee.png
# crabominable.jpg
# crabrawler.jpg
# cradily.png
# cranidos.png
# crawdaunt.png
# cresselia.png
# croagunk.png
# crobat.png
# croconaw.png
# crustle.png
# cryogonal.png
# cubchoo.png
# cubone.png
# cutiefly.jpg
# cyndaquil.png
# darkrai.png
# darmanitan-standard.png
# dartrix.jpg
# darumaka.png
# decidueye.jpg
# dedenne.png
# deerling.png
# deino.png
# delcatty.png
# delibird.png
# delphox.png
# deoxys-normal.png
# dewgong.png
# dewott.png
# dewpider.jpg
# dhelmise.jpg
# dialga.png
# diancie.png
# diggersby.png
# diglett.png
# ditto.png
# dodrio.png
# doduo.png
# donphan.png
# doublade.png
# dragalge.png
# dragonair.png
# dragonite.png
# drampa.jpg
# drapion.png
# dratini.png
# drifblim.png
# drifloon.png
# drilbur.png
# drowzee.png
# druddigon.png
# ducklett.png
# dugtrio.png
# dunsparce.png
# duosion.png
# durant.png
# dusclops.png
# dusknoir.png
# duskull.png
# dustox.png
# dwebble.png
# eelektrik.png
# eelektross.png
# eevee.png
# ekans.png
# electabuzz.png
# electivire.png
# electrike.png
# electrode.png
# elekid.png
# elgyem.png
# emboar.png
# emolga.png
# empoleon.png
# entei.png
# escavalier.png
# espeon.png
# espurr.png
# excadrill.png
# exeggcute.png
# exeggutor.png
# exploud.png
# farfetchd.png
# fearow.png
# feebas.png
# fennekin.png
# feraligatr.png
# ferroseed.png
# ferrothorn.png
# finneon.png
# flaaffy.png
# flabebe.png
# flareon.png
# fletchinder.png
# fletchling.png
# floatzel.png
# floette.png
# florges.png
# flygon.png
# fomantis.jpg
# foongus.png
# forretress.png
# fraxure.png
# frillish.png
# froakie.png
# frogadier.png
# froslass.png
# furfrou.png
# furret.png
# gabite.png
# gallade.png
# galvantula.png
# garbodor.png
# garchomp.png
# gardevoir.png
# gastly.png
# gastrodon.png
# genesect.png
# gengar.png
# geodude.png
# gible.png
# gigalith.png
# girafarig.png
# giratina-altered.png
# glaceon.png
# glalie.png
# glameow.png
# gligar.png
# gliscor.png
# gloom.png
# gogoat.png
# golbat.png
# goldeen.png
# golduck.png
# golem.png
# golett.png
# golisopod.jpg
# golurk.png
# goodra.png
# goomy.png
# gorebyss.png
# gothita.png
# gothitelle.png
# gothorita.png
# gourgeist-average.png
# granbull.png
# graveler.png
# greninja.png
# grimer.png
# grotle.png
# groudon.png
# grovyle.png
# growlithe.png
# grubbin.jpg
# grumpig.png
# gulpin.png
# gumshoos.jpg
# gurdurr.png
# guzzlord.jpg
# gyarados.png
# hakamo-o.jpg
# happiny.png
# hariyama.png
# haunter.png
# hawlucha.png
# haxorus.png
# heatmor.png
# heatran.png
# heliolisk.png
# helioptile.png
# heracross.png
# herdier.png
# hippopotas.png
# hippowdon.png
# hitmonchan.png
# hitmonlee.png
# hitmontop.png
# ho-oh.png
# honchkrow.png
# honedge.png
# hoopa-confined.png
# hoothoot.png
# hoppip.png
# horsea.png
# houndoom.png
# houndour.png
# huntail.png
# hydreigon.png
# hypno.png
# igglybuff.png
# illumise.png
# incineroar.jpg
# infernape.png
# inkay.png
# ivysaur.png
# jangmo-o.jpg
# jellicent.png
# jigglypuff.png
# jirachi.png
# jolteon.png
# joltik.png
# jumpluff.png
# jynx.png
# kabuto.png
# kabutops.png
# kadabra.png
# kakuna.png
# kangaskhan.png
# karrablast.png
# kartana.jpg
# kecleon.png
# keldeo-ordinary.png
# kingdra.png
# kingler.png
# kirlia.png
# klang.png
# klefki.png
# klink.png
# klinklang.png
# koffing.png
# komala.jpg
# kommo-o.jpg
# krabby.png
# kricketot.png
# kricketune.png
# krokorok.png
# krookodile.png
# kyogre.png
# kyurem.png
# lairon.png
# lampent.png
# landorus-incarnate.png
# lanturn.png
# lapras.png
# larvesta.png
# larvitar.png
# latias.png
# latios.png
# leafeon.png
# leavanny.png
# ledian.png
# ledyba.png
# lickilicky.png
# lickitung.png
# liepard.png
# lileep.png
# lilligant.png
# lillipup.png
# linoone.png
# litleo.png
# litten.jpg
# litwick.png
# lombre.png
# lopunny.png
# lotad.png
# loudred.png
# lucario.png
# ludicolo.png
# lugia.png
# lumineon.png
# lunala.jpg
# lunatone.png
# lurantis.jpg
# luvdisc.png
# luxio.png
# luxray.png
# lycanroc-midday.jpg
# machamp.png
# machoke.png
# machop.png
# magby.png
# magcargo.png
# magearna.jpg
# magikarp.png
# magmar.png
# magmortar.png
# magnemite.png
# magneton.png
# magnezone.png
# makuhita.png
# malamar.png
# mamoswine.png
# manaphy.png
# mandibuzz.png
# manectric.png
# mankey.png
# mantine.png
# mantyke.png
# maractus.png
# mareanie.jpg
# mareep.png
# marill.png
# marowak.png
# marshadow.jpg
# marshtomp.png
# masquerain.png
# mawile.png
# medicham.png
# meditite.png
# meganium.png
# melmetal.jpg
# meloetta-aria.png
# meltan.jpg
# meowstic-male.png
# meowth.png
# mesprit.png
# metagross.png
# metang.png
# metapod.png
# mew.png
# mewtwo.png
# mienfoo.png
# mienshao.png
# mightyena.png
# milotic.png
# miltank.png
# mime-jr.png
# mimikyu.jpg
# minccino.png
# minior-meteor.jpg
# minun.png
# misdreavus.png
# mismagius.png
# moltres.png
# monferno.png
# morelull.jpg
# mothim.png
# mr-mime.png
# mudbray.jpg
# mudkip.png
# mudsdale.jpg
# muk.png
# munchlax.png
# munna.png
# murkrow.png
# musharna.png
# naganadel.jpg
# natu.png
# necrozma.jpg
# nidoking.png
# nidoqueen.png
# nidoran-f.png
# nidoran-m.png
# nidorina.png
# nidorino.png
# nihilego.jpg
# nincada.png
# ninetales.png
# ninjask.png
# noctowl.png
# noibat.png
# noivern.png
# nosepass.png
# numel.png
# nuzleaf.png
# octillery.png
# oddish.png
# omanyte.png
# omastar.png
# onix.png
# oranguru.jpg
# oricorio-baile.jpg
# oshawott.png
# pachirisu.png
# palkia.png
# palossand.jpg
# palpitoad.png
# pancham.png
# pangoro.png
# panpour.png
# pansage.png
# pansear.png
# paras.png
# parasect.png
# passimian.jpg
# patrat.png
# pawniard.png
# pelipper.png
# persian.png
# petilil.png
# phanpy.png
# phantump.png
# pheromosa.jpg
# phione.png
# pichu.png
# pidgeot.png
# pidgeotto.png
# pidgey.png
# pidove.png
# pignite.png
# pikachu.png
# pikipek.jpg
# piloswine.png
# pineco.png
# pinsir.png
# piplup.png
# plusle.png
# poipole.jpg
# politoed.png
# poliwag.png
# poliwhirl.png
# poliwrath.png
# ponyta.png
# poochyena.png
# popplio.jpg
# porygon-z.png
# porygon.png
# porygon2.png
# primarina.jpg
# primeape.png
# prinplup.png
# probopass.png
# psyduck.png
# pumpkaboo-average.png
# pupitar.png
# purrloin.png
# purugly.png
# pyroar.png
# pyukumuku.jpg
# quagsire.png
# quilava.png
# quilladin.png
# qwilfish.png
# raichu.png
# raikou.png
# ralts.png
# rampardos.png
# rapidash.png
# raticate.png
# rattata.png
# rayquaza.png
# regice.png
# regigigas.png
# regirock.png
# registeel.png
# relicanth.png
# remoraid.png
# reshiram.png
# reuniclus.png
# rhydon.png
# rhyhorn.png
# rhyperior.png
# ribombee.jpg
# riolu.png
# rockruff.jpg
# roggenrola.png
# roselia.png
# roserade.png
# rotom.png
# rowlet.jpg
# rufflet.png
# sableye.png
# salamence.png
# salandit.jpg
# salazzle.jpg
# samurott.png
# sandile.png
# sandshrew.png
# sandslash.png
# sandygast.jpg
# sawk.png
# sawsbuck.png
# scatterbug.png
# sceptile.png
# scizor.png
# scolipede.png
# scrafty.png
# scraggy.png
# scyther.png
# seadra.png
# seaking.png
# sealeo.png
# seedot.png
# seel.png
# seismitoad.png
# sentret.png
# serperior.png
# servine.png
# seviper.png
# sewaddle.png
# sharpedo.png
# shaymin-land.png
# shedinja.png
# shelgon.png
# shellder.png
# shellos.png
# shelmet.png
# shieldon.png
# shiftry.png
# shiinotic.jpg
# shinx.png
# shroomish.png
# shuckle.png
# shuppet.png
# sigilyph.png
# silcoon.png
# silvally.jpg
# simipour.png
# simisage.png
# simisear.png
# skarmory.png
# skiddo.png
# skiploom.png
# skitty.png
# skorupi.png
# skrelp.png
# skuntank.png
# slaking.png
# slakoth.png
# sliggoo.png
# slowbro.png
# slowking.png
# slowpoke.png
# slugma.png
# slurpuff.png
# smeargle.png
# smoochum.png
# sneasel.png
# snivy.png
# snorlax.png
# snorunt.png
# snover.png
# snubbull.png
# solgaleo.jpg
# solosis.png
# solrock.png
# spearow.png
# spewpa.png
# spheal.png
# spinarak.png
# spinda.png
# spiritomb.png
# spoink.png
# spritzee.png
# squirtle.png
# stakataka.jpg
# stantler.png
# staraptor.png
# staravia.png
# starly.png
# starmie.png
# staryu.png
# steelix.png
# steenee.jpg
# stoutland.png
# stufful.jpg
# stunfisk.png
# stunky.png
# sudowoodo.png
# suicune.png
# sunflora.png
# sunkern.png
# surskit.png
# swablu.png
# swadloon.png
# swalot.png
# swampert.png
# swanna.png
# swellow.png
# swinub.png
# swirlix.png
# swoobat.png
# sylveon.png
# taillow.png
# talonflame.png
# tangela.png
# tangrowth.png
# tapu-bulu.jpg
# tapu-fini.jpg
# tapu-koko.jpg
# tapu-lele.jpg
# tauros.png
# teddiursa.png
# tentacool.png
# tentacruel.png
# tepig.png
# terrakion.png
# throh.png
# thundurus-incarnate.png
# timburr.png
# tirtouga.png
# togedemaru.jpg
# togekiss.png
# togepi.png
# togetic.png
# torchic.png
# torkoal.png
# tornadus-incarnate.png
# torracat.jpg
# torterra.png
# totodile.png
# toucannon.jpg
# toxapex.jpg
# toxicroak.png
# tranquill.png
# trapinch.png
# treecko.png
# trevenant.png
# tropius.png
# trubbish.png
# trumbeak.jpg
# tsareena.jpg
# turtonator.jpg
# turtwig.png
# tympole.png
# tynamo.png
# type-null.jpg
# typhlosion.png
# tyranitar.png
# tyrantrum.png
# tyrogue.png
# tyrunt.png
# umbreon.png
# unfezant.png
# unown.png
# ursaring.png
# uxie.png
# vanillish.png
# vanillite.png
# vanilluxe.png
# vaporeon.png
# venipede.png
# venomoth.png
# venonat.png
# venusaur.png
# vespiquen.png
# vibrava.png
# victini.png
# victreebel.png
# vigoroth.png
# vikavolt.jpg
# vileplume.png
# virizion.png
# vivillon.png
# volbeat.png
# volcanion.png
# volcarona.png
# voltorb.png
# vullaby.png
# vulpix.png
# wailmer.png
# wailord.png
# walrein.png
# wartortle.png
# watchog.png
# weavile.png
# weedle.png
# weepinbell.png
# weezing.png
# whimsicott.png
# whirlipede.png
# whiscash.png
# whismur.png
# wigglytuff.png
# wimpod.jpg
# wingull.png
# wishiwashi-solo.jpg
# wobbuffet.png
# woobat.png
# wooper.png
# wormadam-plant.png
# wurmple.png
# wynaut.png
# xatu.png
# xerneas.png
# xurkitree.jpg
# yamask.png
# yanma.png
# yanmega.png
# yungoos.jpg
# yveltal.png
# zangoose.png
# zapdos.png
# zebstrika.png
# zekrom.png
# zeraora.jpg
# zigzagoon.png
# zoroark.png
# zorua.png
# zubat.png
# zweilous.png
# zygarde-50.png

# %%
transform=A.Compose([
#     A.Resize(width=1920,height=1080),
#     A.RandomCrop(width=1280,height=720),
    A.Rotate(limit=40,p=0.9),
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip (p=0.1),
#     A.RGBShift(r_shift_limit=25,g_shift_limit=25,b_shift_limit=25,p=0.9),
    A.OneOf([
        A.Blur(blur_limit=3,p=0.5)
    ],p=1.0),
])

# %%
l=[]
for i in os.listdir():
    img=Image.open(i)
    img=np.array(img)
    image_list=[img]
    for j in range(2):
        augumentations=transform(image=img)
        augumentation_image=augumentations["image"]
        image_list.append(augumentation_image)
    l.append(image_list)
print(len(l))
# Out:
# 809

# %%
k=0
i=l[400]
print(len(i))
plt.imshow(i[0])
plt.show()
# Out:
# 3

# %%
plt.imshow(i[1])
plt.show()

# %%
plt.imshow(i[2])
plt.show()

# %%
di=os.listdir()
di
# %cd mern
# %cd samples
# Out:
# C:\Users\Rohith\mern
# C:\Users\Rohith\mern\samples

# %%
curr=os.getcwd()
curr
# Out:
# 'C:\\Users\\Rohith\\mern\\samples'

# %%
count=0
for i in l:
    directory=di[count].split(".")[0]
    count+=1
    path = os.path.join(curr, directory)
    os.mkdir(path)
    os.chdir(path)
    ind=0
    for j in i:
        i = Image.fromarray(j)
        i.save(directory+str(ind)+".png")
        ind+=1

# %%
di=os.listdir()
di
# Out:
# ['abomasnow.png',
#  'abra.png',
#  'absol.png',
#  'accelgor.png',
#  'aegislash-blade.png',
#  'aerodactyl.png',
#  'aggron.png',
#  'aipom.png',
#  'alakazam.png',
#  'alomomola.png',
#  'altaria.png',
#  'amaura.png',
#  'ambipom.png',
#  'amoonguss.png',
#  'ampharos.png',
#  'anorith.png',
#  'araquanid.jpg',
#  'arbok.png',
#  'arcanine.png',
#  'arceus.png',
#  'archen.png',
#  'archeops.png',
#  'ariados.png',
#  'armaldo.png',
#  'aromatisse.png',
#  'aron.png',
#  'articuno.png',
#  'audino.png',
#  'aurorus.png',
#  'avalugg.png',
#  'axew.png',
#  'azelf.png',
#  'azumarill.png',
#  'azurill.png',
#  'bagon.png',
#  'baltoy.png',
#  'banette.png',
#  'barbaracle.png',
#  'barboach.png',
#  'basculin-red-striped.png',
#  'bastiodon.png',
#  'bayleef.png',
#  'beartic.png',
#  'beautifly.png',
#  'beedrill.png',
#  'beheeyem.png',
#  'beldum.png',
#  'bellossom.png',
#  'bellsprout.png',
#  'bergmite.png',
#  'bewear.jpg',
#  'bibarel.png',
#  'bidoof.png',
#  'binacle.png',
#  'bisharp.png',
#  'blacephalon.jpg',
#  'blastoise.png',
#  'blaziken.png',
#  'blissey.png',
#  'blitzle.png',
#  'boldore.png',
#  'bonsly.png',
#  'bouffalant.png',
#  'bounsweet.jpg',
#  'braixen.png',
#  'braviary.png',
#  'breloom.png',
#  'brionne.jpg',
#  'bronzong.png',
#  'bronzor.png',
#  'bruxish.jpg',
#  'budew.png',
#  'buizel.png',
#  'bulbasaur.png',
#  'buneary.png',
#  'bunnelby.png',
#  'burmy.png',
#  'butterfree.png',
#  'buzzwole.jpg',
#  'cacnea.png',
#  'cacturne.png',
#  'camerupt.png',
#  'carbink.png',
#  'carnivine.png',
#  'carracosta.png',
#  'carvanha.png',
#  'cascoon.png',
#  'castform.png',
#  'caterpie.png',
#  'celebi.png',
#  'celesteela.jpg',
#  'chandelure.png',
#  'chansey.png',
#  'charizard.png',
#  'charjabug.jpg',
#  'charmander.png',
#  'charmeleon.png',
#  'chatot.png',
#  'cherrim.png',
#  'cherubi.png',
#  'chesnaught.png',
#  'chespin.png',
#  'chikorita.png',
#  'chimchar.png',
#  'chimecho.png',
#  'chinchou.png',
#  'chingling.png',
#  'cinccino.png',
#  'clamperl.png',
#  'clauncher.png',
#  'clawitzer.png',
#  'claydol.png',
#  'clefable.png',
#  'clefairy.png',
#  'cleffa.png',
#  'cloyster.png',
#  'cobalion.png',
#  'cofagrigus.png',
#  'combee.png',
#  'combusken.png',
#  'comfey.jpg',
#  'conkeldurr.png',
#  'corphish.png',
#  'corsola.png',
#  'cosmoem.jpg',
#  'cosmog.jpg',
#  'cottonee.png',
#  'crabominable.jpg',
#  'crabrawler.jpg',
#  'cradily.png',
#  'cranidos.png',
#  'crawdaunt.png',
#  'cresselia.png',
#  'croagunk.png',
#  'crobat.png',
#  'croconaw.png',
#  'crustle.png',
#  'cryogonal.png',
#  'cubchoo.png',
#  'cubone.png',
#  'cutiefly.jpg',
#  'cyndaquil.png',
#  'darkrai.png',
#  'darmanitan-standard.png',
#  'dartrix.jpg',
#  'darumaka.png',
#  'decidueye.jpg',
#  'dedenne.png',
#  'deerling.png',
#  'deino.png',
#  'delcatty.png',
#  'delibird.png',
#  'delphox.png',
#  'deoxys-normal.png',
#  'dewgong.png',
#  'dewott.png',
#  'dewpider.jpg',
#  'dhelmise.jpg',
#  'dialga.png',
#  'diancie.png',
#  'diggersby.png',
#  'diglett.png',
#  'ditto.png',
#  'dodrio.png',
#  'doduo.png',
#  'donphan.png',
#  'doublade.png',
#  'dragalge.png',
#  'dragonair.png',
#  'dragonite.png',
#  'drampa.jpg',
#  'drapion.png',
#  'dratini.png',
#  'drifblim.png',
#  'drifloon.png',
#  'drilbur.png',
#  'drowzee.png',
#  'druddigon.png',
#  'ducklett.png',
#  'dugtrio.png',
#  'dunsparce.png',
#  'duosion.png',
#  'durant.png',
#  'dusclops.png',
#  'dusknoir.png',
#  'duskull.png',
#  'dustox.png',
#  'dwebble.png',
#  'eelektrik.png',
#  'eelektross.png',
#  'eevee.png',
#  'ekans.png',
#  'electabuzz.png',
#  'electivire.png',
#  'electrike.png',
#  'electrode.png',
#  'elekid.png',
#  'elgyem.png',
#  'emboar.png',
#  'emolga.png',
#  'empoleon.png',
#  'entei.png',
#  'escavalier.png',
#  'espeon.png',
#  'espurr.png',
#  'excadrill.png',
#  'exeggcute.png',
#  'exeggutor.png',
#  'exploud.png',
#  'farfetchd.png',
#  'fearow.png',
#  'feebas.png',
#  'fennekin.png',
#  'feraligatr.png',
#  'ferroseed.png',
#  'ferrothorn.png',
#  'finneon.png',
#  'flaaffy.png',
#  'flabebe.png',
#  'flareon.png',
#  'fletchinder.png',
#  'fletchling.png',
#  'floatzel.png',
#  'floette.png',
#  'florges.png',
#  'flygon.png',
#  'fomantis.jpg',
#  'foongus.png',
#  'forretress.png',
#  'fraxure.png',
#  'frillish.png',
#  'froakie.png',
#  'frogadier.png',
#  'froslass.png',
#  'furfrou.png',
#  'furret.png',
#  'gabite.png',
#  'gallade.png',
#  'galvantula.png',
#  'garbodor.png',
#  'garchomp.png',
#  'gardevoir.png',
#  'gastly.png',
#  'gastrodon.png',
#  'genesect.png',
#  'gengar.png',
#  'geodude.png',
#  'gible.png',
#  'gigalith.png',
#  'girafarig.png',
#  'giratina-altered.png',
#  'glaceon.png',
#  'glalie.png',
#  'glameow.png',
#  'gligar.png',
#  'gliscor.png',
#  'gloom.png',
#  'gogoat.png',
#  'golbat.png',
#  'goldeen.png',
#  'golduck.png',
#  'golem.png',
#  'golett.png',
#  'golisopod.jpg',
#  'golurk.png',
#  'goodra.png',
#  'goomy.png',
#  'gorebyss.png',
#  'gothita.png',
#  'gothitelle.png',
#  'gothorita.png',
#  'gourgeist-average.png',
#  'granbull.png',
#  'graveler.png',
#  'greninja.png',
#  'grimer.png',
#  'grotle.png',
#  'groudon.png',
#  'grovyle.png',
#  'growlithe.png',
#  'grubbin.jpg',
#  'grumpig.png',
#  'gulpin.png',
#  'gumshoos.jpg',
#  'gurdurr.png',
#  'guzzlord.jpg',
#  'gyarados.png',
#  'hakamo-o.jpg',
#  'happiny.png',
#  'hariyama.png',
#  'haunter.png',
#  'hawlucha.png',
#  'haxorus.png',
#  'heatmor.png',
#  'heatran.png',
#  'heliolisk.png',
#  'helioptile.png',
#  'heracross.png',
#  'herdier.png',
#  'hippopotas.png',
#  'hippowdon.png',
#  'hitmonchan.png',
#  'hitmonlee.png',
#  'hitmontop.png',
#  'ho-oh.png',
#  'honchkrow.png',
#  'honedge.png',
#  'hoopa-confined.png',
#  'hoothoot.png',
#  'hoppip.png',
#  'horsea.png',
#  'houndoom.png',
#  'houndour.png',
#  'huntail.png',
#  'hydreigon.png',
#  'hypno.png',
#  'igglybuff.png',
#  'illumise.png',
#  'incineroar.jpg',
#  'infernape.png',
#  'inkay.png',
#  'ivysaur.png',
#  'jangmo-o.jpg',
#  'jellicent.png',
#  'jigglypuff.png',
#  'jirachi.png',
#  'jolteon.png',
#  'joltik.png',
#  'jumpluff.png',
#  'jynx.png',
#  'kabuto.png',
#  'kabutops.png',
#  'kadabra.png',
#  'kakuna.png',
#  'kangaskhan.png',
#  'karrablast.png',
#  'kartana.jpg',
#  'kecleon.png',
#  'keldeo-ordinary.png',
#  'kingdra.png',
#  'kingler.png',
#  'kirlia.png',
#  'klang.png',
#  'klefki.png',
#  'klink.png',
#  'klinklang.png',
#  'koffing.png',
#  'komala.jpg',
#  'kommo-o.jpg',
#  'krabby.png',
#  'kricketot.png',
#  'kricketune.png',
#  'krokorok.png',
#  'krookodile.png',
#  'kyogre.png',
#  'kyurem.png',
#  'lairon.png',
#  'lampent.png',
#  'landorus-incarnate.png',
#  'lanturn.png',
#  'lapras.png',
#  'larvesta.png',
#  'larvitar.png',
#  'latias.png',
#  'latios.png',
#  'leafeon.png',
#  'leavanny.png',
#  'ledian.png',
#  'ledyba.png',
#  'lickilicky.png',
#  'lickitung.png',
#  'liepard.png',
#  'lileep.png',
#  'lilligant.png',
#  'lillipup.png',
#  'linoone.png',
#  'litleo.png',
#  'litten.jpg',
#  'litwick.png',
#  'lombre.png',
#  'lopunny.png',
#  'lotad.png',
#  'loudred.png',
#  'lucario.png',
#  'ludicolo.png',
#  'lugia.png',
#  'lumineon.png',
#  'lunala.jpg',
#  'lunatone.png',
#  'lurantis.jpg',
#  'luvdisc.png',
#  'luxio.png',
#  'luxray.png',
#  'lycanroc-midday.jpg',
#  'machamp.png',
#  'machoke.png',
#  'machop.png',
#  'magby.png',
#  'magcargo.png',
#  'magearna.jpg',
#  'magikarp.png',
#  'magmar.png',
#  'magmortar.png',
#  'magnemite.png',
#  'magneton.png',
#  'magnezone.png',
#  'makuhita.png',
#  'malamar.png',
#  'mamoswine.png',
#  'manaphy.png',
#  'mandibuzz.png',
#  'manectric.png',
#  'mankey.png',
#  'mantine.png',
#  'mantyke.png',
#  'maractus.png',
#  'mareanie.jpg',
#  'mareep.png',
#  'marill.png',
#  'marowak.png',
#  'marshadow.jpg',
#  'marshtomp.png',
#  'masquerain.png',
#  'mawile.png',
#  'medicham.png',
#  'meditite.png',
#  'meganium.png',
#  'melmetal.jpg',
#  'meloetta-aria.png',
#  'meltan.jpg',
#  'meowstic-male.png',
#  'meowth.png',
#  'mesprit.png',
#  'metagross.png',
#  'metang.png',
#  'metapod.png',
#  'mew.png',
#  'mewtwo.png',
#  'mienfoo.png',
#  'mienshao.png',
#  'mightyena.png',
#  'milotic.png',
#  'miltank.png',
#  'mime-jr.png',
#  'mimikyu.jpg',
#  'minccino.png',
#  'minior-meteor.jpg',
#  'minun.png',
#  'misdreavus.png',
#  'mismagius.png',
#  'moltres.png',
#  'monferno.png',
#  'morelull.jpg',
#  'mothim.png',
#  'mr-mime.png',
#  'mudbray.jpg',
#  'mudkip.png',
#  'mudsdale.jpg',
#  'muk.png',
#  'munchlax.png',
#  'munna.png',
#  'murkrow.png',
#  'musharna.png',
#  'naganadel.jpg',
#  'natu.png',
#  'necrozma.jpg',
#  'nidoking.png',
#  'nidoqueen.png',
#  'nidoran-f.png',
#  'nidoran-m.png',
#  'nidorina.png',
#  'nidorino.png',
#  'nihilego.jpg',
#  'nincada.png',
#  'ninetales.png',
#  'ninjask.png',
#  'noctowl.png',
#  'noibat.png',
#  'noivern.png',
#  'nosepass.png',
#  'numel.png',
#  'nuzleaf.png',
#  'octillery.png',
#  'oddish.png',
#  'omanyte.png',
#  'omastar.png',
#  'onix.png',
#  'oranguru.jpg',
#  'oricorio-baile.jpg',
#  'oshawott.png',
#  'pachirisu.png',
#  'palkia.png',
#  'palossand.jpg',
#  'palpitoad.png',
#  'pancham.png',
#  'pangoro.png',
#  'panpour.png',
#  'pansage.png',
#  'pansear.png',
#  'paras.png',
#  'parasect.png',
#  'passimian.jpg',
#  'patrat.png',
#  'pawniard.png',
#  'pelipper.png',
#  'persian.png',
#  'petilil.png',
#  'phanpy.png',
#  'phantump.png',
#  'pheromosa.jpg',
#  'phione.png',
#  'pichu.png',
#  'pidgeot.png',
#  'pidgeotto.png',
#  'pidgey.png',
#  'pidove.png',
#  'pignite.png',
#  'pikachu.png',
#  'pikipek.jpg',
#  'piloswine.png',
#  'pineco.png',
#  'pinsir.png',
#  'piplup.png',
#  'plusle.png',
#  'poipole.jpg',
#  'politoed.png',
#  'poliwag.png',
#  'poliwhirl.png',
#  'poliwrath.png',
#  'ponyta.png',
#  'poochyena.png',
#  'popplio.jpg',
#  'porygon-z.png',
#  'porygon.png',
#  'porygon2.png',
#  'primarina.jpg',
#  'primeape.png',
#  'prinplup.png',
#  'probopass.png',
#  'psyduck.png',
#  'pumpkaboo-average.png',
#  'pupitar.png',
#  'purrloin.png',
#  'purugly.png',
#  'pyroar.png',
#  'pyukumuku.jpg',
#  'quagsire.png',
#  'quilava.png',
#  'quilladin.png',
#  'qwilfish.png',
#  'raichu.png',
#  'raikou.png',
#  'ralts.png',
#  'rampardos.png',
#  'rapidash.png',
#  'raticate.png',
#  'rattata.png',
#  'rayquaza.png',
#  'regice.png',
#  'regigigas.png',
#  'regirock.png',
#  'registeel.png',
#  'relicanth.png',
#  'remoraid.png',
#  'reshiram.png',
#  'reuniclus.png',
#  'rhydon.png',
#  'rhyhorn.png',
#  'rhyperior.png',
#  'ribombee.jpg',
#  'riolu.png',
#  'rockruff.jpg',
#  'roggenrola.png',
#  'roselia.png',
#  'roserade.png',
#  'rotom.png',
#  'rowlet.jpg',
#  'rufflet.png',
#  'sableye.png',
#  'salamence.png',
#  'salandit.jpg',
#  'salazzle.jpg',
#  'samurott.png',
#  'sandile.png',
#  'sandshrew.png',
#  'sandslash.png',
#  'sandygast.jpg',
#  'sawk.png',
#  'sawsbuck.png',
#  'scatterbug.png',
#  'sceptile.png',
#  'scizor.png',
#  'scolipede.png',
#  'scrafty.png',
#  'scraggy.png',
#  'scyther.png',
#  'seadra.png',
#  'seaking.png',
#  'sealeo.png',
#  'seedot.png',
#  'seel.png',
#  'seismitoad.png',
#  'sentret.png',
#  'serperior.png',
#  'servine.png',
#  'seviper.png',
#  'sewaddle.png',
#  'sharpedo.png',
#  'shaymin-land.png',
#  'shedinja.png',
#  'shelgon.png',
#  'shellder.png',
#  'shellos.png',
#  'shelmet.png',
#  'shieldon.png',
#  'shiftry.png',
#  'shiinotic.jpg',
#  'shinx.png',
#  'shroomish.png',
#  'shuckle.png',
#  'shuppet.png',
#  'sigilyph.png',
#  'silcoon.png',
#  'silvally.jpg',
#  'simipour.png',
#  'simisage.png',
#  'simisear.png',
#  'skarmory.png',
#  'skiddo.png',
#  'skiploom.png',
#  'skitty.png',
#  'skorupi.png',
#  'skrelp.png',
#  'skuntank.png',
#  'slaking.png',
#  'slakoth.png',
#  'sliggoo.png',
#  'slowbro.png',
#  'slowking.png',
#  'slowpoke.png',
#  'slugma.png',
#  'slurpuff.png',
#  'smeargle.png',
#  'smoochum.png',
#  'sneasel.png',
#  'snivy.png',
#  'snorlax.png',
#  'snorunt.png',
#  'snover.png',
#  'snubbull.png',
#  'solgaleo.jpg',
#  'solosis.png',
#  'solrock.png',
#  'spearow.png',
#  'spewpa.png',
#  'spheal.png',
#  'spinarak.png',
#  'spinda.png',
#  'spiritomb.png',
#  'spoink.png',
#  'spritzee.png',
#  'squirtle.png',
#  'stakataka.jpg',
#  'stantler.png',
#  'staraptor.png',
#  'staravia.png',
#  'starly.png',
#  'starmie.png',
#  'staryu.png',
#  'steelix.png',
#  'steenee.jpg',
#  'stoutland.png',
#  'stufful.jpg',
#  'stunfisk.png',
#  'stunky.png',
#  'sudowoodo.png',
#  'suicune.png',
#  'sunflora.png',
#  'sunkern.png',
#  'surskit.png',
#  'swablu.png',
#  'swadloon.png',
#  'swalot.png',
#  'swampert.png',
#  'swanna.png',
#  'swellow.png',
#  'swinub.png',
#  'swirlix.png',
#  'swoobat.png',
#  'sylveon.png',
#  'taillow.png',
#  'talonflame.png',
#  'tangela.png',
#  'tangrowth.png',
#  'tapu-bulu.jpg',
#  'tapu-fini.jpg',
#  'tapu-koko.jpg',
#  'tapu-lele.jpg',
#  'tauros.png',
#  'teddiursa.png',
#  'tentacool.png',
#  'tentacruel.png',
#  'tepig.png',
#  'terrakion.png',
#  'throh.png',
#  'thundurus-incarnate.png',
#  'timburr.png',
#  'tirtouga.png',
#  'togedemaru.jpg',
#  'togekiss.png',
#  'togepi.png',
#  'togetic.png',
#  'torchic.png',
#  'torkoal.png',
#  'tornadus-incarnate.png',
#  'torracat.jpg',
#  'torterra.png',
#  'totodile.png',
#  'toucannon.jpg',
#  'toxapex.jpg',
#  'toxicroak.png',
#  'tranquill.png',
#  'trapinch.png',
#  'treecko.png',
#  'trevenant.png',
#  'tropius.png',
#  'trubbish.png',
#  'trumbeak.jpg',
#  'tsareena.jpg',
#  'turtonator.jpg',
#  'turtwig.png',
#  'tympole.png',
#  'tynamo.png',
#  'type-null.jpg',
#  'typhlosion.png',
#  'tyranitar.png',
#  'tyrantrum.png',
#  'tyrogue.png',
#  'tyrunt.png',
#  'umbreon.png',
#  'unfezant.png',
#  'unown.png',
#  'ursaring.png',
#  'uxie.png',
#  'vanillish.png',
#  'vanillite.png',
#  'vanilluxe.png',
#  'vaporeon.png',
#  'venipede.png',
#  'venomoth.png',
#  'venonat.png',
#  'venusaur.png',
#  'vespiquen.png',
#  'vibrava.png',
#  'victini.png',
#  'victreebel.png',
#  'vigoroth.png',
#  'vikavolt.jpg',
#  'vileplume.png',
#  'virizion.png',
#  'vivillon.png',
#  'volbeat.png',
#  'volcanion.png',
#  'volcarona.png',
#  'voltorb.png',
#  'vullaby.png',
#  'vulpix.png',
#  'wailmer.png',
#  'wailord.png',
#  'walrein.png',
#  'wartortle.png',
#  'watchog.png',
#  'weavile.png',
#  'weedle.png',
#  'weepinbell.png',
#  'weezing.png',
#  'whimsicott.png',
#  'whirlipede.png',
#  'whiscash.png',
#  'whismur.png',
#  'wigglytuff.png',
#  'wimpod.jpg',
#  'wingull.png',
#  'wishiwashi-solo.jpg',
#  'wobbuffet.png',
#  'woobat.png',
#  'wooper.png',
#  'wormadam-plant.png',
#  'wurmple.png',
#  'wynaut.png',
#  'xatu.png',
#  'xerneas.png',
#  'xurkitree.jpg',
#  'yamask.png',
#  'yanma.png',
#  'yanmega.png',
#  'yungoos.jpg',
#  'yveltal.png',
#  'zangoose.png',
#  'zapdos.png',
#  'zebstrika.png',
#  'zekrom.png',
#  'zeraora.jpg',
#  'zigzagoon.png',
#  'zoroark.png',
#  'zorua.png',
#  'zubat.png',
#  'zweilous.png',
#  'zygarde-50.png']

# %%
curr=os.getcwd()
curr
# Out:
# 'C:\\Users\\Rohith\\mern\\samples'

# %%
# %cd samples
# Out:
# C:\Users\Rohith\mern\samples

# %%
categories=os.listdir()
categories
# Out:
# ['abomasnow',
#  'abra',
#  'absol',
#  'accelgor',
#  'aegislash-blade',
#  'aerodactyl',
#  'aggron',
#  'aipom',
#  'alakazam',
#  'alomomola',
#  'altaria',
#  'amaura',
#  'ambipom',
#  'amoonguss',
#  'ampharos',
#  'anorith',
#  'araquanid',
#  'arbok',
#  'arcanine',
#  'arceus',
#  'archen',
#  'archeops',
#  'ariados',
#  'armaldo',
#  'aromatisse',
#  'aron',
#  'articuno',
#  'audino',
#  'aurorus',
#  'avalugg',
#  'axew',
#  'azelf',
#  'azumarill',
#  'azurill',
#  'bagon',
#  'baltoy',
#  'banette',
#  'barbaracle',
#  'barboach',
#  'basculin-red-striped',
#  'bastiodon',
#  'bayleef',
#  'beartic',
#  'beautifly',
#  'beedrill',
#  'beheeyem',
#  'beldum',
#  'bellossom',
#  'bellsprout',
#  'bergmite',
#  'bewear',
#  'bibarel',
#  'bidoof',
#  'binacle',
#  'bisharp',
#  'blacephalon',
#  'blastoise',
#  'blaziken',
#  'blissey',
#  'blitzle',
#  'boldore',
#  'bonsly',
#  'bouffalant',
#  'bounsweet',
#  'braixen',
#  'braviary',
#  'breloom',
#  'brionne',
#  'bronzong',
#  'bronzor',
#  'bruxish',
#  'budew',
#  'buizel',
#  'bulbasaur',
#  'buneary',
#  'bunnelby',
#  'burmy',
#  'butterfree',
#  'buzzwole',
#  'cacnea',
#  'cacturne',
#  'camerupt',
#  'carbink',
#  'carnivine',
#  'carracosta',
#  'carvanha',
#  'cascoon',
#  'castform',
#  'caterpie',
#  'celebi',
#  'celesteela',
#  'chandelure',
#  'chansey',
#  'charizard',
#  'charjabug',
#  'charmander',
#  'charmeleon',
#  'chatot',
#  'cherrim',
#  'cherubi',
#  'chesnaught',
#  'chespin',
#  'chikorita',
#  'chimchar',
#  'chimecho',
#  'chinchou',
#  'chingling',
#  'cinccino',
#  'clamperl',
#  'clauncher',
#  'clawitzer',
#  'claydol',
#  'clefable',
#  'clefairy',
#  'cleffa',
#  'cloyster',
#  'cobalion',
#  'cofagrigus',
#  'combee',
#  'combusken',
#  'comfey',
#  'conkeldurr',
#  'corphish',
#  'corsola',
#  'cosmoem',
#  'cosmog',
#  'cottonee',
#  'crabominable',
#  'crabrawler',
#  'cradily',
#  'cranidos',
#  'crawdaunt',
#  'cresselia',
#  'croagunk',
#  'crobat',
#  'croconaw',
#  'crustle',
#  'cryogonal',
#  'cubchoo',
#  'cubone',
#  'cutiefly',
#  'cyndaquil',
#  'darkrai',
#  'darmanitan-standard',
#  'dartrix',
#  'darumaka',
#  'decidueye',
#  'dedenne',
#  'deerling',
#  'deino',
#  'delcatty',
#  'delibird',
#  'delphox',
#  'deoxys-normal',
#  'dewgong',
#  'dewott',
#  'dewpider',
#  'dhelmise',
#  'dialga',
#  'diancie',
#  'diggersby',
#  'diglett',
#  'ditto',
#  'dodrio',
#  'doduo',
#  'donphan',
#  'doublade',
#  'dragalge',
#  'dragonair',
#  'dragonite',
#  'drampa',
#  'drapion',
#  'dratini',
#  'drifblim',
#  'drifloon',
#  'drilbur',
#  'drowzee',
#  'druddigon',
#  'ducklett',
#  'dugtrio',
#  'dunsparce',
#  'duosion',
#  'durant',
#  'dusclops',
#  'dusknoir',
#  'duskull',
#  'dustox',
#  'dwebble',
#  'eelektrik',
#  'eelektross',
#  'eevee',
#  'ekans',
#  'electabuzz',
#  'electivire',
#  'electrike',
#  'electrode',
#  'elekid',
#  'elgyem',
#  'emboar',
#  'emolga',
#  'empoleon',
#  'entei',
#  'escavalier',
#  'espeon',
#  'espurr',
#  'excadrill',
#  'exeggcute',
#  'exeggutor',
#  'exploud',
#  'farfetchd',
#  'fearow',
#  'feebas',
#  'fennekin',
#  'feraligatr',
#  'ferroseed',
#  'ferrothorn',
#  'finneon',
#  'flaaffy',
#  'flabebe',
#  'flareon',
#  'fletchinder',
#  'fletchling',
#  'floatzel',
#  'floette',
#  'florges',
#  'flygon',
#  'fomantis',
#  'foongus',
#  'forretress',
#  'fraxure',
#  'frillish',
#  'froakie',
#  'frogadier',
#  'froslass',
#  'furfrou',
#  'furret',
#  'gabite',
#  'gallade',
#  'galvantula',
#  'garbodor',
#  'garchomp',
#  'gardevoir',
#  'gastly',
#  'gastrodon',
#  'genesect',
#  'gengar',
#  'geodude',
#  'gible',
#  'gigalith',
#  'girafarig',
#  'giratina-altered',
#  'glaceon',
#  'glalie',
#  'glameow',
#  'gligar',
#  'gliscor',
#  'gloom',
#  'gogoat',
#  'golbat',
#  'goldeen',
#  'golduck',
#  'golem',
#  'golett',
#  'golisopod',
#  'golurk',
#  'goodra',
#  'goomy',
#  'gorebyss',
#  'gothita',
#  'gothitelle',
#  'gothorita',
#  'gourgeist-average',
#  'granbull',
#  'graveler',
#  'greninja',
#  'grimer',
#  'grotle',
#  'groudon',
#  'grovyle',
#  'growlithe',
#  'grubbin',
#  'grumpig',
#  'gulpin',
#  'gumshoos',
#  'gurdurr',
#  'guzzlord',
#  'gyarados',
#  'hakamo-o',
#  'happiny',
#  'hariyama',
#  'haunter',
#  'hawlucha',
#  'haxorus',
#  'heatmor',
#  'heatran',
#  'heliolisk',
#  'helioptile',
#  'heracross',
#  'herdier',
#  'hippopotas',
#  'hippowdon',
#  'hitmonchan',
#  'hitmonlee',
#  'hitmontop',
#  'ho-oh',
#  'honchkrow',
#  'honedge',
#  'hoopa-confined',
#  'hoothoot',
#  'hoppip',
#  'horsea',
#  'houndoom',
#  'houndour',
#  'huntail',
#  'hydreigon',
#  'hypno',
#  'igglybuff',
#  'illumise',
#  'incineroar',
#  'infernape',
#  'inkay',
#  'ivysaur',
#  'jangmo-o',
#  'jellicent',
#  'jigglypuff',
#  'jirachi',
#  'jolteon',
#  'joltik',
#  'jumpluff',
#  'jynx',
#  'kabuto',
#  'kabutops',
#  'kadabra',
#  'kakuna',
#  'kangaskhan',
#  'karrablast',
#  'kartana',
#  'kecleon',
#  'keldeo-ordinary',
#  'kingdra',
#  'kingler',
#  'kirlia',
#  'klang',
#  'klefki',
#  'klink',
#  'klinklang',
#  'koffing',
#  'komala',
#  'kommo-o',
#  'krabby',
#  'kricketot',
#  'kricketune',
#  'krokorok',
#  'krookodile',
#  'kyogre',
#  'kyurem',
#  'lairon',
#  'lampent',
#  'landorus-incarnate',
#  'lanturn',
#  'lapras',
#  'larvesta',
#  'larvitar',
#  'latias',
#  'latios',
#  'leafeon',
#  'leavanny',
#  'ledian',
#  'ledyba',
#  'lickilicky',
#  'lickitung',
#  'liepard',
#  'lileep',
#  'lilligant',
#  'lillipup',
#  'linoone',
#  'litleo',
#  'litten',
#  'litwick',
#  'lombre',
#  'lopunny',
#  'lotad',
#  'loudred',
#  'lucario',
#  'ludicolo',
#  'lugia',
#  'lumineon',
#  'lunala',
#  'lunatone',
#  'lurantis',
#  'luvdisc',
#  'luxio',
#  'luxray',
#  'lycanroc-midday',
#  'machamp',
#  'machoke',
#  'machop',
#  'magby',
#  'magcargo',
#  'magearna',
#  'magikarp',
#  'magmar',
#  'magmortar',
#  'magnemite',
#  'magneton',
#  'magnezone',
#  'makuhita',
#  'malamar',
#  'mamoswine',
#  'manaphy',
#  'mandibuzz',
#  'manectric',
#  'mankey',
#  'mantine',
#  'mantyke',
#  'maractus',
#  'mareanie',
#  'mareep',
#  'marill',
#  'marowak',
#  'marshadow',
#  'marshtomp',
#  'masquerain',
#  'mawile',
#  'medicham',
#  'meditite',
#  'meganium',
#  'melmetal',
#  'meloetta-aria',
#  'meltan',
#  'meowstic-male',
#  'meowth',
#  'mesprit',
#  'metagross',
#  'metang',
#  'metapod',
#  'mew',
#  'mewtwo',
#  'mienfoo',
#  'mienshao',
#  'mightyena',
#  'milotic',
#  'miltank',
#  'mime-jr',
#  'mimikyu',
#  'minccino',
#  'minior-meteor',
#  'minun',
#  'misdreavus',
#  'mismagius',
#  'moltres',
#  'monferno',
#  'morelull',
#  'mothim',
#  'mr-mime',
#  'mudbray',
#  'mudkip',
#  'mudsdale',
#  'muk',
#  'munchlax',
#  'munna',
#  'murkrow',
#  'musharna',
#  'naganadel',
#  'natu',
#  'necrozma',
#  'nidoking',
#  'nidoqueen',
#  'nidoran-f',
#  'nidoran-m',
#  'nidorina',
#  'nidorino',
#  'nihilego',
#  'nincada',
#  'ninetales',
#  'ninjask',
#  'noctowl',
#  'noibat',
#  'noivern',
#  'nosepass',
#  'numel',
#  'nuzleaf',
#  'octillery',
#  'oddish',
#  'omanyte',
#  'omastar',
#  'onix',
#  'oranguru',
#  'oricorio-baile',
#  'oshawott',
#  'pachirisu',
#  'palkia',
#  'palossand',
#  'palpitoad',
#  'pancham',
#  'pangoro',
#  'panpour',
#  'pansage',
#  'pansear',
#  'paras',
#  'parasect',
#  'passimian',
#  'patrat',
#  'pawniard',
#  'pelipper',
#  'persian',
#  'petilil',
#  'phanpy',
#  'phantump',
#  'pheromosa',
#  'phione',
#  'pichu',
#  'pidgeot',
#  'pidgeotto',
#  'pidgey',
#  'pidove',
#  'pignite',
#  'pikachu',
#  'pikipek',
#  'piloswine',
#  'pineco',
#  'pinsir',
#  'piplup',
#  'plusle',
#  'poipole',
#  'politoed',
#  'poliwag',
#  'poliwhirl',
#  'poliwrath',
#  'ponyta',
#  'poochyena',
#  'popplio',
#  'porygon',
#  'porygon-z',
#  'porygon2',
#  'primarina',
#  'primeape',
#  'prinplup',
#  'probopass',
#  'psyduck',
#  'pumpkaboo-average',
#  'pupitar',
#  'purrloin',
#  'purugly',
#  'pyroar',
#  'pyukumuku',
#  'quagsire',
#  'quilava',
#  'quilladin',
#  'qwilfish',
#  'raichu',
#  'raikou',
#  'ralts',
#  'rampardos',
#  'rapidash',
#  'raticate',
#  'rattata',
#  'rayquaza',
#  'regice',
#  'regigigas',
#  'regirock',
#  'registeel',
#  'relicanth',
#  'remoraid',
#  'reshiram',
#  'reuniclus',
#  'rhydon',
#  'rhyhorn',
#  'rhyperior',
#  'ribombee',
#  'riolu',
#  'rockruff',
#  'roggenrola',
#  'roselia',
#  'roserade',
#  'rotom',
#  'rowlet',
#  'rufflet',
#  'sableye',
#  'salamence',
#  'salandit',
#  'salazzle',
#  'samurott',
#  'sandile',
#  'sandshrew',
#  'sandslash',
#  'sandygast',
#  'sawk',
#  'sawsbuck',
#  'scatterbug',
#  'sceptile',
#  'scizor',
#  'scolipede',
#  'scrafty',
#  'scraggy',
#  'scyther',
#  'seadra',
#  'seaking',
#  'sealeo',
#  'seedot',
#  'seel',
#  'seismitoad',
#  'sentret',
#  'serperior',
#  'servine',
#  'seviper',
#  'sewaddle',
#  'sharpedo',
#  'shaymin-land',
#  'shedinja',
#  'shelgon',
#  'shellder',
#  'shellos',
#  'shelmet',
#  'shieldon',
#  'shiftry',
#  'shiinotic',
#  'shinx',
#  'shroomish',
#  'shuckle',
#  'shuppet',
#  'sigilyph',
#  'silcoon',
#  'silvally',
#  'simipour',
#  'simisage',
#  'simisear',
#  'skarmory',
#  'skiddo',
#  'skiploom',
#  'skitty',
#  'skorupi',
#  'skrelp',
#  'skuntank',
#  'slaking',
#  'slakoth',
#  'sliggoo',
#  'slowbro',
#  'slowking',
#  'slowpoke',
#  'slugma',
#  'slurpuff',
#  'smeargle',
#  'smoochum',
#  'sneasel',
#  'snivy',
#  'snorlax',
#  'snorunt',
#  'snover',
#  'snubbull',
#  'solgaleo',
#  'solosis',
#  'solrock',
#  'spearow',
#  'spewpa',
#  'spheal',
#  'spinarak',
#  'spinda',
#  'spiritomb',
#  'spoink',
#  'spritzee',
#  'squirtle',
#  'stakataka',
#  'stantler',
#  'staraptor',
#  'staravia',
#  'starly',
#  'starmie',
#  'staryu',
#  'steelix',
#  'steenee',
#  'stoutland',
#  'stufful',
#  'stunfisk',
#  'stunky',
#  'sudowoodo',
#  'suicune',
#  'sunflora',
#  'sunkern',
#  'surskit',
#  'swablu',
#  'swadloon',
#  'swalot',
#  'swampert',
#  'swanna',
#  'swellow',
#  'swinub',
#  'swirlix',
#  'swoobat',
#  'sylveon',
#  'taillow',
#  'talonflame',
#  'tangela',
#  'tangrowth',
#  'tapu-bulu',
#  'tapu-fini',
#  'tapu-koko',
#  'tapu-lele',
#  'tauros',
#  'teddiursa',
#  'tentacool',
#  'tentacruel',
#  'tepig',
#  'terrakion',
#  'throh',
#  'thundurus-incarnate',
#  'timburr',
#  'tirtouga',
#  'togedemaru',
#  'togekiss',
#  'togepi',
#  'togetic',
#  'torchic',
#  'torkoal',
#  'tornadus-incarnate',
#  'torracat',
#  'torterra',
#  'totodile',
#  'toucannon',
#  'toxapex',
#  'toxicroak',
#  'tranquill',
#  'trapinch',
#  'treecko',
#  'trevenant',
#  'tropius',
#  'trubbish',
#  'trumbeak',
#  'tsareena',
#  'turtonator',
#  'turtwig',
#  'tympole',
#  'tynamo',
#  'type-null',
#  'typhlosion',
#  'tyranitar',
#  'tyrantrum',
#  'tyrogue',
#  'tyrunt',
#  'umbreon',
#  'unfezant',
#  'unown',
#  'ursaring',
#  'uxie',
#  'vanillish',
#  'vanillite',
#  'vanilluxe',
#  'vaporeon',
#  'venipede',
#  'venomoth',
#  'venonat',
#  'venusaur',
#  'vespiquen',
#  'vibrava',
#  'victini',
#  'victreebel',
#  'vigoroth',
#  'vikavolt',
#  'vileplume',
#  'virizion',
#  'vivillon',
#  'volbeat',
#  'volcanion',
#  'volcarona',
#  'voltorb',
#  'vullaby',
#  'vulpix',
#  'wailmer',
#  'wailord',
#  'walrein',
#  'wartortle',
#  'watchog',
#  'weavile',
#  'weedle',
#  'weepinbell',
#  'weezing',
#  'whimsicott',
#  'whirlipede',
#  'whiscash',
#  'whismur',
#  'wigglytuff',
#  'wimpod',
#  'wingull',
#  'wishiwashi-solo',
#  'wobbuffet',
#  'woobat',
#  'wooper',
#  'wormadam-plant',
#  'wurmple',
#  'wynaut',
#  'xatu',
#  'xerneas',
#  'xurkitree',
#  'yamask',
#  'yanma',
#  'yanmega',
#  'yungoos',
#  'yveltal',
#  'zangoose',
#  'zapdos',
#  'zebstrika',
#  'zekrom',
#  'zeraora',
#  'zigzagoon',
#  'zoroark',
#  'zorua',
#  'zubat',
#  'zweilous',
#  'zygarde-50']

# %%
filenames=[]
cat=[]
for i in os.listdir(curr):
    path = os.path.join(curr, i)
    names=os.listdir(path)
    for j in names:
        filenames.append(j)
        cat.append(i)

# %%
filenames
# Out:
# ['abomasnow0.png',
#  'abomasnow1.png',
#  'abomasnow2.png',
#  'abra0.png',
#  'abra1.png',
#  'abra2.png',
#  'absol0.png',
#  'absol1.png',
#  'absol2.png',
#  'accelgor0.png',
#  'accelgor1.png',
#  'accelgor2.png',
#  'aegislash-blade0.png',
#  'aegislash-blade1.png',
#  'aegislash-blade2.png',
#  'aerodactyl0.png',
#  'aerodactyl1.png',
#  'aerodactyl2.png',
#  'aggron0.png',
#  'aggron1.png',
#  'aggron2.png',
#  'aipom0.png',
#  'aipom1.png',
#  'aipom2.png',
#  'alakazam0.png',
#  'alakazam1.png',
#  'alakazam2.png',
#  'alomomola0.png',
#  'alomomola1.png',
#  'alomomola2.png',
#  'altaria0.png',
#  'altaria1.png',
#  'altaria2.png',
#  'amaura0.png',
#  'amaura1.png',
#  'amaura2.png',
#  'ambipom0.png',
#  'ambipom1.png',
#  'ambipom2.png',
#  'amoonguss0.png',
#  'amoonguss1.png',
#  'amoonguss2.png',
#  'ampharos0.png',
#  'ampharos1.png',
#  'ampharos2.png',
#  'anorith0.png',
#  'anorith1.png',
#  'anorith2.png',
#  'araquanid0.png',
#  'araquanid1.png',
#  'araquanid2.png',
#  'arbok0.png',
#  'arbok1.png',
#  'arbok2.png',
#  'arcanine0.png',
#  'arcanine1.png',
#  'arcanine2.png',
#  'arceus0.png',
#  'arceus1.png',
#  'arceus2.png',
#  'archen0.png',
#  'archen1.png',
#  'archen2.png',
#  'archeops0.png',
#  'archeops1.png',
#  'archeops2.png',
#  'ariados0.png',
#  'ariados1.png',
#  'ariados2.png',
#  'armaldo0.png',
#  'armaldo1.png',
#  'armaldo2.png',
#  'aromatisse0.png',
#  'aromatisse1.png',
#  'aromatisse2.png',
#  'aron0.png',
#  'aron1.png',
#  'aron2.png',
#  'articuno0.png',
#  'articuno1.png',
#  'articuno2.png',
#  'audino0.png',
#  'audino1.png',
#  'audino2.png',
#  'aurorus0.png',
#  'aurorus1.png',
#  'aurorus2.png',
#  'avalugg0.png',
#  'avalugg1.png',
#  'avalugg2.png',
#  'axew0.png',
#  'axew1.png',
#  'axew2.png',
#  'azelf0.png',
#  'azelf1.png',
#  'azelf2.png',
#  'azumarill0.png',
#  'azumarill1.png',
#  'azumarill2.png',
#  'azurill0.png',
#  'azurill1.png',
#  'azurill2.png',
#  'bagon0.png',
#  'bagon1.png',
#  'bagon2.png',
#  'baltoy0.png',
#  'baltoy1.png',
#  'baltoy2.png',
#  'banette0.png',
#  'banette1.png',
#  'banette2.png',
#  'barbaracle0.png',
#  'barbaracle1.png',
#  'barbaracle2.png',
#  'barboach0.png',
#  'barboach1.png',
#  'barboach2.png',
#  'basculin-red-striped0.png',
#  'basculin-red-striped1.png',
#  'basculin-red-striped2.png',
#  'bastiodon0.png',
#  'bastiodon1.png',
#  'bastiodon2.png',
#  'bayleef0.png',
#  'bayleef1.png',
#  'bayleef2.png',
#  'beartic0.png',
#  'beartic1.png',
#  'beartic2.png',
#  'beautifly0.png',
#  'beautifly1.png',
#  'beautifly2.png',
#  'beedrill0.png',
#  'beedrill1.png',
#  'beedrill2.png',
#  'beheeyem0.png',
#  'beheeyem1.png',
#  'beheeyem2.png',
#  'beldum0.png',
#  'beldum1.png',
#  'beldum2.png',
#  'bellossom0.png',
#  'bellossom1.png',
#  'bellossom2.png',
#  'bellsprout0.png',
#  'bellsprout1.png',
#  'bellsprout2.png',
#  'bergmite0.png',
#  'bergmite1.png',
#  'bergmite2.png',
#  'bewear0.png',
#  'bewear1.png',
#  'bewear2.png',
#  'bibarel0.png',
#  'bibarel1.png',
#  'bibarel2.png',
#  'bidoof0.png',
#  'bidoof1.png',
#  'bidoof2.png',
#  'binacle0.png',
#  'binacle1.png',
#  'binacle2.png',
#  'bisharp0.png',
#  'bisharp1.png',
#  'bisharp2.png',
#  'blacephalon0.png',
#  'blacephalon1.png',
#  'blacephalon2.png',
#  'blastoise0.png',
#  'blastoise1.png',
#  'blastoise2.png',
#  'blaziken0.png',
#  'blaziken1.png',
#  'blaziken2.png',
#  'blissey0.png',
#  'blissey1.png',
#  'blissey2.png',
#  'blitzle0.png',
#  'blitzle1.png',
#  'blitzle2.png',
#  'boldore0.png',
#  'boldore1.png',
#  'boldore2.png',
#  'bonsly0.png',
#  'bonsly1.png',
#  'bonsly2.png',
#  'bouffalant0.png',
#  'bouffalant1.png',
#  'bouffalant2.png',
#  'bounsweet0.png',
#  'bounsweet1.png',
#  'bounsweet2.png',
#  'braixen0.png',
#  'braixen1.png',
#  'braixen2.png',
#  'braviary0.png',
#  'braviary1.png',
#  'braviary2.png',
#  'breloom0.png',
#  'breloom1.png',
#  'breloom2.png',
#  'brionne0.png',
#  'brionne1.png',
#  'brionne2.png',
#  'bronzong0.png',
#  'bronzong1.png',
#  'bronzong2.png',
#  'bronzor0.png',
#  'bronzor1.png',
#  'bronzor2.png',
#  'bruxish0.png',
#  'bruxish1.png',
#  'bruxish2.png',
#  'budew0.png',
#  'budew1.png',
#  'budew2.png',
#  'buizel0.png',
#  'buizel1.png',
#  'buizel2.png',
#  'bulbasaur0.png',
#  'bulbasaur1.png',
#  'bulbasaur2.png',
#  'buneary0.png',
#  'buneary1.png',
#  'buneary2.png',
#  'bunnelby0.png',
#  'bunnelby1.png',
#  'bunnelby2.png',
#  'burmy0.png',
#  'burmy1.png',
#  'burmy2.png',
#  'butterfree0.png',
#  'butterfree1.png',
#  'butterfree2.png',
#  'buzzwole0.png',
#  'buzzwole1.png',
#  'buzzwole2.png',
#  'cacnea0.png',
#  'cacnea1.png',
#  'cacnea2.png',
#  'cacturne0.png',
#  'cacturne1.png',
#  'cacturne2.png',
#  'camerupt0.png',
#  'camerupt1.png',
#  'camerupt2.png',
#  'carbink0.png',
#  'carbink1.png',
#  'carbink2.png',
#  'carnivine0.png',
#  'carnivine1.png',
#  'carnivine2.png',
#  'carracosta0.png',
#  'carracosta1.png',
#  'carracosta2.png',
#  'carvanha0.png',
#  'carvanha1.png',
#  'carvanha2.png',
#  'cascoon0.png',
#  'cascoon1.png',
#  'cascoon2.png',
#  'castform0.png',
#  'castform1.png',
#  'castform2.png',
#  'caterpie0.png',
#  'caterpie1.png',
#  'caterpie2.png',
#  'celebi0.png',
#  'celebi1.png',
#  'celebi2.png',
#  'celesteela0.png',
#  'celesteela1.png',
#  'celesteela2.png',
#  'chandelure0.png',
#  'chandelure1.png',
#  'chandelure2.png',
#  'chansey0.png',
#  'chansey1.png',
#  'chansey2.png',
#  'charizard0.png',
#  'charizard1.png',
#  'charizard2.png',
#  'charjabug0.png',
#  'charjabug1.png',
#  'charjabug2.png',
#  'charmander0.png',
#  'charmander1.png',
#  'charmander2.png',
#  'charmeleon0.png',
#  'charmeleon1.png',
#  'charmeleon2.png',
#  'chatot0.png',
#  'chatot1.png',
#  'chatot2.png',
#  'cherrim0.png',
#  'cherrim1.png',
#  'cherrim2.png',
#  'cherubi0.png',
#  'cherubi1.png',
#  'cherubi2.png',
#  'chesnaught0.png',
#  'chesnaught1.png',
#  'chesnaught2.png',
#  'chespin0.png',
#  'chespin1.png',
#  'chespin2.png',
#  'chikorita0.png',
#  'chikorita1.png',
#  'chikorita2.png',
#  'chimchar0.png',
#  'chimchar1.png',
#  'chimchar2.png',
#  'chimecho0.png',
#  'chimecho1.png',
#  'chimecho2.png',
#  'chinchou0.png',
#  'chinchou1.png',
#  'chinchou2.png',
#  'chingling0.png',
#  'chingling1.png',
#  'chingling2.png',
#  'cinccino0.png',
#  'cinccino1.png',
#  'cinccino2.png',
#  'clamperl0.png',
#  'clamperl1.png',
#  'clamperl2.png',
#  'clauncher0.png',
#  'clauncher1.png',
#  'clauncher2.png',
#  'clawitzer0.png',
#  'clawitzer1.png',
#  'clawitzer2.png',
#  'claydol0.png',
#  'claydol1.png',
#  'claydol2.png',
#  'clefable0.png',
#  'clefable1.png',
#  'clefable2.png',
#  'clefairy0.png',
#  'clefairy1.png',
#  'clefairy2.png',
#  'cleffa0.png',
#  'cleffa1.png',
#  'cleffa2.png',
#  'cloyster0.png',
#  'cloyster1.png',
#  'cloyster2.png',
#  'cobalion0.png',
#  'cobalion1.png',
#  'cobalion2.png',
#  'cofagrigus0.png',
#  'cofagrigus1.png',
#  'cofagrigus2.png',
#  'combee0.png',
#  'combee1.png',
#  'combee2.png',
#  'combusken0.png',
#  'combusken1.png',
#  'combusken2.png',
#  'comfey0.png',
#  'comfey1.png',
#  'comfey2.png',
#  'conkeldurr0.png',
#  'conkeldurr1.png',
#  'conkeldurr2.png',
#  'corphish0.png',
#  'corphish1.png',
#  'corphish2.png',
#  'corsola0.png',
#  'corsola1.png',
#  'corsola2.png',
#  'cosmoem0.png',
#  'cosmoem1.png',
#  'cosmoem2.png',
#  'cosmog0.png',
#  'cosmog1.png',
#  'cosmog2.png',
#  'cottonee0.png',
#  'cottonee1.png',
#  'cottonee2.png',
#  'crabominable0.png',
#  'crabominable1.png',
#  'crabominable2.png',
#  'crabrawler0.png',
#  'crabrawler1.png',
#  'crabrawler2.png',
#  'cradily0.png',
#  'cradily1.png',
#  'cradily2.png',
#  'cranidos0.png',
#  'cranidos1.png',
#  'cranidos2.png',
#  'crawdaunt0.png',
#  'crawdaunt1.png',
#  'crawdaunt2.png',
#  'cresselia0.png',
#  'cresselia1.png',
#  'cresselia2.png',
#  'croagunk0.png',
#  'croagunk1.png',
#  'croagunk2.png',
#  'crobat0.png',
#  'crobat1.png',
#  'crobat2.png',
#  'croconaw0.png',
#  'croconaw1.png',
#  'croconaw2.png',
#  'crustle0.png',
#  'crustle1.png',
#  'crustle2.png',
#  'cryogonal0.png',
#  'cryogonal1.png',
#  'cryogonal2.png',
#  'cubchoo0.png',
#  'cubchoo1.png',
#  'cubchoo2.png',
#  'cubone0.png',
#  'cubone1.png',
#  'cubone2.png',
#  'cutiefly0.png',
#  'cutiefly1.png',
#  'cutiefly2.png',
#  'cyndaquil0.png',
#  'cyndaquil1.png',
#  'cyndaquil2.png',
#  'darkrai0.png',
#  'darkrai1.png',
#  'darkrai2.png',
#  'darmanitan-standard0.png',
#  'darmanitan-standard1.png',
#  'darmanitan-standard2.png',
#  'dartrix0.png',
#  'dartrix1.png',
#  'dartrix2.png',
#  'darumaka0.png',
#  'darumaka1.png',
#  'darumaka2.png',
#  'decidueye0.png',
#  'decidueye1.png',
#  'decidueye2.png',
#  'dedenne0.png',
#  'dedenne1.png',
#  'dedenne2.png',
#  'deerling0.png',
#  'deerling1.png',
#  'deerling2.png',
#  'deino0.png',
#  'deino1.png',
#  'deino2.png',
#  'delcatty0.png',
#  'delcatty1.png',
#  'delcatty2.png',
#  'delibird0.png',
#  'delibird1.png',
#  'delibird2.png',
#  'delphox0.png',
#  'delphox1.png',
#  'delphox2.png',
#  'deoxys-normal0.png',
#  'deoxys-normal1.png',
#  'deoxys-normal2.png',
#  'dewgong0.png',
#  'dewgong1.png',
#  'dewgong2.png',
#  'dewott0.png',
#  'dewott1.png',
#  'dewott2.png',
#  'dewpider0.png',
#  'dewpider1.png',
#  'dewpider2.png',
#  'dhelmise0.png',
#  'dhelmise1.png',
#  'dhelmise2.png',
#  'dialga0.png',
#  'dialga1.png',
#  'dialga2.png',
#  'diancie0.png',
#  'diancie1.png',
#  'diancie2.png',
#  'diggersby0.png',
#  'diggersby1.png',
#  'diggersby2.png',
#  'diglett0.png',
#  'diglett1.png',
#  'diglett2.png',
#  'ditto0.png',
#  'ditto1.png',
#  'ditto2.png',
#  'dodrio0.png',
#  'dodrio1.png',
#  'dodrio2.png',
#  'doduo0.png',
#  'doduo1.png',
#  'doduo2.png',
#  'donphan0.png',
#  'donphan1.png',
#  'donphan2.png',
#  'doublade0.png',
#  'doublade1.png',
#  'doublade2.png',
#  'dragalge0.png',
#  'dragalge1.png',
#  'dragalge2.png',
#  'dragonair0.png',
#  'dragonair1.png',
#  'dragonair2.png',
#  'dragonite0.png',
#  'dragonite1.png',
#  'dragonite2.png',
#  'drampa0.png',
#  'drampa1.png',
#  'drampa2.png',
#  'drapion0.png',
#  'drapion1.png',
#  'drapion2.png',
#  'dratini0.png',
#  'dratini1.png',
#  'dratini2.png',
#  'drifblim0.png',
#  'drifblim1.png',
#  'drifblim2.png',
#  'drifloon0.png',
#  'drifloon1.png',
#  'drifloon2.png',
#  'drilbur0.png',
#  'drilbur1.png',
#  'drilbur2.png',
#  'drowzee0.png',
#  'drowzee1.png',
#  'drowzee2.png',
#  'druddigon0.png',
#  'druddigon1.png',
#  'druddigon2.png',
#  'ducklett0.png',
#  'ducklett1.png',
#  'ducklett2.png',
#  'dugtrio0.png',
#  'dugtrio1.png',
#  'dugtrio2.png',
#  'dunsparce0.png',
#  'dunsparce1.png',
#  'dunsparce2.png',
#  'duosion0.png',
#  'duosion1.png',
#  'duosion2.png',
#  'durant0.png',
#  'durant1.png',
#  'durant2.png',
#  'dusclops0.png',
#  'dusclops1.png',
#  'dusclops2.png',
#  'dusknoir0.png',
#  'dusknoir1.png',
#  'dusknoir2.png',
#  'duskull0.png',
#  'duskull1.png',
#  'duskull2.png',
#  'dustox0.png',
#  'dustox1.png',
#  'dustox2.png',
#  'dwebble0.png',
#  'dwebble1.png',
#  'dwebble2.png',
#  'eelektrik0.png',
#  'eelektrik1.png',
#  'eelektrik2.png',
#  'eelektross0.png',
#  'eelektross1.png',
#  'eelektross2.png',
#  'eevee0.png',
#  'eevee1.png',
#  'eevee2.png',
#  'ekans0.png',
#  'ekans1.png',
#  'ekans2.png',
#  'electabuzz0.png',
#  'electabuzz1.png',
#  'electabuzz2.png',
#  'electivire0.png',
#  'electivire1.png',
#  'electivire2.png',
#  'electrike0.png',
#  'electrike1.png',
#  'electrike2.png',
#  'electrode0.png',
#  'electrode1.png',
#  'electrode2.png',
#  'elekid0.png',
#  'elekid1.png',
#  'elekid2.png',
#  'elgyem0.png',
#  'elgyem1.png',
#  'elgyem2.png',
#  'emboar0.png',
#  'emboar1.png',
#  'emboar2.png',
#  'emolga0.png',
#  'emolga1.png',
#  'emolga2.png',
#  'empoleon0.png',
#  'empoleon1.png',
#  'empoleon2.png',
#  'entei0.png',
#  'entei1.png',
#  'entei2.png',
#  'escavalier0.png',
#  'escavalier1.png',
#  'escavalier2.png',
#  'espeon0.png',
#  'espeon1.png',
#  'espeon2.png',
#  'espurr0.png',
#  'espurr1.png',
#  'espurr2.png',
#  'excadrill0.png',
#  'excadrill1.png',
#  'excadrill2.png',
#  'exeggcute0.png',
#  'exeggcute1.png',
#  'exeggcute2.png',
#  'exeggutor0.png',
#  'exeggutor1.png',
#  'exeggutor2.png',
#  'exploud0.png',
#  'exploud1.png',
#  'exploud2.png',
#  'farfetchd0.png',
#  'farfetchd1.png',
#  'farfetchd2.png',
#  'fearow0.png',
#  'fearow1.png',
#  'fearow2.png',
#  'feebas0.png',
#  'feebas1.png',
#  'feebas2.png',
#  'fennekin0.png',
#  'fennekin1.png',
#  'fennekin2.png',
#  'feraligatr0.png',
#  'feraligatr1.png',
#  'feraligatr2.png',
#  'ferroseed0.png',
#  'ferroseed1.png',
#  'ferroseed2.png',
#  'ferrothorn0.png',
#  'ferrothorn1.png',
#  'ferrothorn2.png',
#  'finneon0.png',
#  'finneon1.png',
#  'finneon2.png',
#  'flaaffy0.png',
#  'flaaffy1.png',
#  'flaaffy2.png',
#  'flabebe0.png',
#  'flabebe1.png',
#  'flabebe2.png',
#  'flareon0.png',
#  'flareon1.png',
#  'flareon2.png',
#  'fletchinder0.png',
#  'fletchinder1.png',
#  'fletchinder2.png',
#  'fletchling0.png',
#  'fletchling1.png',
#  'fletchling2.png',
#  'floatzel0.png',
#  'floatzel1.png',
#  'floatzel2.png',
#  'floette0.png',
#  'floette1.png',
#  'floette2.png',
#  'florges0.png',
#  'florges1.png',
#  'florges2.png',
#  'flygon0.png',
#  'flygon1.png',
#  'flygon2.png',
#  'fomantis0.png',
#  'fomantis1.png',
#  'fomantis2.png',
#  'foongus0.png',
#  'foongus1.png',
#  'foongus2.png',
#  'forretress0.png',
#  'forretress1.png',
#  'forretress2.png',
#  'fraxure0.png',
#  'fraxure1.png',
#  'fraxure2.png',
#  'frillish0.png',
#  'frillish1.png',
#  'frillish2.png',
#  'froakie0.png',
#  'froakie1.png',
#  'froakie2.png',
#  'frogadier0.png',
#  'frogadier1.png',
#  'frogadier2.png',
#  'froslass0.png',
#  'froslass1.png',
#  'froslass2.png',
#  'furfrou0.png',
#  'furfrou1.png',
#  'furfrou2.png',
#  'furret0.png',
#  'furret1.png',
#  'furret2.png',
#  'gabite0.png',
#  'gabite1.png',
#  'gabite2.png',
#  'gallade0.png',
#  'gallade1.png',
#  'gallade2.png',
#  'galvantula0.png',
#  'galvantula1.png',
#  'galvantula2.png',
#  'garbodor0.png',
#  'garbodor1.png',
#  'garbodor2.png',
#  'garchomp0.png',
#  'garchomp1.png',
#  'garchomp2.png',
#  'gardevoir0.png',
#  'gardevoir1.png',
#  'gardevoir2.png',
#  'gastly0.png',
#  'gastly1.png',
#  'gastly2.png',
#  'gastrodon0.png',
#  'gastrodon1.png',
#  'gastrodon2.png',
#  'genesect0.png',
#  'genesect1.png',
#  'genesect2.png',
#  'gengar0.png',
#  'gengar1.png',
#  'gengar2.png',
#  'geodude0.png',
#  'geodude1.png',
#  'geodude2.png',
#  'gible0.png',
#  'gible1.png',
#  'gible2.png',
#  'gigalith0.png',
#  'gigalith1.png',
#  'gigalith2.png',
#  'girafarig0.png',
#  'girafarig1.png',
#  'girafarig2.png',
#  'giratina-altered0.png',
#  'giratina-altered1.png',
#  'giratina-altered2.png',
#  'glaceon0.png',
#  'glaceon1.png',
#  'glaceon2.png',
#  'glalie0.png',
#  'glalie1.png',
#  'glalie2.png',
#  'glameow0.png',
#  'glameow1.png',
#  'glameow2.png',
#  'gligar0.png',
#  'gligar1.png',
#  'gligar2.png',
#  'gliscor0.png',
#  'gliscor1.png',
#  'gliscor2.png',
#  'gloom0.png',
#  'gloom1.png',
#  'gloom2.png',
#  'gogoat0.png',
#  'gogoat1.png',
#  'gogoat2.png',
#  'golbat0.png',
#  'golbat1.png',
#  'golbat2.png',
#  'goldeen0.png',
#  'goldeen1.png',
#  'goldeen2.png',
#  'golduck0.png',
#  'golduck1.png',
#  'golduck2.png',
#  'golem0.png',
#  'golem1.png',
#  'golem2.png',
#  'golett0.png',
#  'golett1.png',
#  'golett2.png',
#  'golisopod0.png',
#  'golisopod1.png',
#  'golisopod2.png',
#  'golurk0.png',
#  'golurk1.png',
#  'golurk2.png',
#  'goodra0.png',
#  'goodra1.png',
#  'goodra2.png',
#  'goomy0.png',
#  'goomy1.png',
#  'goomy2.png',
#  'gorebyss0.png',
#  'gorebyss1.png',
#  'gorebyss2.png',
#  'gothita0.png',
#  'gothita1.png',
#  'gothita2.png',
#  'gothitelle0.png',
#  'gothitelle1.png',
#  'gothitelle2.png',
#  'gothorita0.png',
#  'gothorita1.png',
#  'gothorita2.png',
#  'gourgeist-average0.png',
#  'gourgeist-average1.png',
#  'gourgeist-average2.png',
#  'granbull0.png',
#  'granbull1.png',
#  'granbull2.png',
#  'graveler0.png',
#  'graveler1.png',
#  'graveler2.png',
#  'greninja0.png',
#  'greninja1.png',
#  'greninja2.png',
#  'grimer0.png',
#  'grimer1.png',
#  'grimer2.png',
#  'grotle0.png',
#  'grotle1.png',
#  'grotle2.png',
#  'groudon0.png',
#  'groudon1.png',
#  'groudon2.png',
#  'grovyle0.png',
#  'grovyle1.png',
#  'grovyle2.png',
#  'growlithe0.png',
#  'growlithe1.png',
#  'growlithe2.png',
#  'grubbin0.png',
#  'grubbin1.png',
#  'grubbin2.png',
#  'grumpig0.png',
#  'grumpig1.png',
#  'grumpig2.png',
#  'gulpin0.png',
#  'gulpin1.png',
#  'gulpin2.png',
#  'gumshoos0.png',
#  'gumshoos1.png',
#  'gumshoos2.png',
#  'gurdurr0.png',
#  'gurdurr1.png',
#  'gurdurr2.png',
#  'guzzlord0.png',
#  'guzzlord1.png',
#  'guzzlord2.png',
#  'gyarados0.png',
#  'gyarados1.png',
#  'gyarados2.png',
#  'hakamo-o0.png',
#  'hakamo-o1.png',
#  'hakamo-o2.png',
#  'happiny0.png',
#  'happiny1.png',
#  'happiny2.png',
#  'hariyama0.png',
#  'hariyama1.png',
#  'hariyama2.png',
#  'haunter0.png',
#  'haunter1.png',
#  'haunter2.png',
#  'hawlucha0.png',
#  'hawlucha1.png',
#  'hawlucha2.png',
#  'haxorus0.png',
#  'haxorus1.png',
#  'haxorus2.png',
#  'heatmor0.png',
#  'heatmor1.png',
#  'heatmor2.png',
#  'heatran0.png',
#  'heatran1.png',
#  'heatran2.png',
#  'heliolisk0.png',
#  'heliolisk1.png',
#  'heliolisk2.png',
#  'helioptile0.png',
#  'helioptile1.png',
#  'helioptile2.png',
#  'heracross0.png',
#  'heracross1.png',
#  'heracross2.png',
#  'herdier0.png',
#  'herdier1.png',
#  'herdier2.png',
#  'hippopotas0.png',
#  'hippopotas1.png',
#  'hippopotas2.png',
#  'hippowdon0.png',
#  'hippowdon1.png',
#  'hippowdon2.png',
#  'hitmonchan0.png',
#  'hitmonchan1.png',
#  'hitmonchan2.png',
#  'hitmonlee0.png',
#  'hitmonlee1.png',
#  'hitmonlee2.png',
#  'hitmontop0.png',
#  'hitmontop1.png',
#  'hitmontop2.png',
#  'ho-oh0.png',
#  'ho-oh1.png',
#  'ho-oh2.png',
#  'honchkrow0.png',
#  'honchkrow1.png',
#  'honchkrow2.png',
#  'honedge0.png',
#  'honedge1.png',
#  'honedge2.png',
#  'hoopa-confined0.png',
#  'hoopa-confined1.png',
#  'hoopa-confined2.png',
#  'hoothoot0.png',
#  'hoothoot1.png',
#  'hoothoot2.png',
#  'hoppip0.png',
#  'hoppip1.png',
#  'hoppip2.png',
#  'horsea0.png',
#  'horsea1.png',
#  'horsea2.png',
#  'houndoom0.png',
#  'houndoom1.png',
#  'houndoom2.png',
#  'houndour0.png',
#  'houndour1.png',
#  'houndour2.png',
#  'huntail0.png',
#  'huntail1.png',
#  'huntail2.png',
#  'hydreigon0.png',
#  'hydreigon1.png',
#  'hydreigon2.png',
#  'hypno0.png',
#  'hypno1.png',
#  'hypno2.png',
#  'igglybuff0.png',
#  'igglybuff1.png',
#  'igglybuff2.png',
#  'illumise0.png',
#  'illumise1.png',
#  'illumise2.png',
#  'incineroar0.png',
#  'incineroar1.png',
#  'incineroar2.png',
#  'infernape0.png',
#  'infernape1.png',
#  'infernape2.png',
#  'inkay0.png',
#  'inkay1.png',
#  'inkay2.png',
#  'ivysaur0.png',
#  'ivysaur1.png',
#  'ivysaur2.png',
#  'jangmo-o0.png',
#  'jangmo-o1.png',
#  'jangmo-o2.png',
#  'jellicent0.png',
#  'jellicent1.png',
#  'jellicent2.png',
#  'jigglypuff0.png',
#  'jigglypuff1.png',
#  'jigglypuff2.png',
#  'jirachi0.png',
#  'jirachi1.png',
#  'jirachi2.png',
#  'jolteon0.png',
#  'jolteon1.png',
#  'jolteon2.png',
#  'joltik0.png',
#  'joltik1.png',
#  'joltik2.png',
#  'jumpluff0.png',
#  'jumpluff1.png',
#  'jumpluff2.png',
#  'jynx0.png',
#  'jynx1.png',
#  'jynx2.png',
#  'kabuto0.png',
#  'kabuto1.png',
#  'kabuto2.png',
#  'kabutops0.png',
#  'kabutops1.png',
#  'kabutops2.png',
#  'kadabra0.png',
#  'kadabra1.png',
#  'kadabra2.png',
#  'kakuna0.png',
#  ...]

# %%
cat
# Out:
# ['abomasnow',
#  'abomasnow',
#  'abomasnow',
#  'abra',
#  'abra',
#  'abra',
#  'absol',
#  'absol',
#  'absol',
#  'accelgor',
#  'accelgor',
#  'accelgor',
#  'aegislash-blade',
#  'aegislash-blade',
#  'aegislash-blade',
#  'aerodactyl',
#  'aerodactyl',
#  'aerodactyl',
#  'aggron',
#  'aggron',
#  'aggron',
#  'aipom',
#  'aipom',
#  'aipom',
#  'alakazam',
#  'alakazam',
#  'alakazam',
#  'alomomola',
#  'alomomola',
#  'alomomola',
#  'altaria',
#  'altaria',
#  'altaria',
#  'amaura',
#  'amaura',
#  'amaura',
#  'ambipom',
#  'ambipom',
#  'ambipom',
#  'amoonguss',
#  'amoonguss',
#  'amoonguss',
#  'ampharos',
#  'ampharos',
#  'ampharos',
#  'anorith',
#  'anorith',
#  'anorith',
#  'araquanid',
#  'araquanid',
#  'araquanid',
#  'arbok',
#  'arbok',
#  'arbok',
#  'arcanine',
#  'arcanine',
#  'arcanine',
#  'arceus',
#  'arceus',
#  'arceus',
#  'archen',
#  'archen',
#  'archen',
#  'archeops',
#  'archeops',
#  'archeops',
#  'ariados',
#  'ariados',
#  'ariados',
#  'armaldo',
#  'armaldo',
#  'armaldo',
#  'aromatisse',
#  'aromatisse',
#  'aromatisse',
#  'aron',
#  'aron',
#  'aron',
#  'articuno',
#  'articuno',
#  'articuno',
#  'audino',
#  'audino',
#  'audino',
#  'aurorus',
#  'aurorus',
#  'aurorus',
#  'avalugg',
#  'avalugg',
#  'avalugg',
#  'axew',
#  'axew',
#  'axew',
#  'azelf',
#  'azelf',
#  'azelf',
#  'azumarill',
#  'azumarill',
#  'azumarill',
#  'azurill',
#  'azurill',
#  'azurill',
#  'bagon',
#  'bagon',
#  'bagon',
#  'baltoy',
#  'baltoy',
#  'baltoy',
#  'banette',
#  'banette',
#  'banette',
#  'barbaracle',
#  'barbaracle',
#  'barbaracle',
#  'barboach',
#  'barboach',
#  'barboach',
#  'basculin-red-striped',
#  'basculin-red-striped',
#  'basculin-red-striped',
#  'bastiodon',
#  'bastiodon',
#  'bastiodon',
#  'bayleef',
#  'bayleef',
#  'bayleef',
#  'beartic',
#  'beartic',
#  'beartic',
#  'beautifly',
#  'beautifly',
#  'beautifly',
#  'beedrill',
#  'beedrill',
#  'beedrill',
#  'beheeyem',
#  'beheeyem',
#  'beheeyem',
#  'beldum',
#  'beldum',
#  'beldum',
#  'bellossom',
#  'bellossom',
#  'bellossom',
#  'bellsprout',
#  'bellsprout',
#  'bellsprout',
#  'bergmite',
#  'bergmite',
#  'bergmite',
#  'bewear',
#  'bewear',
#  'bewear',
#  'bibarel',
#  'bibarel',
#  'bibarel',
#  'bidoof',
#  'bidoof',
#  'bidoof',
#  'binacle',
#  'binacle',
#  'binacle',
#  'bisharp',
#  'bisharp',
#  'bisharp',
#  'blacephalon',
#  'blacephalon',
#  'blacephalon',
#  'blastoise',
#  'blastoise',
#  'blastoise',
#  'blaziken',
#  'blaziken',
#  'blaziken',
#  'blissey',
#  'blissey',
#  'blissey',
#  'blitzle',
#  'blitzle',
#  'blitzle',
#  'boldore',
#  'boldore',
#  'boldore',
#  'bonsly',
#  'bonsly',
#  'bonsly',
#  'bouffalant',
#  'bouffalant',
#  'bouffalant',
#  'bounsweet',
#  'bounsweet',
#  'bounsweet',
#  'braixen',
#  'braixen',
#  'braixen',
#  'braviary',
#  'braviary',
#  'braviary',
#  'breloom',
#  'breloom',
#  'breloom',
#  'brionne',
#  'brionne',
#  'brionne',
#  'bronzong',
#  'bronzong',
#  'bronzong',
#  'bronzor',
#  'bronzor',
#  'bronzor',
#  'bruxish',
#  'bruxish',
#  'bruxish',
#  'budew',
#  'budew',
#  'budew',
#  'buizel',
#  'buizel',
#  'buizel',
#  'bulbasaur',
#  'bulbasaur',
#  'bulbasaur',
#  'buneary',
#  'buneary',
#  'buneary',
#  'bunnelby',
#  'bunnelby',
#  'bunnelby',
#  'burmy',
#  'burmy',
#  'burmy',
#  'butterfree',
#  'butterfree',
#  'butterfree',
#  'buzzwole',
#  'buzzwole',
#  'buzzwole',
#  'cacnea',
#  'cacnea',
#  'cacnea',
#  'cacturne',
#  'cacturne',
#  'cacturne',
#  'camerupt',
#  'camerupt',
#  'camerupt',
#  'carbink',
#  'carbink',
#  'carbink',
#  'carnivine',
#  'carnivine',
#  'carnivine',
#  'carracosta',
#  'carracosta',
#  'carracosta',
#  'carvanha',
#  'carvanha',
#  'carvanha',
#  'cascoon',
#  'cascoon',
#  'cascoon',
#  'castform',
#  'castform',
#  'castform',
#  'caterpie',
#  'caterpie',
#  'caterpie',
#  'celebi',
#  'celebi',
#  'celebi',
#  'celesteela',
#  'celesteela',
#  'celesteela',
#  'chandelure',
#  'chandelure',
#  'chandelure',
#  'chansey',
#  'chansey',
#  'chansey',
#  'charizard',
#  'charizard',
#  'charizard',
#  'charjabug',
#  'charjabug',
#  'charjabug',
#  'charmander',
#  'charmander',
#  'charmander',
#  'charmeleon',
#  'charmeleon',
#  'charmeleon',
#  'chatot',
#  'chatot',
#  'chatot',
#  'cherrim',
#  'cherrim',
#  'cherrim',
#  'cherubi',
#  'cherubi',
#  'cherubi',
#  'chesnaught',
#  'chesnaught',
#  'chesnaught',
#  'chespin',
#  'chespin',
#  'chespin',
#  'chikorita',
#  'chikorita',
#  'chikorita',
#  'chimchar',
#  'chimchar',
#  'chimchar',
#  'chimecho',
#  'chimecho',
#  'chimecho',
#  'chinchou',
#  'chinchou',
#  'chinchou',
#  'chingling',
#  'chingling',
#  'chingling',
#  'cinccino',
#  'cinccino',
#  'cinccino',
#  'clamperl',
#  'clamperl',
#  'clamperl',
#  'clauncher',
#  'clauncher',
#  'clauncher',
#  'clawitzer',
#  'clawitzer',
#  'clawitzer',
#  'claydol',
#  'claydol',
#  'claydol',
#  'clefable',
#  'clefable',
#  'clefable',
#  'clefairy',
#  'clefairy',
#  'clefairy',
#  'cleffa',
#  'cleffa',
#  'cleffa',
#  'cloyster',
#  'cloyster',
#  'cloyster',
#  'cobalion',
#  'cobalion',
#  'cobalion',
#  'cofagrigus',
#  'cofagrigus',
#  'cofagrigus',
#  'combee',
#  'combee',
#  'combee',
#  'combusken',
#  'combusken',
#  'combusken',
#  'comfey',
#  'comfey',
#  'comfey',
#  'conkeldurr',
#  'conkeldurr',
#  'conkeldurr',
#  'corphish',
#  'corphish',
#  'corphish',
#  'corsola',
#  'corsola',
#  'corsola',
#  'cosmoem',
#  'cosmoem',
#  'cosmoem',
#  'cosmog',
#  'cosmog',
#  'cosmog',
#  'cottonee',
#  'cottonee',
#  'cottonee',
#  'crabominable',
#  'crabominable',
#  'crabominable',
#  'crabrawler',
#  'crabrawler',
#  'crabrawler',
#  'cradily',
#  'cradily',
#  'cradily',
#  'cranidos',
#  'cranidos',
#  'cranidos',
#  'crawdaunt',
#  'crawdaunt',
#  'crawdaunt',
#  'cresselia',
#  'cresselia',
#  'cresselia',
#  'croagunk',
#  'croagunk',
#  'croagunk',
#  'crobat',
#  'crobat',
#  'crobat',
#  'croconaw',
#  'croconaw',
#  'croconaw',
#  'crustle',
#  'crustle',
#  'crustle',
#  'cryogonal',
#  'cryogonal',
#  'cryogonal',
#  'cubchoo',
#  'cubchoo',
#  'cubchoo',
#  'cubone',
#  'cubone',
#  'cubone',
#  'cutiefly',
#  'cutiefly',
#  'cutiefly',
#  'cyndaquil',
#  'cyndaquil',
#  'cyndaquil',
#  'darkrai',
#  'darkrai',
#  'darkrai',
#  'darmanitan-standard',
#  'darmanitan-standard',
#  'darmanitan-standard',
#  'dartrix',
#  'dartrix',
#  'dartrix',
#  'darumaka',
#  'darumaka',
#  'darumaka',
#  'decidueye',
#  'decidueye',
#  'decidueye',
#  'dedenne',
#  'dedenne',
#  'dedenne',
#  'deerling',
#  'deerling',
#  'deerling',
#  'deino',
#  'deino',
#  'deino',
#  'delcatty',
#  'delcatty',
#  'delcatty',
#  'delibird',
#  'delibird',
#  'delibird',
#  'delphox',
#  'delphox',
#  'delphox',
#  'deoxys-normal',
#  'deoxys-normal',
#  'deoxys-normal',
#  'dewgong',
#  'dewgong',
#  'dewgong',
#  'dewott',
#  'dewott',
#  'dewott',
#  'dewpider',
#  'dewpider',
#  'dewpider',
#  'dhelmise',
#  'dhelmise',
#  'dhelmise',
#  'dialga',
#  'dialga',
#  'dialga',
#  'diancie',
#  'diancie',
#  'diancie',
#  'diggersby',
#  'diggersby',
#  'diggersby',
#  'diglett',
#  'diglett',
#  'diglett',
#  'ditto',
#  'ditto',
#  'ditto',
#  'dodrio',
#  'dodrio',
#  'dodrio',
#  'doduo',
#  'doduo',
#  'doduo',
#  'donphan',
#  'donphan',
#  'donphan',
#  'doublade',
#  'doublade',
#  'doublade',
#  'dragalge',
#  'dragalge',
#  'dragalge',
#  'dragonair',
#  'dragonair',
#  'dragonair',
#  'dragonite',
#  'dragonite',
#  'dragonite',
#  'drampa',
#  'drampa',
#  'drampa',
#  'drapion',
#  'drapion',
#  'drapion',
#  'dratini',
#  'dratini',
#  'dratini',
#  'drifblim',
#  'drifblim',
#  'drifblim',
#  'drifloon',
#  'drifloon',
#  'drifloon',
#  'drilbur',
#  'drilbur',
#  'drilbur',
#  'drowzee',
#  'drowzee',
#  'drowzee',
#  'druddigon',
#  'druddigon',
#  'druddigon',
#  'ducklett',
#  'ducklett',
#  'ducklett',
#  'dugtrio',
#  'dugtrio',
#  'dugtrio',
#  'dunsparce',
#  'dunsparce',
#  'dunsparce',
#  'duosion',
#  'duosion',
#  'duosion',
#  'durant',
#  'durant',
#  'durant',
#  'dusclops',
#  'dusclops',
#  'dusclops',
#  'dusknoir',
#  'dusknoir',
#  'dusknoir',
#  'duskull',
#  'duskull',
#  'duskull',
#  'dustox',
#  'dustox',
#  'dustox',
#  'dwebble',
#  'dwebble',
#  'dwebble',
#  'eelektrik',
#  'eelektrik',
#  'eelektrik',
#  'eelektross',
#  'eelektross',
#  'eelektross',
#  'eevee',
#  'eevee',
#  'eevee',
#  'ekans',
#  'ekans',
#  'ekans',
#  'electabuzz',
#  'electabuzz',
#  'electabuzz',
#  'electivire',
#  'electivire',
#  'electivire',
#  'electrike',
#  'electrike',
#  'electrike',
#  'electrode',
#  'electrode',
#  'electrode',
#  'elekid',
#  'elekid',
#  'elekid',
#  'elgyem',
#  'elgyem',
#  'elgyem',
#  'emboar',
#  'emboar',
#  'emboar',
#  'emolga',
#  'emolga',
#  'emolga',
#  'empoleon',
#  'empoleon',
#  'empoleon',
#  'entei',
#  'entei',
#  'entei',
#  'escavalier',
#  'escavalier',
#  'escavalier',
#  'espeon',
#  'espeon',
#  'espeon',
#  'espurr',
#  'espurr',
#  'espurr',
#  'excadrill',
#  'excadrill',
#  'excadrill',
#  'exeggcute',
#  'exeggcute',
#  'exeggcute',
#  'exeggutor',
#  'exeggutor',
#  'exeggutor',
#  'exploud',
#  'exploud',
#  'exploud',
#  'farfetchd',
#  'farfetchd',
#  'farfetchd',
#  'fearow',
#  'fearow',
#  'fearow',
#  'feebas',
#  'feebas',
#  'feebas',
#  'fennekin',
#  'fennekin',
#  'fennekin',
#  'feraligatr',
#  'feraligatr',
#  'feraligatr',
#  'ferroseed',
#  'ferroseed',
#  'ferroseed',
#  'ferrothorn',
#  'ferrothorn',
#  'ferrothorn',
#  'finneon',
#  'finneon',
#  'finneon',
#  'flaaffy',
#  'flaaffy',
#  'flaaffy',
#  'flabebe',
#  'flabebe',
#  'flabebe',
#  'flareon',
#  'flareon',
#  'flareon',
#  'fletchinder',
#  'fletchinder',
#  'fletchinder',
#  'fletchling',
#  'fletchling',
#  'fletchling',
#  'floatzel',
#  'floatzel',
#  'floatzel',
#  'floette',
#  'floette',
#  'floette',
#  'florges',
#  'florges',
#  'florges',
#  'flygon',
#  'flygon',
#  'flygon',
#  'fomantis',
#  'fomantis',
#  'fomantis',
#  'foongus',
#  'foongus',
#  'foongus',
#  'forretress',
#  'forretress',
#  'forretress',
#  'fraxure',
#  'fraxure',
#  'fraxure',
#  'frillish',
#  'frillish',
#  'frillish',
#  'froakie',
#  'froakie',
#  'froakie',
#  'frogadier',
#  'frogadier',
#  'frogadier',
#  'froslass',
#  'froslass',
#  'froslass',
#  'furfrou',
#  'furfrou',
#  'furfrou',
#  'furret',
#  'furret',
#  'furret',
#  'gabite',
#  'gabite',
#  'gabite',
#  'gallade',
#  'gallade',
#  'gallade',
#  'galvantula',
#  'galvantula',
#  'galvantula',
#  'garbodor',
#  'garbodor',
#  'garbodor',
#  'garchomp',
#  'garchomp',
#  'garchomp',
#  'gardevoir',
#  'gardevoir',
#  'gardevoir',
#  'gastly',
#  'gastly',
#  'gastly',
#  'gastrodon',
#  'gastrodon',
#  'gastrodon',
#  'genesect',
#  'genesect',
#  'genesect',
#  'gengar',
#  'gengar',
#  'gengar',
#  'geodude',
#  'geodude',
#  'geodude',
#  'gible',
#  'gible',
#  'gible',
#  'gigalith',
#  'gigalith',
#  'gigalith',
#  'girafarig',
#  'girafarig',
#  'girafarig',
#  'giratina-altered',
#  'giratina-altered',
#  'giratina-altered',
#  'glaceon',
#  'glaceon',
#  'glaceon',
#  'glalie',
#  'glalie',
#  'glalie',
#  'glameow',
#  'glameow',
#  'glameow',
#  'gligar',
#  'gligar',
#  'gligar',
#  'gliscor',
#  'gliscor',
#  'gliscor',
#  'gloom',
#  'gloom',
#  'gloom',
#  'gogoat',
#  'gogoat',
#  'gogoat',
#  'golbat',
#  'golbat',
#  'golbat',
#  'goldeen',
#  'goldeen',
#  'goldeen',
#  'golduck',
#  'golduck',
#  'golduck',
#  'golem',
#  'golem',
#  'golem',
#  'golett',
#  'golett',
#  'golett',
#  'golisopod',
#  'golisopod',
#  'golisopod',
#  'golurk',
#  'golurk',
#  'golurk',
#  'goodra',
#  'goodra',
#  'goodra',
#  'goomy',
#  'goomy',
#  'goomy',
#  'gorebyss',
#  'gorebyss',
#  'gorebyss',
#  'gothita',
#  'gothita',
#  'gothita',
#  'gothitelle',
#  'gothitelle',
#  'gothitelle',
#  'gothorita',
#  'gothorita',
#  'gothorita',
#  'gourgeist-average',
#  'gourgeist-average',
#  'gourgeist-average',
#  'granbull',
#  'granbull',
#  'granbull',
#  'graveler',
#  'graveler',
#  'graveler',
#  'greninja',
#  'greninja',
#  'greninja',
#  'grimer',
#  'grimer',
#  'grimer',
#  'grotle',
#  'grotle',
#  'grotle',
#  'groudon',
#  'groudon',
#  'groudon',
#  'grovyle',
#  'grovyle',
#  'grovyle',
#  'growlithe',
#  'growlithe',
#  'growlithe',
#  'grubbin',
#  'grubbin',
#  'grubbin',
#  'grumpig',
#  'grumpig',
#  'grumpig',
#  'gulpin',
#  'gulpin',
#  'gulpin',
#  'gumshoos',
#  'gumshoos',
#  'gumshoos',
#  'gurdurr',
#  'gurdurr',
#  'gurdurr',
#  'guzzlord',
#  'guzzlord',
#  'guzzlord',
#  'gyarados',
#  'gyarados',
#  'gyarados',
#  'hakamo-o',
#  'hakamo-o',
#  'hakamo-o',
#  'happiny',
#  'happiny',
#  'happiny',
#  'hariyama',
#  'hariyama',
#  'hariyama',
#  'haunter',
#  'haunter',
#  'haunter',
#  'hawlucha',
#  'hawlucha',
#  'hawlucha',
#  'haxorus',
#  'haxorus',
#  'haxorus',
#  'heatmor',
#  'heatmor',
#  'heatmor',
#  'heatran',
#  'heatran',
#  'heatran',
#  'heliolisk',
#  'heliolisk',
#  'heliolisk',
#  'helioptile',
#  'helioptile',
#  'helioptile',
#  'heracross',
#  'heracross',
#  'heracross',
#  'herdier',
#  'herdier',
#  'herdier',
#  'hippopotas',
#  'hippopotas',
#  'hippopotas',
#  'hippowdon',
#  'hippowdon',
#  'hippowdon',
#  'hitmonchan',
#  'hitmonchan',
#  'hitmonchan',
#  'hitmonlee',
#  'hitmonlee',
#  'hitmonlee',
#  'hitmontop',
#  'hitmontop',
#  'hitmontop',
#  'ho-oh',
#  'ho-oh',
#  'ho-oh',
#  'honchkrow',
#  'honchkrow',
#  'honchkrow',
#  'honedge',
#  'honedge',
#  'honedge',
#  'hoopa-confined',
#  'hoopa-confined',
#  'hoopa-confined',
#  'hoothoot',
#  'hoothoot',
#  'hoothoot',
#  'hoppip',
#  'hoppip',
#  'hoppip',
#  'horsea',
#  'horsea',
#  'horsea',
#  'houndoom',
#  'houndoom',
#  'houndoom',
#  'houndour',
#  'houndour',
#  'houndour',
#  'huntail',
#  'huntail',
#  'huntail',
#  'hydreigon',
#  'hydreigon',
#  'hydreigon',
#  'hypno',
#  'hypno',
#  'hypno',
#  'igglybuff',
#  'igglybuff',
#  'igglybuff',
#  'illumise',
#  'illumise',
#  'illumise',
#  'incineroar',
#  'incineroar',
#  'incineroar',
#  'infernape',
#  'infernape',
#  'infernape',
#  'inkay',
#  'inkay',
#  'inkay',
#  'ivysaur',
#  'ivysaur',
#  'ivysaur',
#  'jangmo-o',
#  'jangmo-o',
#  'jangmo-o',
#  'jellicent',
#  'jellicent',
#  'jellicent',
#  'jigglypuff',
#  'jigglypuff',
#  'jigglypuff',
#  'jirachi',
#  'jirachi',
#  'jirachi',
#  'jolteon',
#  'jolteon',
#  'jolteon',
#  'joltik',
#  'joltik',
#  'joltik',
#  'jumpluff',
#  'jumpluff',
#  'jumpluff',
#  'jynx',
#  'jynx',
#  'jynx',
#  'kabuto',
#  'kabuto',
#  'kabuto',
#  'kabutops',
#  'kabutops',
#  'kabutops',
#  'kadabra',
#  'kadabra',
#  'kadabra',
#  'kakuna',
#  ...]

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'filename': filenames,
    'category': cat
})

# %%
df
# Out:
#              filename    category
# 0      abomasnow0.png   abomasnow
# 1      abomasnow1.png   abomasnow
# 2      abomasnow2.png   abomasnow
# 3           abra0.png        abra
# 4           abra1.png        abra
# ...               ...         ...
# 2422    zweilous1.png    zweilous
# 2423    zweilous2.png    zweilous
# 2424  zygarde-500.png  zygarde-50
# 2425  zygarde-501.png  zygarde-50
# 2426  zygarde-502.png  zygarde-50
#
# [2427 rows x 2 columns]

# %%
df['category'].value_counts().plot.bar()
# Out:
# <AxesSubplot: >

# %%
sample=filenames[0]
catt=cat[0]
path = os.path.join(curr,catt)
path = os.path.join(path,sample)
image = load_img(path)
plt.imshow(image)

# %%
from keras.utils import load_img
import random

# %%
print(len(categories))
# Out:
# 809

# %%
os.listdir()
# Out:
# ['abomasnow',
#  'abra',
#  'absol',
#  'accelgor',
#  'aegislash-blade',
#  'aerodactyl',
#  'aggron',
#  'aipom',
#  'alakazam',
#  'alomomola',
#  'altaria',
#  'amaura',
#  'ambipom',
#  'amoonguss',
#  'ampharos',
#  'anorith',
#  'araquanid',
#  'arbok',
#  'arcanine',
#  'arceus',
#  'archen',
#  'archeops',
#  'ariados',
#  'armaldo',
#  'aromatisse',
#  'aron',
#  'articuno',
#  'audino',
#  'aurorus',
#  'avalugg',
#  'axew',
#  'azelf',
#  'azumarill',
#  'azurill',
#  'bagon',
#  'baltoy',
#  'banette',
#  'barbaracle',
#  'barboach',
#  'basculin-red-striped',
#  'bastiodon',
#  'bayleef',
#  'beartic',
#  'beautifly',
#  'beedrill',
#  'beheeyem',
#  'beldum',
#  'bellossom',
#  'bellsprout',
#  'bergmite',
#  'bewear',
#  'bibarel',
#  'bidoof',
#  'binacle',
#  'bisharp',
#  'blacephalon',
#  'blastoise',
#  'blaziken',
#  'blissey',
#  'blitzle',
#  'boldore',
#  'bonsly',
#  'bouffalant',
#  'bounsweet',
#  'braixen',
#  'braviary',
#  'breloom',
#  'brionne',
#  'bronzong',
#  'bronzor',
#  'bruxish',
#  'budew',
#  'buizel',
#  'bulbasaur',
#  'buneary',
#  'bunnelby',
#  'burmy',
#  'butterfree',
#  'buzzwole',
#  'cacnea',
#  'cacturne',
#  'camerupt',
#  'carbink',
#  'carnivine',
#  'carracosta',
#  'carvanha',
#  'cascoon',
#  'castform',
#  'caterpie',
#  'celebi',
#  'celesteela',
#  'chandelure',
#  'chansey',
#  'charizard',
#  'charjabug',
#  'charmander',
#  'charmeleon',
#  'chatot',
#  'cherrim',
#  'cherubi',
#  'chesnaught',
#  'chespin',
#  'chikorita',
#  'chimchar',
#  'chimecho',
#  'chinchou',
#  'chingling',
#  'cinccino',
#  'clamperl',
#  'clauncher',
#  'clawitzer',
#  'claydol',
#  'clefable',
#  'clefairy',
#  'cleffa',
#  'cloyster',
#  'cobalion',
#  'cofagrigus',
#  'combee',
#  'combusken',
#  'comfey',
#  'conkeldurr',
#  'corphish',
#  'corsola',
#  'cosmoem',
#  'cosmog',
#  'cottonee',
#  'crabominable',
#  'crabrawler',
#  'cradily',
#  'cranidos',
#  'crawdaunt',
#  'cresselia',
#  'croagunk',
#  'crobat',
#  'croconaw',
#  'crustle',
#  'cryogonal',
#  'cubchoo',
#  'cubone',
#  'cutiefly',
#  'cyndaquil',
#  'darkrai',
#  'darmanitan-standard',
#  'dartrix',
#  'darumaka',
#  'decidueye',
#  'dedenne',
#  'deerling',
#  'deino',
#  'delcatty',
#  'delibird',
#  'delphox',
#  'deoxys-normal',
#  'dewgong',
#  'dewott',
#  'dewpider',
#  'dhelmise',
#  'dialga',
#  'diancie',
#  'diggersby',
#  'diglett',
#  'ditto',
#  'dodrio',
#  'doduo',
#  'donphan',
#  'doublade',
#  'dragalge',
#  'dragonair',
#  'dragonite',
#  'drampa',
#  'drapion',
#  'dratini',
#  'drifblim',
#  'drifloon',
#  'drilbur',
#  'drowzee',
#  'druddigon',
#  'ducklett',
#  'dugtrio',
#  'dunsparce',
#  'duosion',
#  'durant',
#  'dusclops',
#  'dusknoir',
#  'duskull',
#  'dustox',
#  'dwebble',
#  'eelektrik',
#  'eelektross',
#  'eevee',
#  'ekans',
#  'electabuzz',
#  'electivire',
#  'electrike',
#  'electrode',
#  'elekid',
#  'elgyem',
#  'emboar',
#  'emolga',
#  'empoleon',
#  'entei',
#  'escavalier',
#  'espeon',
#  'espurr',
#  'excadrill',
#  'exeggcute',
#  'exeggutor',
#  'exploud',
#  'farfetchd',
#  'fearow',
#  'feebas',
#  'fennekin',
#  'feraligatr',
#  'ferroseed',
#  'ferrothorn',
#  'finneon',
#  'flaaffy',
#  'flabebe',
#  'flareon',
#  'fletchinder',
#  'fletchling',
#  'floatzel',
#  'floette',
#  'florges',
#  'flygon',
#  'fomantis',
#  'foongus',
#  'forretress',
#  'fraxure',
#  'frillish',
#  'froakie',
#  'frogadier',
#  'froslass',
#  'furfrou',
#  'furret',
#  'gabite',
#  'gallade',
#  'galvantula',
#  'garbodor',
#  'garchomp',
#  'gardevoir',
#  'gastly',
#  'gastrodon',
#  'genesect',
#  'gengar',
#  'geodude',
#  'gible',
#  'gigalith',
#  'girafarig',
#  'giratina-altered',
#  'glaceon',
#  'glalie',
#  'glameow',
#  'gligar',
#  'gliscor',
#  'gloom',
#  'gogoat',
#  'golbat',
#  'goldeen',
#  'golduck',
#  'golem',
#  'golett',
#  'golisopod',
#  'golurk',
#  'goodra',
#  'goomy',
#  'gorebyss',
#  'gothita',
#  'gothitelle',
#  'gothorita',
#  'gourgeist-average',
#  'granbull',
#  'graveler',
#  'greninja',
#  'grimer',
#  'grotle',
#  'groudon',
#  'grovyle',
#  'growlithe',
#  'grubbin',
#  'grumpig',
#  'gulpin',
#  'gumshoos',
#  'gurdurr',
#  'guzzlord',
#  'gyarados',
#  'hakamo-o',
#  'happiny',
#  'hariyama',
#  'haunter',
#  'hawlucha',
#  'haxorus',
#  'heatmor',
#  'heatran',
#  'heliolisk',
#  'helioptile',
#  'heracross',
#  'herdier',
#  'hippopotas',
#  'hippowdon',
#  'hitmonchan',
#  'hitmonlee',
#  'hitmontop',
#  'ho-oh',
#  'honchkrow',
#  'honedge',
#  'hoopa-confined',
#  'hoothoot',
#  'hoppip',
#  'horsea',
#  'houndoom',
#  'houndour',
#  'huntail',
#  'hydreigon',
#  'hypno',
#  'igglybuff',
#  'illumise',
#  'incineroar',
#  'infernape',
#  'inkay',
#  'ivysaur',
#  'jangmo-o',
#  'jellicent',
#  'jigglypuff',
#  'jirachi',
#  'jolteon',
#  'joltik',
#  'jumpluff',
#  'jynx',
#  'kabuto',
#  'kabutops',
#  'kadabra',
#  'kakuna',
#  'kangaskhan',
#  'karrablast',
#  'kartana',
#  'kecleon',
#  'keldeo-ordinary',
#  'kingdra',
#  'kingler',
#  'kirlia',
#  'klang',
#  'klefki',
#  'klink',
#  'klinklang',
#  'koffing',
#  'komala',
#  'kommo-o',
#  'krabby',
#  'kricketot',
#  'kricketune',
#  'krokorok',
#  'krookodile',
#  'kyogre',
#  'kyurem',
#  'lairon',
#  'lampent',
#  'landorus-incarnate',
#  'lanturn',
#  'lapras',
#  'larvesta',
#  'larvitar',
#  'latias',
#  'latios',
#  'leafeon',
#  'leavanny',
#  'ledian',
#  'ledyba',
#  'lickilicky',
#  'lickitung',
#  'liepard',
#  'lileep',
#  'lilligant',
#  'lillipup',
#  'linoone',
#  'litleo',
#  'litten',
#  'litwick',
#  'lombre',
#  'lopunny',
#  'lotad',
#  'loudred',
#  'lucario',
#  'ludicolo',
#  'lugia',
#  'lumineon',
#  'lunala',
#  'lunatone',
#  'lurantis',
#  'luvdisc',
#  'luxio',
#  'luxray',
#  'lycanroc-midday',
#  'machamp',
#  'machoke',
#  'machop',
#  'magby',
#  'magcargo',
#  'magearna',
#  'magikarp',
#  'magmar',
#  'magmortar',
#  'magnemite',
#  'magneton',
#  'magnezone',
#  'makuhita',
#  'malamar',
#  'mamoswine',
#  'manaphy',
#  'mandibuzz',
#  'manectric',
#  'mankey',
#  'mantine',
#  'mantyke',
#  'maractus',
#  'mareanie',
#  'mareep',
#  'marill',
#  'marowak',
#  'marshadow',
#  'marshtomp',
#  'masquerain',
#  'mawile',
#  'medicham',
#  'meditite',
#  'meganium',
#  'melmetal',
#  'meloetta-aria',
#  'meltan',
#  'meowstic-male',
#  'meowth',
#  'mesprit',
#  'metagross',
#  'metang',
#  'metapod',
#  'mew',
#  'mewtwo',
#  'mienfoo',
#  'mienshao',
#  'mightyena',
#  'milotic',
#  'miltank',
#  'mime-jr',
#  'mimikyu',
#  'minccino',
#  'minior-meteor',
#  'minun',
#  'misdreavus',
#  'mismagius',
#  'moltres',
#  'monferno',
#  'morelull',
#  'mothim',
#  'mr-mime',
#  'mudbray',
#  'mudkip',
#  'mudsdale',
#  'muk',
#  'munchlax',
#  'munna',
#  'murkrow',
#  'musharna',
#  'naganadel',
#  'natu',
#  'necrozma',
#  'nidoking',
#  'nidoqueen',
#  'nidoran-f',
#  'nidoran-m',
#  'nidorina',
#  'nidorino',
#  'nihilego',
#  'nincada',
#  'ninetales',
#  'ninjask',
#  'noctowl',
#  'noibat',
#  'noivern',
#  'nosepass',
#  'numel',
#  'nuzleaf',
#  'octillery',
#  'oddish',
#  'omanyte',
#  'omastar',
#  'onix',
#  'oranguru',
#  'oricorio-baile',
#  'oshawott',
#  'pachirisu',
#  'palkia',
#  'palossand',
#  'palpitoad',
#  'pancham',
#  'pangoro',
#  'panpour',
#  'pansage',
#  'pansear',
#  'paras',
#  'parasect',
#  'passimian',
#  'patrat',
#  'pawniard',
#  'pelipper',
#  'persian',
#  'petilil',
#  'phanpy',
#  'phantump',
#  'pheromosa',
#  'phione',
#  'pichu',
#  'pidgeot',
#  'pidgeotto',
#  'pidgey',
#  'pidove',
#  'pignite',
#  'pikachu',
#  'pikipek',
#  'piloswine',
#  'pineco',
#  'pinsir',
#  'piplup',
#  'plusle',
#  'poipole',
#  'politoed',
#  'poliwag',
#  'poliwhirl',
#  'poliwrath',
#  'ponyta',
#  'poochyena',
#  'popplio',
#  'porygon',
#  'porygon-z',
#  'porygon2',
#  'primarina',
#  'primeape',
#  'prinplup',
#  'probopass',
#  'psyduck',
#  'pumpkaboo-average',
#  'pupitar',
#  'purrloin',
#  'purugly',
#  'pyroar',
#  'pyukumuku',
#  'quagsire',
#  'quilava',
#  'quilladin',
#  'qwilfish',
#  'raichu',
#  'raikou',
#  'ralts',
#  'rampardos',
#  'rapidash',
#  'raticate',
#  'rattata',
#  'rayquaza',
#  'regice',
#  'regigigas',
#  'regirock',
#  'registeel',
#  'relicanth',
#  'remoraid',
#  'reshiram',
#  'reuniclus',
#  'rhydon',
#  'rhyhorn',
#  'rhyperior',
#  'ribombee',
#  'riolu',
#  'rockruff',
#  'roggenrola',
#  'roselia',
#  'roserade',
#  'rotom',
#  'rowlet',
#  'rufflet',
#  'sableye',
#  'salamence',
#  'salandit',
#  'salazzle',
#  'samurott',
#  'sandile',
#  'sandshrew',
#  'sandslash',
#  'sandygast',
#  'sawk',
#  'sawsbuck',
#  'scatterbug',
#  'sceptile',
#  'scizor',
#  'scolipede',
#  'scrafty',
#  'scraggy',
#  'scyther',
#  'seadra',
#  'seaking',
#  'sealeo',
#  'seedot',
#  'seel',
#  'seismitoad',
#  'sentret',
#  'serperior',
#  'servine',
#  'seviper',
#  'sewaddle',
#  'sharpedo',
#  'shaymin-land',
#  'shedinja',
#  'shelgon',
#  'shellder',
#  'shellos',
#  'shelmet',
#  'shieldon',
#  'shiftry',
#  'shiinotic',
#  'shinx',
#  'shroomish',
#  'shuckle',
#  'shuppet',
#  'sigilyph',
#  'silcoon',
#  'silvally',
#  'simipour',
#  'simisage',
#  'simisear',
#  'skarmory',
#  'skiddo',
#  'skiploom',
#  'skitty',
#  'skorupi',
#  'skrelp',
#  'skuntank',
#  'slaking',
#  'slakoth',
#  'sliggoo',
#  'slowbro',
#  'slowking',
#  'slowpoke',
#  'slugma',
#  'slurpuff',
#  'smeargle',
#  'smoochum',
#  'sneasel',
#  'snivy',
#  'snorlax',
#  'snorunt',
#  'snover',
#  'snubbull',
#  'solgaleo',
#  'solosis',
#  'solrock',
#  'spearow',
#  'spewpa',
#  'spheal',
#  'spinarak',
#  'spinda',
#  'spiritomb',
#  'spoink',
#  'spritzee',
#  'squirtle',
#  'stakataka',
#  'stantler',
#  'staraptor',
#  'staravia',
#  'starly',
#  'starmie',
#  'staryu',
#  'steelix',
#  'steenee',
#  'stoutland',
#  'stufful',
#  'stunfisk',
#  'stunky',
#  'sudowoodo',
#  'suicune',
#  'sunflora',
#  'sunkern',
#  'surskit',
#  'swablu',
#  'swadloon',
#  'swalot',
#  'swampert',
#  'swanna',
#  'swellow',
#  'swinub',
#  'swirlix',
#  'swoobat',
#  'sylveon',
#  'taillow',
#  'talonflame',
#  'tangela',
#  'tangrowth',
#  'tapu-bulu',
#  'tapu-fini',
#  'tapu-koko',
#  'tapu-lele',
#  'tauros',
#  'teddiursa',
#  'tentacool',
#  'tentacruel',
#  'tepig',
#  'terrakion',
#  'throh',
#  'thundurus-incarnate',
#  'timburr',
#  'tirtouga',
#  'togedemaru',
#  'togekiss',
#  'togepi',
#  'togetic',
#  'torchic',
#  'torkoal',
#  'tornadus-incarnate',
#  'torracat',
#  'torterra',
#  'totodile',
#  'toucannon',
#  'toxapex',
#  'toxicroak',
#  'tranquill',
#  'trapinch',
#  'treecko',
#  'trevenant',
#  'tropius',
#  'trubbish',
#  'trumbeak',
#  'tsareena',
#  'turtonator',
#  'turtwig',
#  'tympole',
#  'tynamo',
#  'type-null',
#  'typhlosion',
#  'tyranitar',
#  'tyrantrum',
#  'tyrogue',
#  'tyrunt',
#  'umbreon',
#  'unfezant',
#  'unown',
#  'ursaring',
#  'uxie',
#  'vanillish',
#  'vanillite',
#  'vanilluxe',
#  'vaporeon',
#  'venipede',
#  'venomoth',
#  'venonat',
#  'venusaur',
#  'vespiquen',
#  'vibrava',
#  'victini',
#  'victreebel',
#  'vigoroth',
#  'vikavolt',
#  'vileplume',
#  'virizion',
#  'vivillon',
#  'volbeat',
#  'volcanion',
#  'volcarona',
#  'voltorb',
#  'vullaby',
#  'vulpix',
#  'wailmer',
#  'wailord',
#  'walrein',
#  'wartortle',
#  'watchog',
#  'weavile',
#  'weedle',
#  'weepinbell',
#  'weezing',
#  'whimsicott',
#  'whirlipede',
#  'whiscash',
#  'whismur',
#  'wigglytuff',
#  'wimpod',
#  'wingull',
#  'wishiwashi-solo',
#  'wobbuffet',
#  'woobat',
#  'wooper',
#  'wormadam-plant',
#  'wurmple',
#  'wynaut',
#  'xatu',
#  'xerneas',
#  'xurkitree',
#  'yamask',
#  'yanma',
#  'yanmega',
#  'yungoos',
#  'yveltal',
#  'zangoose',
#  'zapdos',
#  'zebstrika',
#  'zekrom',
#  'zeraora',
#  'zigzagoon',
#  'zoroark',
#  'zorua',
#  'zubat',
#  'zweilous',
#  'zygarde-50']

# %%
for i in os.listdir(curr):
    path = os.path.join(curr, i)
    names=os.listdir(path)
    for j in names:
#         print(j)
        img=Image.open(path+"\\"+j)
        img = img.convert('RGB')
        img=np.array(img)
        img = Image.fromarray(img)
        img.save(j)

# %%
# %cd train
# Out:
# C:\Users\Rohith\mern\train

# %%
abss=os.getcwd()
abss
# Out:
# 'C:\\Users\\Rohith\\mern\\train'

# %%
from keras.models import Sequential
from keras.layers import Conv2D,BatchNormalization, MaxPooling2D, Dropout, Flatten, Dense, Activation,GlobalMaxPooling2D
from keras import applications
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers
from keras.applications.mobilenet import MobileNet
from keras.models import Model

image_size = 120
input_shape = (image_size, image_size, 3)

epochs = 30
batch_size = 200

pre_trained_model = MobileNet(input_shape=input_shape, include_top=False, weights="imagenet")
    
for layer in pre_trained_model.layers:
    layer.trainable = False

# for layer in pre_trained_model.layers:
#     layer.trainable = True
    
# last_layer = pre_trained_model.get_layer('block5_pool')
last_output = pre_trained_model.output
print(last_output)
# Flatten the output layer to 1 dimension
x = GlobalMaxPooling2D()(last_output)
x=BatchNormalization()(x)
x = Dense(512, activation='relu')(x)
# Add a dropout rate of 0.5
# x = Dropout(0.5)(x)
x = Dense(256, activation='relu')(x)
x = Dense(128, activation='relu')(x)

x = Dense(640, activation='relu')(x)
x = Dense(1000, activation='relu')(x)
x = Dense(800, activation='relu')(x)

x = Dense(809, activation='softmax')(x)

model = Model(pre_trained_model.input, x)

model.compile(loss='categorical_crossentropy',
              optimizer='Adam',
              metrics=['accuracy'])

model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# KerasTensor(type_spec=TensorSpec(shape=(None, 3, 3, 1024), dtype=tf.float32, name=None), name='conv_pw_13_relu/Relu6:0', description="created by layer 'conv_pw_13_relu'")
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 120, 120, 3)]     0
#
#  conv1 (Conv2D)              (None, 60, 60, 32)        864
#
#  conv1_bn (BatchNormalizatio  (None, 60, 60, 32)       128
#  n)
#
#  conv1_relu (ReLU)           (None, 60, 60, 32)        0
#
#  conv_dw_1 (DepthwiseConv2D)  (None, 60, 60, 32)       288
#
#  conv_dw_1_bn (BatchNormaliz  (None, 60, 60, 32)       128
#  ation)
#
#  conv_dw_1_relu (ReLU)       (None, 60, 60, 32)        0
#
#  conv_pw_1 (Conv2D)          (None, 60, 60, 64)        2048
#
#  conv_pw_1_bn (BatchNormaliz  (None, 60, 60, 64)       256
#  ation)
#
#  conv_pw_1_relu (ReLU)       (None, 60, 60, 64)        0
#
#  conv_pad_2 (ZeroPadding2D)  (None, 61, 61, 64)        0
#
#  conv_dw_2 (DepthwiseConv2D)  (None, 30, 30, 64)       576
#
#  conv_dw_2_bn (BatchNormaliz  (None, 30, 30, 64)       256
#  ation)
#
#  conv_dw_2_relu (ReLU)       (None, 30, 30, 64)        0
#
#  conv_pw_2 (Conv2D)          (None, 30, 30, 128)       8192
#
#  conv_pw_2_bn (BatchNormaliz  (None, 30, 30, 128)      512
#  ation)
#
#  conv_pw_2_relu (ReLU)       (None, 30, 30, 128)       0
#
#  conv_dw_3 (DepthwiseConv2D)  (None, 30, 30, 128)      1152
#
#  conv_dw_3_bn (BatchNormaliz  (None, 30, 30, 128)      512
#  ation)
#
#  conv_dw_3_relu (ReLU)       (None, 30, 30, 128)       0
#
#  conv_pw_3 (Conv2D)          (None, 30, 30, 128)       16384
#
#  conv_pw_3_bn (BatchNormaliz  (None, 30, 30, 128)      512
#  ation)
#
#  conv_pw_3_relu (ReLU)       (None, 30, 30, 128)       0
#
#  conv_pad_4 (ZeroPadding2D)  (None, 31, 31, 128)       0
#
#  conv_dw_4 (DepthwiseConv2D)  (None, 15, 15, 128)      1152
#
#  conv_dw_4_bn (BatchNormaliz  (None, 15, 15, 128)      512
#  ation)
#
#  conv_dw_4_relu (ReLU)       (None, 15, 15, 128)       0
#
#  conv_pw_4 (Conv2D)          (None, 15, 15, 256)       32768
#
#  conv_pw_4_bn (BatchNormaliz  (None, 15, 15, 256)      1024
#  ation)
#
#  conv_pw_4_relu (ReLU)       (None, 15, 15, 256)       0
#
#  conv_dw_5 (DepthwiseConv2D)  (None, 15, 15, 256)      2304
#
#  conv_dw_5_bn (BatchNormaliz  (None, 15, 15, 256)      1024
#  ation)
#
#  conv_dw_5_relu (ReLU)       (None, 15, 15, 256)       0
#
#  conv_pw_5 (Conv2D)          (None, 15, 15, 256)       65536
#
#  conv_pw_5_bn (BatchNormaliz  (None, 15, 15, 256)      1024
#  ation)
#
#  conv_pw_5_relu (ReLU)       (None, 15, 15, 256)       0
#
#  conv_pad_6 (ZeroPadding2D)  (None, 16, 16, 256)       0
#
#  conv_dw_6 (DepthwiseConv2D)  (None, 7, 7, 256)        2304
#
#  conv_dw_6_bn (BatchNormaliz  (None, 7, 7, 256)        1024
#  ation)
#
#  conv_dw_6_relu (ReLU)       (None, 7, 7, 256)         0
#
#  conv_pw_6 (Conv2D)          (None, 7, 7, 512)         131072
#
#  conv_pw_6_bn (BatchNormaliz  (None, 7, 7, 512)        2048
#  ation)
#
#  conv_pw_6_relu (ReLU)       (None, 7, 7, 512)         0
#
#  conv_dw_7 (DepthwiseConv2D)  (None, 7, 7, 512)        4608
#
#  conv_dw_7_bn (BatchNormaliz  (None, 7, 7, 512)        2048
#  ation)
#
#  conv_dw_7_relu (ReLU)       (None, 7, 7, 512)         0
#
#  conv_pw_7 (Conv2D)          (None, 7, 7, 512)         262144
#
#  conv_pw_7_bn (BatchNormaliz  (None, 7, 7, 512)        2048
#  ation)
#
#  conv_pw_7_relu (ReLU)       (None, 7, 7, 512)         0
#
#  conv_dw_8 (DepthwiseConv2D)  (None, 7, 7, 512)        4608
#
#  conv_dw_8_bn (BatchNormaliz  (None, 7, 7, 512)        2048
#  ation)
#
#  conv_dw_8_relu (ReLU)       (None, 7, 7, 512)         0
#
#  conv_pw_8 (Conv2D)          (None, 7, 7, 512)         262144
#
#  conv_pw_8_bn (BatchNormaliz  (None, 7, 7, 512)        2048
#  ation)
#
#  conv_pw_8_relu (ReLU)       (None, 7, 7, 512)         0
#
#  conv_dw_9 (DepthwiseConv2D)  (None, 7, 7, 512)        4608
#
#  conv_dw_9_bn (BatchNormaliz  (None, 7, 7, 512)        2048
#  ation)
#
#  conv_dw_9_relu (ReLU)       (None, 7, 7, 512)         0
#
#  conv_pw_9 (Conv2D)          (None, 7, 7, 512)         262144
#
#  conv_pw_9_bn (BatchNormaliz  (None, 7, 7, 512)        2048
#  ation)
#
#  conv_pw_9_relu (ReLU)       (None, 7, 7, 512)         0
#
#  conv_dw_10 (DepthwiseConv2D  (None, 7, 7, 512)        4608
#  )
#
#  conv_dw_10_bn (BatchNormali  (None, 7, 7, 512)        2048
#  zation)
#
#  conv_dw_10_relu (ReLU)      (None, 7, 7, 512)         0
#
#  conv_pw_10 (Conv2D)         (None, 7, 7, 512)         262144
#
#  conv_pw_10_bn (BatchNormali  (None, 7, 7, 512)        2048
#  zation)
#
#  conv_pw_10_relu (ReLU)      (None, 7, 7, 512)         0
#
#  conv_dw_11 (DepthwiseConv2D  (None, 7, 7, 512)        4608
#  )
#
#  conv_dw_11_bn (BatchNormali  (None, 7, 7, 512)        2048
#  zation)
#
#  conv_dw_11_relu (ReLU)      (None, 7, 7, 512)         0
#
#  conv_pw_11 (Conv2D)         (None, 7, 7, 512)         262144
#
#  conv_pw_11_bn (BatchNormali  (None, 7, 7, 512)        2048
#  zation)
#
#  conv_pw_11_relu (ReLU)      (None, 7, 7, 512)         0
#
#  conv_pad_12 (ZeroPadding2D)  (None, 8, 8, 512)        0
#
#  conv_dw_12 (DepthwiseConv2D  (None, 3, 3, 512)        4608
#  )
#
#  conv_dw_12_bn (BatchNormali  (None, 3, 3, 512)        2048
#  zation)
#
#  conv_dw_12_relu (ReLU)      (None, 3, 3, 512)         0
#
#  conv_pw_12 (Conv2D)         (None, 3, 3, 1024)        524288
#
#  conv_pw_12_bn (BatchNormali  (None, 3, 3, 1024)       4096
#  zation)
#
#  conv_pw_12_relu (ReLU)      (None, 3, 3, 1024)        0
#
#  conv_dw_13 (DepthwiseConv2D  (None, 3, 3, 1024)       9216
#  )
#
#  conv_dw_13_bn (BatchNormali  (None, 3, 3, 1024)       4096
#  zation)
#
#  conv_dw_13_relu (ReLU)      (None, 3, 3, 1024)        0
#
#  conv_pw_13 (Conv2D)         (None, 3, 3, 1024)        1048576
#
#  conv_pw_13_bn (BatchNormali  (None, 3, 3, 1024)       4096
#  zation)
#
#  conv_pw_13_relu (ReLU)      (None, 3, 3, 1024)        0
#
#  global_max_pooling2d (Globa  (None, 1024)             0
#  lMaxPooling2D)
#
#  batch_normalization (BatchN  (None, 1024)             4096
#  ormalization)
#
#  dense (Dense)               (None, 512)               524800
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dense_3 (Dense)             (None, 640)               82560
#
#  dense_4 (Dense)             (None, 1000)              641000
#
#  dense_5 (Dense)             (None, 800)               800800
#
#  dense_6 (Dense)             (None, 809)               648009
#
# =================================================================
# Total params: 6,094,353
# Trainable params: 2,863,441
# Non-trainable params: 3,230,912
# _________________________________________________________________

# %%
from sklearn.model_selection import train_test_split
train_df=df
train_df = train_df.reset_index()
# validate_df = validate_df.reset_index()

# validate_df = validate_df.sample(n=100).reset_index() # use for fast testing code purpose
# train_df = train_df.sample(n=1800).reset_index() # use for fast testing code purpose

total_train = train_df.shape[0]
# total_validate = validate_df.shape[0]

# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(
    rotation_range=15,
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    width_shift_range=0.1,
    height_shift_range=0.1
)

train_generator = train_datagen.flow_from_dataframe(
    train_df, 
    abss, 
    x_col='filename',
    y_col='category',
    class_mode='categorical',
    target_size=(image_size, image_size),
    batch_size=batch_size
)
validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow_from_dataframe(
    train_df, 
    abss, 
    x_col='filename',
    y_col='category',
    class_mode='categorical',
    target_size=(image_size, image_size),
    batch_size=batch_size
)
# Out:
# Found 2427 validated image filenames belonging to 809 classes.
# Found 2427 validated image filenames belonging to 809 classes.

# %%
history = model.fit(
    train_generator,
    epochs=epochs,
    steps_per_epoch=total_train//batch_size)
# Out:
# Epoch 1/30
# 12/12 [==============================] - 38s 3s/step - loss: 6.7184 - accuracy: 0.0013
# Epoch 2/30
# 12/12 [==============================] - 36s 3s/step - loss: 6.6326 - accuracy: 0.0029
# Epoch 3/30
# 12/12 [==============================] - 34s 3s/step - loss: 6.2164 - accuracy: 0.0126
# Epoch 4/30
# 12/12 [==============================] - 35s 3s/step - loss: 5.2879 - accuracy: 0.0476
# Epoch 5/30
# 12/12 [==============================] - 34s 3s/step - loss: 4.2921 - accuracy: 0.1271
# Epoch 6/30
# 12/12 [==============================] - 34s 3s/step - loss: 3.3315 - accuracy: 0.2366
# Epoch 7/30
# 12/12 [==============================] - 35s 3s/step - loss: 2.4818 - accuracy: 0.3974
# Epoch 8/30
# 12/12 [==============================] - 34s 3s/step - loss: 2.0189 - accuracy: 0.4791
# Epoch 9/30
# 12/12 [==============================] - 33s 3s/step - loss: 1.7289 - accuracy: 0.5420
# Epoch 10/30
# 12/12 [==============================] - 34s 3s/step - loss: 1.4753 - accuracy: 0.6004
# Epoch 11/30
# 12/12 [==============================] - 35s 3s/step - loss: 1.0589 - accuracy: 0.7038
# Epoch 12/30
# 12/12 [==============================] - 34s 3s/step - loss: 0.8535 - accuracy: 0.7508
# Epoch 13/30
# 12/12 [==============================] - 34s 3s/step - loss: 0.8152 - accuracy: 0.7741
# Epoch 14/30
# 12/12 [==============================] - 34s 3s/step - loss: 0.7387 - accuracy: 0.7773
# Epoch 15/30
# 12/12 [==============================] - 32s 3s/step - loss: 0.8229 - accuracy: 0.7750
# Epoch 16/30
# 12/12 [==============================] - 34s 3s/step - loss: 0.5744 - accuracy: 0.8334
# Epoch 17/30
# 12/12 [==============================] - 33s 3s/step - loss: 0.7751 - accuracy: 0.7849
# Epoch 18/30
# 12/12 [==============================] - 34s 3s/step - loss: 0.5193 - accuracy: 0.8536
# Epoch 19/30
# 12/12 [==============================] - 33s 3s/step - loss: 0.4351 - accuracy: 0.8765
# Epoch 20/30
# 12/12 [==============================] - 32s 3s/step - loss: 0.4493 - accuracy: 0.8716
# Epoch 21/30
# 12/12 [==============================] - 32s 3s/step - loss: 0.5660 - accuracy: 0.8321
# Epoch 22/30
# 12/12 [==============================] - 32s 3s/step - loss: 0.4127 - accuracy: 0.8850
# Epoch 23/30
# 12/12 [==============================] - 32s 3s/step - loss: 0.4559 - accuracy: 0.8662
# Epoch 24/30
# 12/12 [==============================] - 33s 3s/step - loss: 0.3520 - accuracy: 0.8994
# Epoch 25/30
# 12/12 [==============================] - 34s 3s/step - loss: 0.4565 - accuracy: 0.8774
# Epoch 26/30
# 12/12 [==============================] - 34s 3s/step - loss: 0.3779 - accuracy: 0.8927
# Epoch 27/30
# 12/12 [==============================] - 34s 3s/step - loss: 0.2689 - accuracy: 0.9237
# Epoch 28/30
# 12/12 [==============================] - 34s 3s/step - loss: 0.3044 - accuracy: 0.9151
# Epoch 29/30
# 12/12 [==============================] - 34s 3s/step - loss: 0.2460 - accuracy: 0.9219
# Epoch 30/30
# 12/12 [==============================] - 33s 3s/step - loss: 0.3797 - accuracy: 0.9026

# %%
def plot_model_history(model_history, acc='accuracy', val_acc='val_accuracy'):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    axs[0].plot(range(1,len(model_history.history[acc])+1),model_history.history[acc])
    # axs[0].plot(range(1,len(model_history.history[val_acc])+1),model_history.history[val_acc])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
#     axs[0].set_xticks(np.arange(1,len(model_history.history[acc])+1),len(model_history.history[acc])/10)
    axs[0].legend(['train'], loc='best')
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    # axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
#     axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train'], loc='best')
    plt.show()
    
plot_model_history(history)
