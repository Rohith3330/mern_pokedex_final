# %%
import albumentations as A        # For data augmentation
import cv2                        # For loading images
import matplotlib.pyplot as plt   # For plotting images
import numpy as np

# %%
from PIL import Image

# %%
import os

# %%
# %cd /content/drive/MyDrive

# %%
# %cd imgs

# %%
transform=A.Compose([
#     A.Resize(width=1920,height=1080),
#     A.RandomCrop(width=1280,height=720),
   
#     A.RGBShift(r_shift_limit=25,g_shift_limit=25,b_shift_limit=25,p=0.9),
    A.OneOf([
        A.Blur(blur_limit=3,p=0.5),
        A.Rotate(limit=40,p=0.9),
        A.HorizontalFlip(p=0.5),
        A.VerticalFlip (p=0.1)
    ],p=1.0),
])

# %%
l=[]
for i in os.listdir():
    img=Image.open(i)
    img=np.array(img)
    image_list=[img]
    for j in range(20):
        augumentations=transform(image=img)
        augumentation_image=augumentations["image"]
        image_list.append(augumentation_image)
    l.append(image_list)
print(len(l))
# Out:
# 803

# %%
k=0
i=l[400]
print(len(i))
plt.imshow(i[0])
plt.show()
# Out:
# 21

# %%
# %cd ..
# Out:
# /content/drive/MyDrive/train

# %%
curr=os.getcwd()
curr
# Out:
# '/content/drive/MyDrive/train'

# %%
di=os.listdir("/content/drive/MyDrive/imgs")
di
# Out:
# ['conkeldurr.png',
#  'azelf.png',
#  'azurill.png',
#  'bagon.png',
#  'azumarill.png',
#  'baltoy.png',
#  'barbaracle.png',
#  'frillish.png',
#  'abra.png',
#  'accelgor.png',
#  'absol.png',
#  'anorith.png',
#  'aegislash-blade.png',
#  'ampharos.png',
#  'amoonguss.png',
#  'araquanid.jpg',
#  'aerodactyl.png',
#  'arbok.png',
#  'ambipom.png',
#  'aromatisse.png',
#  'ariados.png',
#  'archeops.png',
#  'armaldo.png',
#  'gourgeist-average.png',
#  'graveler.png',
#  'greninja.png',
#  'herdier.png',
#  'axew.png',
#  'chikorita.png',
#  'charizard.png',
#  'chespin.png',
#  'bellsprout.png',
#  'clamperl.png',
#  'budew.png',
#  'bergmite.png',
#  'carvanha.png',
#  'blitzle.png',
#  'chimchar.png',
#  'chimecho.png',
#  'cacturne.png',
#  'binacle.png',
#  'camerupt.png',
#  'carracosta.png',
#  'boldore.png',
#  'machamp.png',
#  'bruxish.jpg',
#  'cinccino.png',
#  'marowak.png',
#  'diglett.png',
#  'dewpider.jpg',
#  'chingling.png',
#  'blaziken.png',
#  'cherrim.png',
#  'mew.png',
#  'chansey.png',
#  'cascoon.png',
#  'lycanroc-midday.jpg',
#  'bidoof.png',
#  'blissey.png',
#  'bibarel.png',
#  'charmeleon.png',
#  'celesteela.jpg',
#  'drilbur.png',
#  'charjabug.jpg',
#  'chesnaught.png',
#  'dewott.png',
#  'chatot.png',
#  'dragonair.png',
#  'bewear.jpg',
#  'chinchou.png',
#  'drampa.jpg',
#  'dragalge.png',
#  'carnivine.png',
#  'dodrio.png',
#  'ditto.png',
#  'drifloon.png',
#  'dhelmise.jpg',
#  'dragonite.png',
#  'dratini.png',
#  'ducklett.png',
#  'musharna.png',
#  'drowzee.png',
#  'dugtrio.png',
#  'drapion.png',
#  'druddigon.png',
#  'dustox.png',
#  'elekid.png',
#  'duosion.png',
#  'dusknoir.png',
#  'durant.png',
#  'dusclops.png',
#  'dwebble.png',
#  'duskull.png',
#  'eelektrik.png',
#  'eelektross.png',
#  'elgyem.png',
#  'escavalier.png',
#  'empoleon.png',
#  'espeon.png',
#  'emboar.png',
#  'entei.png',
#  'excadrill.png',
#  'exeggcute.png',
#  'exeggutor.png',
#  'feebas.png',
#  'exploud.png',
#  'fearow.png',
#  'fennekin.png',
#  'feraligatr.png',
#  'ferroseed.png',
#  'finneon.png',
#  'ferrothorn.png',
#  'flaaffy.png',
#  'flabebe.png',
#  'flareon.png',
#  'fletchinder.png',
#  'fletchling.png',
#  'floatzel.png',
#  'floette.png',
#  'florges.png',
#  'flygon.png',
#  'fomantis.jpg',
#  'foongus.png',
#  'forretress.png',
#  'fraxure.png',
#  'froakie.png',
#  'frogadier.png',
#  'froslass.png',
#  'furret.png',
#  'furfrou.png',
#  'gabite.png',
#  'gallade.png',
#  'galvantula.png',
#  'garbodor.png',
#  'garchomp.png',
#  'gardevoir.png',
#  'gastly.png',
#  'gastrodon.png',
#  'genesect.png',
#  'gengar.png',
#  'geodude.png',
#  'gible.png',
#  'gigalith.png',
#  'girafarig.png',
#  'giratina-altered.png',
#  'glameow.png',
#  'glaceon.png',
#  'glalie.png',
#  'gligar.png',
#  'gliscor.png',
#  'abomasnow.png',
#  'gloom.png',
#  'gogoat.png',
#  'golbat.png',
#  'goldeen.png',
#  'aggron.png',
#  'aipom.png',
#  'alomomola.png',
#  'altaria.png',
#  'alakazam.png',
#  'arcanine.png',
#  'amaura.png',
#  'arceus.png',
#  'archen.png',
#  'aron.png',
#  'articuno.png',
#  'audino.png',
#  'avalugg.png',
#  'aurorus.png',
#  'golduck.png',
#  'goomy.png',
#  'goodra.png',
#  'gorebyss.png',
#  'golisopod.jpg',
#  'golett.png',
#  'gothitelle.png',
#  'gothorita.png',
#  'granbull.png',
#  'grimer.png',
#  'grotle.png',
#  'groudon.png',
#  'growlithe.png',
#  'grubbin.jpg',
#  'grovyle.png',
#  'grumpig.png',
#  'gulpin.png',
#  'gumshoos.jpg',
#  'gurdurr.png',
#  'guzzlord.jpg',
#  'gyarados.png',
#  'hakamo-o.jpg',
#  'happiny.png',
#  'hariyama.png',
#  'haunter.png',
#  'hawlucha.png',
#  'heatmor.png',
#  'heliolisk.png',
#  'heatran.png',
#  'heracross.png',
#  'helioptile.png',
#  'hippopotas.png',
#  'hippowdon.png',
#  'hitmonchan.png',
#  'hitmonlee.png',
#  'hitmontop.png',
#  'honedge.png',
#  'hoppip.png',
#  'hoopa-confined.png',
#  'horsea.png',
#  'ho-oh.png',
#  'houndour.png',
#  'houndoom.png',
#  'huntail.png',
#  'hypno.png',
#  'hydreigon.png',
#  'igglybuff.png',
#  'illumise.png',
#  'incineroar.jpg',
#  'infernape.png',
#  'inkay.png',
#  'ivysaur.png',
#  'jellicent.png',
#  'jigglypuff.png',
#  'jirachi.png',
#  'jolteon.png',
#  'joltik.png',
#  'jumpluff.png',
#  'jynx.png',
#  'kabuto.png',
#  'kabutops.png',
#  'kadabra.png',
#  'kakuna.png',
#  'kangaskhan.png',
#  'karrablast.png',
#  'kartana.jpg',
#  'kecleon.png',
#  'keldeo-ordinary.png',
#  'kingdra.png',
#  'kingler.png',
#  'kirlia.png',
#  'klang.png',
#  'klefki.png',
#  'klink.png',
#  'klinklang.png',
#  'koffing.png',
#  'komala.jpg',
#  'kommo-o.jpg',
#  'krabby.png',
#  'kricketot.png',
#  'kricketune.png',
#  'krokorok.png',
#  'krookodile.png',
#  'kyogre.png',
#  'kyurem.png',
#  'lairon.png',
#  'lampent.png',
#  'lanturn.png',
#  'landorus-incarnate.png',
#  'lapras.png',
#  'larvitar.png',
#  'latias.png',
#  'latios.png',
#  'leafeon.png',
#  'leavanny.png',
#  'ledian.png',
#  'ledyba.png',
#  'lickilicky.png',
#  'lickitung.png',
#  'liepard.png',
#  'lileep.png',
#  'linoone.png',
#  'litleo.png',
#  'lillipup.png',
#  'lilligant.png',
#  'litten.jpg',
#  'litwick.png',
#  'lombre.png',
#  'lopunny.png',
#  'lotad.png',
#  'banette.png',
#  'barboach.png',
#  'basculin-red-striped.png',
#  'bastiodon.png',
#  'bayleef.png',
#  'beartic.png',
#  'beautifly.png',
#  'beedrill.png',
#  'beheeyem.png',
#  'beldum.png',
#  'loudred.png',
#  'bellossom.png',
#  'lucario.png',
#  'bisharp.png',
#  'blacephalon.jpg',
#  'blastoise.png',
#  'bonsly.png',
#  'ludicolo.png',
#  'bouffalant.png',
#  'bounsweet.jpg',
#  'braixen.png',
#  'braviary.png',
#  'breloom.png',
#  'brionne.jpg',
#  'bronzong.png',
#  'bronzor.png',
#  'lugia.png',
#  'lumineon.png',
#  'lunala.jpg',
#  'lurantis.jpg',
#  'lunatone.png',
#  'luvdisc.png',
#  'luxray.png',
#  'luxio.png',
#  'bulbasaur.png',
#  'buizel.png',
#  'buneary.png',
#  'bunnelby.png',
#  'burmy.png',
#  'butterfree.png',
#  'buzzwole.jpg',
#  'cacnea.png',
#  'machoke.png',
#  'machop.png',
#  'magby.png',
#  'magcargo.png',
#  'magearna.jpg',
#  'carbink.png',
#  'magikarp.png',
#  'magmar.png',
#  'castform.png',
#  'caterpie.png',
#  'celebi.png',
#  'magmortar.png',
#  'magnemite.png',
#  'makuhita.png',
#  'magnezone.png',
#  'magneton.png',
#  'malamar.png',
#  'mamoswine.png',
#  'manaphy.png',
#  'manectric.png',
#  'mandibuzz.png',
#  'mankey.png',
#  'mantine.png',
#  'mantyke.png',
#  'maractus.png',
#  'mareanie.jpg',
#  'mareep.png',
#  'marill.png',
#  'marshadow.jpg',
#  'marshtomp.png',
#  'masquerain.png',
#  'chandelure.png',
#  'charmander.png',
#  'cherubi.png',
#  'medicham.png',
#  'mawile.png',
#  'meditite.png',
#  'meganium.png',
#  'melmetal.jpg',
#  'meloetta-aria.png',
#  'meltan.jpg',
#  'meowstic-male.png',
#  'meowth.png',
#  'mesprit.png',
#  'metagross.png',
#  'metang.png',
#  'metapod.png',
#  'clauncher.png',
#  'clawitzer.png',
#  'claydol.png',
#  'clefable.png',
#  'clefairy.png',
#  'cleffa.png',
#  'cloyster.png',
#  'cobalion.png',
#  'cofagrigus.png',
#  'combee.png',
#  'comfey.jpg',
#  'combusken.png',
#  'corphish.png',
#  'corsola.png',
#  'cosmoem.jpg',
#  'cosmog.jpg',
#  'cottonee.png',
#  'crabominable.jpg',
#  'crabrawler.jpg',
#  'cradily.png',
#  'cranidos.png',
#  'crawdaunt.png',
#  'cresselia.png',
#  'croagunk.png',
#  'croconaw.png',
#  'crobat.png',
#  'crustle.png',
#  'cryogonal.png',
#  'cubchoo.png',
#  'cutiefly.jpg',
#  'cubone.png',
#  'cyndaquil.png',
#  'darkrai.png',
#  'darmanitan-standard.png',
#  'dartrix.jpg',
#  'darumaka.png',
#  'decidueye.jpg',
#  'dedenne.png',
#  'deerling.png',
#  'deino.png',
#  'delcatty.png',
#  'delibird.png',
#  'delphox.png',
#  'deoxys-normal.png',
#  'dewgong.png',
#  'dialga.png',
#  'diancie.png',
#  'diggersby.png',
#  'mienfoo.png',
#  'mewtwo.png',
#  'mienshao.png',
#  'mightyena.png',
#  'milotic.png',
#  'miltank.png',
#  'mime-jr.png',
#  'mimikyu.jpg',
#  'minccino.png',
#  'minior-meteor.jpg',
#  'minun.png',
#  'misdreavus.png',
#  'mismagius.png',
#  'moltres.png',
#  'doduo.png',
#  'donphan.png',
#  'doublade.png',
#  'monferno.png',
#  'morelull.jpg',
#  'mothim.png',
#  'mr-mime.png',
#  'mudbray.jpg',
#  'mudkip.png',
#  'mudsdale.jpg',
#  'muk.png',
#  'munchlax.png',
#  'munna.png',
#  'murkrow.png',
#  'drifblim.png',
#  'naganadel.jpg',
#  'natu.png',
#  'necrozma.jpg',
#  'nidoking.png',
#  'nidoqueen.png',
#  'nidoran-f.png',
#  'nidoran-m.png',
#  'nidorina.png',
#  'nidorino.png',
#  'nihilego.jpg',
#  'nincada.png',
#  'ninetales.png',
#  'ninjask.png',
#  'noctowl.png',
#  'noibat.png',
#  'noivern.png',
#  'nosepass.png',
#  'numel.png',
#  'nuzleaf.png',
#  'octillery.png',
#  'oddish.png',
#  'omanyte.png',
#  'omastar.png',
#  'onix.png',
#  'oranguru.jpg',
#  'oricorio-baile.jpg',
#  'oshawott.png',
#  'pachirisu.png',
#  'palkia.png',
#  'palossand.jpg',
#  'palpitoad.png',
#  'pancham.png',
#  'panpour.png',
#  'pangoro.png',
#  'pansage.png',
#  'pansear.png',
#  'paras.png',
#  'parasect.png',
#  'passimian.jpg',
#  'patrat.png',
#  'pawniard.png',
#  'pelipper.png',
#  'persian.png',
#  'phanpy.png',
#  'petilil.png',
#  'phantump.png',
#  'pheromosa.jpg',
#  'pichu.png',
#  'phione.png',
#  'pidgeot.png',
#  'pidgeotto.png',
#  'pidgey.png',
#  'pidove.png',
#  'pikachu.png',
#  'pignite.png',
#  'pikipek.jpg',
#  'piloswine.png',
#  'pineco.png',
#  'pinsir.png',
#  'piplup.png',
#  'plusle.png',
#  'politoed.png',
#  'poliwag.png',
#  'poipole.jpg',
#  'poliwhirl.png',
#  'poliwrath.png',
#  'ponyta.png',
#  'poochyena.png',
#  'popplio.jpg',
#  'porygon.png',
#  'porygon2.png',
#  'porygon-z.png',
#  'primarina.jpg',
#  'primeape.png',
#  'prinplup.png',
#  'probopass.png',
#  'psyduck.png',
#  'pumpkaboo-average.png',
#  'pupitar.png',
#  'purrloin.png',
#  'purugly.png',
#  'pyroar.png',
#  'pyukumuku.jpg',
#  'quagsire.png',
#  'quilava.png',
#  'quilladin.png',
#  'qwilfish.png',
#  'raichu.png',
#  'raikou.png',
#  'ralts.png',
#  'rampardos.png',
#  'rapidash.png',
#  'raticate.png',
#  'rattata.png',
#  'rayquaza.png',
#  'regice.png',
#  'regigigas.png',
#  'regirock.png',
#  'registeel.png',
#  'relicanth.png',
#  'remoraid.png',
#  'reuniclus.png',
#  'reshiram.png',
#  'rhyhorn.png',
#  'rhydon.png',
#  'rhyperior.png',
#  'ribombee.jpg',
#  'riolu.png',
#  'rockruff.jpg',
#  'roggenrola.png',
#  'roselia.png',
#  'roserade.png',
#  'rotom.png',
#  'rowlet.jpg',
#  'rufflet.png',
#  'sableye.png',
#  'salamence.png',
#  'salandit.jpg',
#  'salazzle.jpg',
#  'samurott.png',
#  'sandshrew.png',
#  'sandile.png',
#  'dunsparce.png',
#  'eevee.png',
#  'ekans.png',
#  'electabuzz.png',
#  'electivire.png',
#  'electrode.png',
#  'electrike.png',
#  'emolga.png',
#  'sandslash.png',
#  'sandygast.jpg',
#  'sawk.png',
#  'sawsbuck.png',
#  'scatterbug.png',
#  'scizor.png',
#  'sceptile.png',
#  'scrafty.png',
#  'scraggy.png',
#  'scyther.png',
#  'seadra.png',
#  'sealeo.png',
#  'seaking.png',
#  'seedot.png',
#  'seel.png',
#  'seismitoad.png',
#  'sentret.png',
#  'serperior.png',
#  'servine.png',
#  'seviper.png',
#  'sewaddle.png',
#  'sharpedo.png',
#  'shaymin-land.png',
#  'shedinja.png',
#  'shelgon.png',
#  'shellos.png',
#  'shellder.png',
#  'shieldon.png',
#  'shelmet.png',
#  'shiftry.png',
#  'shiinotic.jpg',
#  'shinx.png',
#  'shroomish.png',
#  'shuckle.png',
#  'shuppet.png',
#  'sigilyph.png',
#  'silcoon.png',
#  'silvally.jpg',
#  'simipour.png',
#  'simisage.png',
#  'simisear.png',
#  'skarmory.png',
#  'skiploom.png',
#  'skiddo.png',
#  'skorupi.png',
#  'skitty.png',
#  'skrelp.png',
#  'skuntank.png',
#  'slaking.png',
#  'slakoth.png',
#  'sliggoo.png',
#  'slowbro.png',
#  'slowking.png',
#  'slowpoke.png',
#  'slugma.png',
#  'slurpuff.png',
#  'smoochum.png',
#  'sneasel.png',
#  'smeargle.png',
#  'snivy.png',
#  'snorunt.png',
#  'snorlax.png',
#  'snover.png',
#  'snubbull.png',
#  'solgaleo.jpg',
#  'solosis.png',
#  'solrock.png',
#  'spearow.png',
#  'spewpa.png',
#  'spheal.png',
#  'spinarak.png',
#  'spiritomb.png',
#  'spinda.png',
#  'spoink.png',
#  'spritzee.png',
#  'squirtle.png',
#  'stakataka.jpg',
#  'stantler.png',
#  'staraptor.png',
#  'staravia.png',
#  'starly.png',
#  'starmie.png',
#  'staryu.png',
#  'steelix.png',
#  'steenee.jpg',
#  'stoutland.png',
#  'stufful.jpg',
#  'stunfisk.png',
#  'stunky.png',
#  'sudowoodo.png',
#  'suicune.png',
#  'sunflora.png',
#  'sunkern.png',
#  'surskit.png',
#  'swablu.png',
#  'swadloon.png',
#  'swalot.png',
#  'swampert.png',
#  'swellow.png',
#  'swinub.png',
#  'swirlix.png',
#  'swanna.png',
#  'swoobat.png',
#  'sylveon.png',
#  'taillow.png',
#  'talonflame.png',
#  'tangela.png',
#  'tangrowth.png',
#  'tapu-bulu.jpg',
#  'tapu-fini.jpg',
#  'tapu-lele.jpg',
#  'tapu-koko.jpg',
#  'tauros.png',
#  'tentacool.png',
#  'teddiursa.png',
#  'tentacruel.png',
#  'tepig.png',
#  'terrakion.png',
#  'throh.png',
#  'thundurus-incarnate.png',
#  'timburr.png',
#  'tirtouga.png',
#  'togedemaru.jpg',
#  'togekiss.png',
#  'togetic.png',
#  'torchic.png',
#  'torkoal.png',
#  'tornadus-incarnate.png',
#  'torracat.jpg',
#  'torterra.png',
#  'totodile.png',
#  'toucannon.jpg',
#  'toxapex.jpg',
#  'toxicroak.png',
#  'tranquill.png',
#  'trevenant.png',
#  'treecko.png',
#  'tropius.png',
#  'trubbish.png',
#  'trumbeak.jpg',
#  'tsareena.jpg',
#  'turtonator.jpg',
#  'turtwig.png',
#  'tympole.png',
#  'type-null.jpg',
#  'tynamo.png',
#  'typhlosion.png',
#  'tyranitar.png',
#  'tyrantrum.png',
#  'tyrogue.png',
#  'tyrunt.png',
#  'umbreon.png',
#  'unown.png',
#  'unfezant.png',
#  'ursaring.png',
#  'uxie.png',
#  'vanillish.png',
#  'vanillite.png',
#  'vanilluxe.png',
#  'vaporeon.png',
#  'venipede.png',
#  'venonat.png',
#  'venomoth.png',
#  'vespiquen.png',
#  'venusaur.png',
#  'vibrava.png',
#  'victini.png',
#  'victreebel.png',
#  'vigoroth.png',
#  'vikavolt.jpg',
#  'virizion.png',
#  'vivillon.png',
#  'volbeat.png',
#  'volcanion.png',
#  'voltorb.png',
#  'vullaby.png',
#  'vulpix.png',
#  'wailmer.png',
#  'wailord.png',
#  'wartortle.png',
#  'watchog.png',
#  'weavile.png',
#  'weedle.png',
#  'weepinbell.png',
#  'weezing.png',
#  'whirlipede.png',
#  'whiscash.png',
#  'whismur.png',
#  'whimsicott.png',
#  'wigglytuff.png',
#  'wimpod.jpg',
#  'wishiwashi-solo.jpg',
#  'wingull.png',
#  'wobbuffet.png',
#  'wooper.png',
#  'woobat.png',
#  'wurmple.png',
#  'wormadam-plant.png',
#  'xerneas.png',
#  'xurkitree.jpg',
#  'wynaut.png',
#  'xatu.png',
#  'yanmega.png',
#  'yungoos.jpg',
#  'zebstrika.png',
#  'yamask.png',
#  'yveltal.png',
#  'zangoose.png',
#  'zapdos.png',
#  'zekrom.png',
#  'zeraora.jpg',
#  'zigzagoon.png',
#  'yanma.png',
#  'zorua.png',
#  'farfetchd.png',
#  'golem.png',
#  'gothita.png',
#  'haxorus.png',
#  'hoothoot.png',
#  'zoroark.png',
#  'zubat.png',
#  'zweilous.png',
#  'zygarde-50.png',
#  'espurr.png',
#  'golurk.png',
#  'honchkrow.png',
#  'jangmo-o.jpg',
#  'larvesta.png']

# %%
count=0
for i in l:
    directory=di[count].split(".")[0]
    count+=1
    path = os.path.join(curr, directory)
    os.mkdir(path)
    os.chdir(path)
    ind=0
    for j in i:
        i = Image.fromarray(j)
        i.save(directory+"."+str(ind)+".png")
        ind+=1

# %%
# %cd train
# Out:
# /content/drive/MyDrive/train

# %%
categories=os.listdir()
categories
# Out:
# ['conkeldurr',
#  'azelf',
#  'azurill',
#  'bagon',
#  'azumarill',
#  'baltoy',
#  'barbaracle',
#  'frillish',
#  'abra',
#  'accelgor',
#  'absol',
#  'anorith',
#  'aegislash-blade',
#  'ampharos',
#  'amoonguss',
#  'araquanid',
#  'aerodactyl',
#  'arbok',
#  'ambipom',
#  'aromatisse',
#  'ariados',
#  'archeops',
#  'armaldo',
#  'gourgeist-average',
#  'graveler',
#  'greninja',
#  'herdier',
#  'axew',
#  'chikorita',
#  'charizard',
#  'chespin',
#  'bellsprout',
#  'clamperl',
#  'budew',
#  'bergmite',
#  'carvanha',
#  'blitzle',
#  'chimchar',
#  'chimecho',
#  'cacturne',
#  'binacle',
#  'camerupt',
#  'carracosta',
#  'boldore',
#  'machamp',
#  'bruxish',
#  'cinccino',
#  'marowak',
#  'diglett',
#  'dewpider',
#  'chingling',
#  'blaziken',
#  'cherrim',
#  'mew',
#  'chansey',
#  'cascoon',
#  'lycanroc-midday',
#  'bidoof',
#  'blissey',
#  'bibarel',
#  'charmeleon',
#  'celesteela',
#  'drilbur',
#  'charjabug',
#  'chesnaught',
#  'dewott',
#  'chatot',
#  'dragonair',
#  'bewear',
#  'chinchou',
#  'drampa',
#  'dragalge',
#  'carnivine',
#  'dodrio',
#  'ditto',
#  'drifloon',
#  'dhelmise',
#  'dragonite',
#  'dratini',
#  'ducklett',
#  'musharna',
#  'drowzee',
#  'dugtrio',
#  'drapion',
#  'druddigon',
#  'dustox',
#  'elekid',
#  'duosion',
#  'dusknoir',
#  'durant',
#  'dusclops',
#  'dwebble',
#  'duskull',
#  'eelektrik',
#  'eelektross',
#  'elgyem',
#  'escavalier',
#  'empoleon',
#  'espeon',
#  'emboar',
#  'entei',
#  'excadrill',
#  'exeggcute',
#  'exeggutor',
#  'feebas',
#  'exploud',
#  'fearow',
#  'fennekin',
#  'feraligatr',
#  'ferroseed',
#  'finneon',
#  'ferrothorn',
#  'flaaffy',
#  'flabebe',
#  'flareon',
#  'fletchinder',
#  'fletchling',
#  'floatzel',
#  'floette',
#  'florges',
#  'flygon',
#  'fomantis',
#  'foongus',
#  'forretress',
#  'fraxure',
#  'froakie',
#  'frogadier',
#  'froslass',
#  'furret',
#  'furfrou',
#  'gabite',
#  'gallade',
#  'galvantula',
#  'garbodor',
#  'garchomp',
#  'gardevoir',
#  'gastly',
#  'gastrodon',
#  'genesect',
#  'gengar',
#  'geodude',
#  'gible',
#  'gigalith',
#  'girafarig',
#  'giratina-altered',
#  'glameow',
#  'glaceon',
#  'glalie',
#  'gligar',
#  'gliscor',
#  'abomasnow',
#  'gloom',
#  'gogoat',
#  'golbat',
#  'goldeen',
#  'aggron',
#  'aipom',
#  'alomomola',
#  'altaria',
#  'alakazam',
#  'arcanine',
#  'amaura',
#  'arceus',
#  'archen',
#  'aron',
#  'articuno',
#  'audino',
#  'avalugg',
#  'aurorus',
#  'golduck',
#  'goomy',
#  'goodra',
#  'gorebyss',
#  'golisopod',
#  'golett',
#  'gothitelle',
#  'gothorita',
#  'granbull',
#  'grimer',
#  'grotle',
#  'groudon',
#  'growlithe',
#  'grubbin',
#  'grovyle',
#  'grumpig',
#  'gulpin',
#  'gumshoos',
#  'gurdurr',
#  'guzzlord',
#  'gyarados',
#  'hakamo-o',
#  'happiny',
#  'hariyama',
#  'haunter',
#  'hawlucha',
#  'heatmor',
#  'heliolisk',
#  'heatran',
#  'heracross',
#  'helioptile',
#  'hippopotas',
#  'hippowdon',
#  'hitmonchan',
#  'hitmonlee',
#  'hitmontop',
#  'honedge',
#  'hoppip',
#  'hoopa-confined',
#  'horsea',
#  'ho-oh',
#  'houndour',
#  'houndoom',
#  'huntail',
#  'hypno',
#  'hydreigon',
#  'igglybuff',
#  'illumise',
#  'incineroar',
#  'infernape',
#  'inkay',
#  'ivysaur',
#  'jellicent',
#  'jigglypuff',
#  'jirachi',
#  'jolteon',
#  'joltik',
#  'jumpluff',
#  'jynx',
#  'kabuto',
#  'kabutops',
#  'kadabra',
#  'kakuna',
#  'kangaskhan',
#  'karrablast',
#  'kartana',
#  'kecleon',
#  'keldeo-ordinary',
#  'kingdra',
#  'kingler',
#  'kirlia',
#  'klang',
#  'klefki',
#  'klink',
#  'klinklang',
#  'koffing',
#  'komala',
#  'kommo-o',
#  'krabby',
#  'kricketot',
#  'kricketune',
#  'krokorok',
#  'krookodile',
#  'kyogre',
#  'kyurem',
#  'lairon',
#  'lampent',
#  'lanturn',
#  'landorus-incarnate',
#  'lapras',
#  'larvitar',
#  'latias',
#  'latios',
#  'leafeon',
#  'leavanny',
#  'ledian',
#  'ledyba',
#  'lickilicky',
#  'lickitung',
#  'liepard',
#  'lileep',
#  'linoone',
#  'litleo',
#  'lillipup',
#  'lilligant',
#  'litten',
#  'litwick',
#  'lombre',
#  'lopunny',
#  'lotad',
#  'banette',
#  'barboach',
#  'basculin-red-striped',
#  'bastiodon',
#  'bayleef',
#  'beartic',
#  'beautifly',
#  'beedrill',
#  'beheeyem',
#  'beldum',
#  'loudred',
#  'bellossom',
#  'lucario',
#  'bisharp',
#  'blacephalon',
#  'blastoise',
#  'bonsly',
#  'ludicolo',
#  'bouffalant',
#  'bounsweet',
#  'braixen',
#  'braviary',
#  'breloom',
#  'brionne',
#  'bronzong',
#  'bronzor',
#  'lugia',
#  'lumineon',
#  'lunala',
#  'lurantis',
#  'lunatone',
#  'luvdisc',
#  'luxray',
#  'luxio',
#  'bulbasaur',
#  'buizel',
#  'buneary',
#  'bunnelby',
#  'burmy',
#  'butterfree',
#  'buzzwole',
#  'cacnea',
#  'machoke',
#  'machop',
#  'magby',
#  'magcargo',
#  'magearna',
#  'carbink',
#  'magikarp',
#  'magmar',
#  'castform',
#  'caterpie',
#  'celebi',
#  'magmortar',
#  'magnemite',
#  'makuhita',
#  'magnezone',
#  'magneton',
#  'malamar',
#  'mamoswine',
#  'manaphy',
#  'manectric',
#  'mandibuzz',
#  'mankey',
#  'mantine',
#  'mantyke',
#  'maractus',
#  'mareanie',
#  'mareep',
#  'marill',
#  'marshadow',
#  'marshtomp',
#  'masquerain',
#  'chandelure',
#  'charmander',
#  'cherubi',
#  'medicham',
#  'mawile',
#  'meditite',
#  'meganium',
#  'melmetal',
#  'meloetta-aria',
#  'meltan',
#  'meowstic-male',
#  'meowth',
#  'mesprit',
#  'metagross',
#  'metang',
#  'metapod',
#  'clauncher',
#  'clawitzer',
#  'claydol',
#  'clefable',
#  'clefairy',
#  'cleffa',
#  'cloyster',
#  'cobalion',
#  'cofagrigus',
#  'combee',
#  'comfey',
#  'combusken',
#  'corphish',
#  'corsola',
#  'cosmoem',
#  'cosmog',
#  'cottonee',
#  'crabominable',
#  'crabrawler',
#  'cradily',
#  'cranidos',
#  'crawdaunt',
#  'cresselia',
#  'croagunk',
#  'croconaw',
#  'crobat',
#  'crustle',
#  'cryogonal',
#  'cubchoo',
#  'cutiefly',
#  'cubone',
#  'cyndaquil',
#  'darkrai',
#  'darmanitan-standard',
#  'dartrix',
#  'darumaka',
#  'decidueye',
#  'dedenne',
#  'deerling',
#  'deino',
#  'delcatty',
#  'delibird',
#  'delphox',
#  'deoxys-normal',
#  'dewgong',
#  'dialga',
#  'diancie',
#  'diggersby',
#  'mienfoo',
#  'mewtwo',
#  'mienshao',
#  'mightyena',
#  'milotic',
#  'miltank',
#  'mime-jr',
#  'mimikyu',
#  'minccino',
#  'minior-meteor',
#  'minun',
#  'misdreavus',
#  'mismagius',
#  'moltres',
#  'doduo',
#  'donphan',
#  'doublade',
#  'monferno',
#  'morelull',
#  'mothim',
#  'mr-mime',
#  'mudbray',
#  'mudkip',
#  'mudsdale',
#  'muk',
#  'munchlax',
#  'munna',
#  'murkrow',
#  'drifblim',
#  'naganadel',
#  'natu',
#  'necrozma',
#  'nidoking',
#  'nidoqueen',
#  'nidoran-f',
#  'nidoran-m',
#  'nidorina',
#  'nidorino',
#  'nihilego',
#  'nincada',
#  'ninetales',
#  'ninjask',
#  'noctowl',
#  'noibat',
#  'noivern',
#  'nosepass',
#  'numel',
#  'nuzleaf',
#  'octillery',
#  'oddish',
#  'omanyte',
#  'omastar',
#  'onix',
#  'oranguru',
#  'oricorio-baile',
#  'oshawott',
#  'pachirisu',
#  'palkia',
#  'palossand',
#  'palpitoad',
#  'pancham',
#  'panpour',
#  'pangoro',
#  'pansage',
#  'pansear',
#  'paras',
#  'parasect',
#  'passimian',
#  'patrat',
#  'pawniard',
#  'pelipper',
#  'persian',
#  'phanpy',
#  'petilil',
#  'phantump',
#  'pheromosa',
#  'pichu',
#  'phione',
#  'pidgeot',
#  'pidgeotto',
#  'pidgey',
#  'pidove',
#  'pikachu',
#  'pignite',
#  'pikipek',
#  'piloswine',
#  'pineco',
#  'pinsir',
#  'piplup',
#  'plusle',
#  'politoed',
#  'poliwag',
#  'poipole',
#  'poliwhirl',
#  'poliwrath',
#  'ponyta',
#  'poochyena',
#  'popplio',
#  'porygon',
#  'porygon2',
#  'porygon-z',
#  'primarina',
#  'primeape',
#  'prinplup',
#  'probopass',
#  'psyduck',
#  'pumpkaboo-average',
#  'pupitar',
#  'purrloin',
#  'purugly',
#  'pyroar',
#  'pyukumuku',
#  'quagsire',
#  'quilava',
#  'quilladin',
#  'qwilfish',
#  'raichu',
#  'raikou',
#  'ralts',
#  'rampardos',
#  'rapidash',
#  'raticate',
#  'rattata',
#  'rayquaza',
#  'regice',
#  'regigigas',
#  'regirock',
#  'registeel',
#  'relicanth',
#  'remoraid',
#  'reuniclus',
#  'reshiram',
#  'rhyhorn',
#  'rhydon',
#  'rhyperior',
#  'ribombee',
#  'riolu',
#  'rockruff',
#  'roggenrola',
#  'roselia',
#  'roserade',
#  'rotom',
#  'rowlet',
#  'rufflet',
#  'sableye',
#  'salamence',
#  'salandit',
#  'salazzle',
#  'samurott',
#  'sandshrew',
#  'sandile',
#  'dunsparce',
#  'eevee',
#  'ekans',
#  'electabuzz',
#  'electivire',
#  'electrode',
#  'electrike',
#  'emolga',
#  'sandslash',
#  'sandygast',
#  'sawk',
#  'sawsbuck',
#  'scatterbug',
#  'scizor',
#  'sceptile',
#  'scrafty',
#  'scraggy',
#  'scyther',
#  'seadra',
#  'sealeo',
#  'seaking',
#  'seedot',
#  'seel',
#  'seismitoad',
#  'sentret',
#  'serperior',
#  'servine',
#  'seviper',
#  'sewaddle',
#  'sharpedo',
#  'shaymin-land',
#  'shedinja',
#  'shelgon',
#  'shellos',
#  'shellder',
#  'shieldon',
#  'shelmet',
#  'shiftry',
#  'shiinotic',
#  'shinx',
#  'shroomish',
#  'shuckle',
#  'shuppet',
#  'sigilyph',
#  'silcoon',
#  'silvally',
#  'simipour',
#  'simisage',
#  'simisear',
#  'skarmory',
#  'skiploom',
#  'skiddo',
#  'skorupi',
#  'skitty',
#  'skrelp',
#  'skuntank',
#  'slaking',
#  'slakoth',
#  'sliggoo',
#  'slowbro',
#  'slowking',
#  'slowpoke',
#  'slugma',
#  'slurpuff',
#  'smoochum',
#  'sneasel',
#  'smeargle',
#  'snivy',
#  'snorunt',
#  'snorlax',
#  'snover',
#  'snubbull',
#  'solgaleo',
#  'solosis',
#  'solrock',
#  'spearow',
#  'spewpa',
#  'spheal',
#  'spinarak',
#  'spiritomb',
#  'spinda',
#  'spoink',
#  'spritzee',
#  'squirtle',
#  'stakataka',
#  'stantler',
#  'staraptor',
#  'staravia',
#  'starly',
#  'starmie',
#  'staryu',
#  'steelix',
#  'steenee',
#  'stoutland',
#  'stufful',
#  'stunfisk',
#  'stunky',
#  'sudowoodo',
#  'suicune',
#  'sunflora',
#  'sunkern',
#  'surskit',
#  'swablu',
#  'swadloon',
#  'swalot',
#  'swampert',
#  'swellow',
#  'swinub',
#  'swirlix',
#  'swanna',
#  'swoobat',
#  'sylveon',
#  'taillow',
#  'talonflame',
#  'tangela',
#  'tangrowth',
#  'tapu-bulu',
#  'tapu-fini',
#  'tapu-lele',
#  'tapu-koko',
#  'tauros',
#  'tentacool',
#  'teddiursa',
#  'tentacruel',
#  'tepig',
#  'terrakion',
#  'throh',
#  'thundurus-incarnate',
#  'timburr',
#  'tirtouga',
#  'togedemaru',
#  'togekiss',
#  'togetic',
#  'torchic',
#  'torkoal',
#  'tornadus-incarnate',
#  'torracat',
#  'torterra',
#  'totodile',
#  'toucannon',
#  'toxapex',
#  'toxicroak',
#  'tranquill',
#  'trevenant',
#  'treecko',
#  'tropius',
#  'trubbish',
#  'trumbeak',
#  'tsareena',
#  'turtonator',
#  'turtwig',
#  'tympole',
#  'type-null',
#  'tynamo',
#  'typhlosion',
#  'tyranitar',
#  'tyrantrum',
#  'tyrogue',
#  'tyrunt',
#  'umbreon',
#  'unown',
#  'unfezant',
#  'ursaring',
#  'uxie',
#  'vanillish',
#  'vanillite',
#  'vanilluxe',
#  'vaporeon',
#  'venipede',
#  'venonat',
#  'venomoth',
#  'vespiquen',
#  'venusaur',
#  'vibrava',
#  'victini',
#  'victreebel',
#  'vigoroth',
#  'vikavolt',
#  'virizion',
#  'vivillon',
#  'volbeat',
#  'volcanion',
#  'voltorb',
#  'vullaby',
#  'vulpix',
#  'wailmer',
#  'wailord',
#  'wartortle',
#  'watchog',
#  'weavile',
#  'weedle',
#  'weepinbell',
#  'weezing',
#  'whirlipede',
#  'whiscash',
#  'whismur',
#  'whimsicott',
#  'wigglytuff',
#  'wimpod',
#  'wishiwashi-solo',
#  'wingull',
#  'wobbuffet',
#  'wooper',
#  'woobat',
#  'wurmple',
#  'wormadam-plant',
#  'xerneas',
#  'xurkitree',
#  'wynaut',
#  'xatu',
#  'yanmega',
#  'yungoos',
#  'zebstrika',
#  'yamask',
#  'yveltal',
#  'zangoose',
#  'zapdos',
#  'zekrom',
#  'zeraora',
#  'zigzagoon',
#  'yanma',
#  'zorua',
#  'farfetchd',
#  'golem',
#  'gothita',
#  'haxorus',
#  'hoothoot',
#  'zoroark',
#  'zubat',
#  'zweilous',
#  'zygarde-50',
#  'espurr',
#  'golurk',
#  'honchkrow',
#  'jangmo-o',
#  'larvesta']

# %%
filenames=[]
cat=[]
for i in os.listdir(curr):
    path = os.path.join(curr, i)
    names=os.listdir(path)
    for j in names:
        filenames.append(j)
        cat.append(i)

# %%
filenames
# Out:
# ['conkeldurr.0.png',
#  'conkeldurr.1.png',
#  'conkeldurr.2.png',
#  'conkeldurr.3.png',
#  'conkeldurr.4.png',
#  'conkeldurr.5.png',
#  'conkeldurr.6.png',
#  'conkeldurr.7.png',
#  'conkeldurr.8.png',
#  'conkeldurr.9.png',
#  'conkeldurr.10.png',
#  'conkeldurr.11.png',
#  'conkeldurr.12.png',
#  'conkeldurr.13.png',
#  'conkeldurr.14.png',
#  'conkeldurr.15.png',
#  'conkeldurr.16.png',
#  'conkeldurr.17.png',
#  'conkeldurr.18.png',
#  'conkeldurr.19.png',
#  'conkeldurr.20.png',
#  'azelf.0.png',
#  'azelf.1.png',
#  'azelf.2.png',
#  'azelf.3.png',
#  'azelf.4.png',
#  'azelf.5.png',
#  'azelf.6.png',
#  'azelf.7.png',
#  'azelf.8.png',
#  'azelf.9.png',
#  'azelf.10.png',
#  'azelf.11.png',
#  'azelf.12.png',
#  'azelf.13.png',
#  'azelf.14.png',
#  'azelf.15.png',
#  'azelf.16.png',
#  'azelf.17.png',
#  'azelf.18.png',
#  'azelf.19.png',
#  'azelf.20.png',
#  'azurill.0.png',
#  'azurill.1.png',
#  'azurill.2.png',
#  'azurill.3.png',
#  'azurill.4.png',
#  'azurill.5.png',
#  'azurill.6.png',
#  'azurill.7.png',
#  'azurill.8.png',
#  'azurill.9.png',
#  'azurill.10.png',
#  'azurill.11.png',
#  'azurill.12.png',
#  'azurill.13.png',
#  'azurill.14.png',
#  'azurill.15.png',
#  'azurill.16.png',
#  'azurill.17.png',
#  'azurill.18.png',
#  'azurill.19.png',
#  'azurill.20.png',
#  'bagon.0.png',
#  'bagon.1.png',
#  'bagon.2.png',
#  'bagon.3.png',
#  'bagon.4.png',
#  'bagon.5.png',
#  'bagon.6.png',
#  'bagon.7.png',
#  'bagon.8.png',
#  'bagon.9.png',
#  'bagon.10.png',
#  'bagon.11.png',
#  'bagon.12.png',
#  'bagon.13.png',
#  'bagon.14.png',
#  'bagon.15.png',
#  'bagon.16.png',
#  'bagon.17.png',
#  'bagon.18.png',
#  'bagon.19.png',
#  'bagon.20.png',
#  'azumarill.0.png',
#  'azumarill.1.png',
#  'azumarill.2.png',
#  'azumarill.3.png',
#  'azumarill.4.png',
#  'azumarill.5.png',
#  'azumarill.6.png',
#  'azumarill.7.png',
#  'azumarill.8.png',
#  'azumarill.9.png',
#  'azumarill.10.png',
#  'azumarill.11.png',
#  'azumarill.12.png',
#  'azumarill.13.png',
#  'azumarill.14.png',
#  'azumarill.15.png',
#  'azumarill.16.png',
#  'azumarill.17.png',
#  'azumarill.18.png',
#  'azumarill.19.png',
#  'azumarill.20.png',
#  'baltoy.0.png',
#  'baltoy.1.png',
#  'baltoy.2.png',
#  'baltoy.3.png',
#  'baltoy.4.png',
#  'baltoy.5.png',
#  'baltoy.6.png',
#  'baltoy.7.png',
#  'baltoy.8.png',
#  'baltoy.9.png',
#  'baltoy.10.png',
#  'baltoy.11.png',
#  'baltoy.12.png',
#  'baltoy.13.png',
#  'baltoy.14.png',
#  'baltoy.15.png',
#  'baltoy.16.png',
#  'baltoy.17.png',
#  'baltoy.18.png',
#  'baltoy.19.png',
#  'baltoy.20.png',
#  'barbaracle.0.png',
#  'barbaracle.1.png',
#  'barbaracle.2.png',
#  'barbaracle.3.png',
#  'barbaracle.4.png',
#  'barbaracle.5.png',
#  'barbaracle.6.png',
#  'barbaracle.7.png',
#  'barbaracle.8.png',
#  'barbaracle.9.png',
#  'barbaracle.10.png',
#  'barbaracle.11.png',
#  'barbaracle.12.png',
#  'barbaracle.13.png',
#  'barbaracle.14.png',
#  'barbaracle.15.png',
#  'barbaracle.16.png',
#  'barbaracle.17.png',
#  'barbaracle.18.png',
#  'barbaracle.19.png',
#  'barbaracle.20.png',
#  'frillish.0.png',
#  'frillish.1.png',
#  'frillish.2.png',
#  'frillish.3.png',
#  'frillish.4.png',
#  'frillish.5.png',
#  'frillish.6.png',
#  'frillish.7.png',
#  'frillish.8.png',
#  'frillish.9.png',
#  'frillish.10.png',
#  'frillish.11.png',
#  'frillish.12.png',
#  'frillish.13.png',
#  'frillish.14.png',
#  'frillish.15.png',
#  'frillish.16.png',
#  'frillish.17.png',
#  'frillish.18.png',
#  'frillish.19.png',
#  'frillish.20.png',
#  'abra.0.png',
#  'abra.1.png',
#  'abra.2.png',
#  'abra.3.png',
#  'abra.4.png',
#  'abra.5.png',
#  'abra.6.png',
#  'abra.7.png',
#  'abra.8.png',
#  'abra.9.png',
#  'abra.10.png',
#  'abra.11.png',
#  'abra.12.png',
#  'abra.13.png',
#  'abra.14.png',
#  'abra.15.png',
#  'abra.16.png',
#  'abra.17.png',
#  'abra.18.png',
#  'abra.19.png',
#  'abra.20.png',
#  'accelgor.0.png',
#  'accelgor.1.png',
#  'accelgor.2.png',
#  'accelgor.3.png',
#  'accelgor.4.png',
#  'accelgor.5.png',
#  'accelgor.6.png',
#  'accelgor.7.png',
#  'accelgor.8.png',
#  'accelgor.9.png',
#  'accelgor.10.png',
#  'accelgor.11.png',
#  'accelgor.12.png',
#  'accelgor.13.png',
#  'accelgor.14.png',
#  'accelgor.15.png',
#  'accelgor.16.png',
#  'accelgor.17.png',
#  'accelgor.18.png',
#  'accelgor.19.png',
#  'accelgor.20.png',
#  'absol.0.png',
#  'absol.1.png',
#  'absol.2.png',
#  'absol.3.png',
#  'absol.4.png',
#  'absol.5.png',
#  'absol.6.png',
#  'absol.7.png',
#  'absol.8.png',
#  'absol.9.png',
#  'absol.10.png',
#  'absol.11.png',
#  'absol.12.png',
#  'absol.13.png',
#  'absol.14.png',
#  'absol.15.png',
#  'absol.16.png',
#  'absol.17.png',
#  'absol.18.png',
#  'absol.19.png',
#  'absol.20.png',
#  'anorith.0.png',
#  'anorith.1.png',
#  'anorith.2.png',
#  'anorith.3.png',
#  'anorith.4.png',
#  'anorith.5.png',
#  'anorith.6.png',
#  'anorith.7.png',
#  'anorith.8.png',
#  'anorith.9.png',
#  'anorith.10.png',
#  'anorith.11.png',
#  'anorith.12.png',
#  'anorith.13.png',
#  'anorith.14.png',
#  'anorith.15.png',
#  'anorith.16.png',
#  'anorith.17.png',
#  'anorith.18.png',
#  'anorith.19.png',
#  'anorith.20.png',
#  'aegislash-blade.0.png',
#  'aegislash-blade.1.png',
#  'aegislash-blade.2.png',
#  'aegislash-blade.3.png',
#  'aegislash-blade.4.png',
#  'aegislash-blade.5.png',
#  'aegislash-blade.6.png',
#  'aegislash-blade.7.png',
#  'aegislash-blade.8.png',
#  'aegislash-blade.9.png',
#  'aegislash-blade.10.png',
#  'aegislash-blade.11.png',
#  'aegislash-blade.12.png',
#  'aegislash-blade.13.png',
#  'aegislash-blade.14.png',
#  'aegislash-blade.15.png',
#  'aegislash-blade.16.png',
#  'aegislash-blade.17.png',
#  'aegislash-blade.18.png',
#  'aegislash-blade.19.png',
#  'aegislash-blade.20.png',
#  'ampharos.0.png',
#  'ampharos.1.png',
#  'ampharos.2.png',
#  'ampharos.3.png',
#  'ampharos.4.png',
#  'ampharos.5.png',
#  'ampharos.6.png',
#  'ampharos.7.png',
#  'ampharos.8.png',
#  'ampharos.9.png',
#  'ampharos.10.png',
#  'ampharos.11.png',
#  'ampharos.12.png',
#  'ampharos.13.png',
#  'ampharos.14.png',
#  'ampharos.15.png',
#  'ampharos.16.png',
#  'ampharos.17.png',
#  'ampharos.18.png',
#  'ampharos.19.png',
#  'ampharos.20.png',
#  'amoonguss.0.png',
#  'amoonguss.1.png',
#  'amoonguss.2.png',
#  'amoonguss.3.png',
#  'amoonguss.4.png',
#  'amoonguss.5.png',
#  'amoonguss.6.png',
#  'amoonguss.7.png',
#  'amoonguss.8.png',
#  'amoonguss.9.png',
#  'amoonguss.10.png',
#  'amoonguss.11.png',
#  'amoonguss.12.png',
#  'amoonguss.13.png',
#  'amoonguss.14.png',
#  'amoonguss.15.png',
#  'amoonguss.16.png',
#  'amoonguss.17.png',
#  'amoonguss.18.png',
#  'amoonguss.19.png',
#  'amoonguss.20.png',
#  'araquanid.0.png',
#  'araquanid.1.png',
#  'araquanid.2.png',
#  'araquanid.3.png',
#  'araquanid.4.png',
#  'araquanid.5.png',
#  'araquanid.6.png',
#  'araquanid.7.png',
#  'araquanid.8.png',
#  'araquanid.9.png',
#  'araquanid.10.png',
#  'araquanid.11.png',
#  'araquanid.12.png',
#  'araquanid.13.png',
#  'araquanid.14.png',
#  'araquanid.15.png',
#  'araquanid.16.png',
#  'araquanid.17.png',
#  'araquanid.18.png',
#  'araquanid.19.png',
#  'araquanid.20.png',
#  'aerodactyl.0.png',
#  'aerodactyl.1.png',
#  'aerodactyl.2.png',
#  'aerodactyl.3.png',
#  'aerodactyl.4.png',
#  'aerodactyl.5.png',
#  'aerodactyl.6.png',
#  'aerodactyl.7.png',
#  'aerodactyl.8.png',
#  'aerodactyl.9.png',
#  'aerodactyl.10.png',
#  'aerodactyl.11.png',
#  'aerodactyl.12.png',
#  'aerodactyl.13.png',
#  'aerodactyl.14.png',
#  'aerodactyl.15.png',
#  'aerodactyl.16.png',
#  'aerodactyl.17.png',
#  'aerodactyl.18.png',
#  'aerodactyl.19.png',
#  'aerodactyl.20.png',
#  'arbok.0.png',
#  'arbok.1.png',
#  'arbok.2.png',
#  'arbok.3.png',
#  'arbok.4.png',
#  'arbok.5.png',
#  'arbok.6.png',
#  'arbok.7.png',
#  'arbok.8.png',
#  'arbok.9.png',
#  'arbok.10.png',
#  'arbok.11.png',
#  'arbok.12.png',
#  'arbok.13.png',
#  'arbok.14.png',
#  'arbok.15.png',
#  'arbok.16.png',
#  'arbok.17.png',
#  'arbok.18.png',
#  'arbok.19.png',
#  'arbok.20.png',
#  'ambipom.0.png',
#  'ambipom.1.png',
#  'ambipom.2.png',
#  'ambipom.3.png',
#  'ambipom.4.png',
#  'ambipom.5.png',
#  'ambipom.6.png',
#  'ambipom.7.png',
#  'ambipom.8.png',
#  'ambipom.9.png',
#  'ambipom.10.png',
#  'ambipom.11.png',
#  'ambipom.12.png',
#  'ambipom.13.png',
#  'ambipom.14.png',
#  'ambipom.15.png',
#  'ambipom.16.png',
#  'ambipom.17.png',
#  'ambipom.18.png',
#  'ambipom.19.png',
#  'ambipom.20.png',
#  'aromatisse.0.png',
#  'aromatisse.1.png',
#  'aromatisse.2.png',
#  'aromatisse.3.png',
#  'aromatisse.4.png',
#  'aromatisse.5.png',
#  'aromatisse.6.png',
#  'aromatisse.7.png',
#  'aromatisse.8.png',
#  'aromatisse.9.png',
#  'aromatisse.10.png',
#  'aromatisse.11.png',
#  'aromatisse.12.png',
#  'aromatisse.13.png',
#  'aromatisse.14.png',
#  'aromatisse.15.png',
#  'aromatisse.16.png',
#  'aromatisse.17.png',
#  'aromatisse.18.png',
#  'aromatisse.19.png',
#  'aromatisse.20.png',
#  'ariados.0.png',
#  'ariados.1.png',
#  'ariados.2.png',
#  'ariados.3.png',
#  'ariados.4.png',
#  'ariados.5.png',
#  'ariados.6.png',
#  'ariados.7.png',
#  'ariados.8.png',
#  'ariados.9.png',
#  'ariados.10.png',
#  'ariados.11.png',
#  'ariados.12.png',
#  'ariados.13.png',
#  'ariados.14.png',
#  'ariados.15.png',
#  'ariados.16.png',
#  'ariados.17.png',
#  'ariados.18.png',
#  'ariados.19.png',
#  'ariados.20.png',
#  'archeops.0.png',
#  'archeops.1.png',
#  'archeops.2.png',
#  'archeops.3.png',
#  'archeops.4.png',
#  'archeops.5.png',
#  'archeops.6.png',
#  'archeops.7.png',
#  'archeops.8.png',
#  'archeops.9.png',
#  'archeops.10.png',
#  'archeops.11.png',
#  'archeops.12.png',
#  'archeops.13.png',
#  'archeops.14.png',
#  'archeops.15.png',
#  'archeops.16.png',
#  'archeops.17.png',
#  'archeops.18.png',
#  'archeops.19.png',
#  'archeops.20.png',
#  'armaldo.0.png',
#  'armaldo.1.png',
#  'armaldo.2.png',
#  'armaldo.3.png',
#  'armaldo.4.png',
#  'armaldo.5.png',
#  'armaldo.6.png',
#  'armaldo.7.png',
#  'armaldo.8.png',
#  'armaldo.9.png',
#  'armaldo.10.png',
#  'armaldo.11.png',
#  'armaldo.12.png',
#  'armaldo.13.png',
#  'armaldo.14.png',
#  'armaldo.15.png',
#  'armaldo.16.png',
#  'armaldo.17.png',
#  'armaldo.18.png',
#  'armaldo.19.png',
#  'armaldo.20.png',
#  'gourgeist-average.0.png',
#  'gourgeist-average.1.png',
#  'gourgeist-average.2.png',
#  'gourgeist-average.3.png',
#  'gourgeist-average.4.png',
#  'gourgeist-average.5.png',
#  'gourgeist-average.6.png',
#  'gourgeist-average.7.png',
#  'gourgeist-average.8.png',
#  'gourgeist-average.9.png',
#  'gourgeist-average.10.png',
#  'gourgeist-average.11.png',
#  'gourgeist-average.12.png',
#  'gourgeist-average.13.png',
#  'gourgeist-average.14.png',
#  'gourgeist-average.15.png',
#  'gourgeist-average.16.png',
#  'gourgeist-average.17.png',
#  'gourgeist-average.18.png',
#  'gourgeist-average.19.png',
#  'gourgeist-average.20.png',
#  'graveler.0.png',
#  'graveler.1.png',
#  'graveler.2.png',
#  'graveler.3.png',
#  'graveler.4.png',
#  'graveler.5.png',
#  'graveler.6.png',
#  'graveler.7.png',
#  'graveler.8.png',
#  'graveler.9.png',
#  'graveler.10.png',
#  'graveler.11.png',
#  'graveler.12.png',
#  'graveler.13.png',
#  'graveler.14.png',
#  'graveler.15.png',
#  'graveler.16.png',
#  'graveler.17.png',
#  'graveler.18.png',
#  'graveler.19.png',
#  'graveler.20.png',
#  'greninja.0.png',
#  'greninja.1.png',
#  'greninja.2.png',
#  'greninja.3.png',
#  'greninja.4.png',
#  'greninja.5.png',
#  'greninja.6.png',
#  'greninja.7.png',
#  'greninja.8.png',
#  'greninja.9.png',
#  'greninja.10.png',
#  'greninja.11.png',
#  'greninja.12.png',
#  'greninja.13.png',
#  'greninja.14.png',
#  'greninja.15.png',
#  'greninja.16.png',
#  'greninja.17.png',
#  'greninja.18.png',
#  'greninja.19.png',
#  'greninja.20.png',
#  'herdier.0.png',
#  'herdier.1.png',
#  'herdier.2.png',
#  'herdier.3.png',
#  'herdier.4.png',
#  'herdier.5.png',
#  'herdier.6.png',
#  'herdier.7.png',
#  'herdier.8.png',
#  'herdier.9.png',
#  'herdier.10.png',
#  'herdier.11.png',
#  'herdier.12.png',
#  'herdier.13.png',
#  'herdier.14.png',
#  'herdier.15.png',
#  'herdier.16.png',
#  'herdier.17.png',
#  'herdier.18.png',
#  'herdier.19.png',
#  'herdier.20.png',
#  'axew.0.png',
#  'axew.1.png',
#  'axew.2.png',
#  'axew.3.png',
#  'axew.4.png',
#  'axew.5.png',
#  'axew.6.png',
#  'axew.7.png',
#  'axew.8.png',
#  'axew.9.png',
#  'axew.10.png',
#  'axew.11.png',
#  'axew.12.png',
#  'axew.13.png',
#  'axew.14.png',
#  'axew.15.png',
#  'axew.16.png',
#  'axew.17.png',
#  'axew.18.png',
#  'axew.19.png',
#  'axew.20.png',
#  'chikorita.0.png',
#  'chikorita.1.png',
#  'chikorita.2.png',
#  'chikorita.3.png',
#  'chikorita.4.png',
#  'chikorita.5.png',
#  'chikorita.6.png',
#  'chikorita.7.png',
#  'chikorita.8.png',
#  'chikorita.9.png',
#  'chikorita.10.png',
#  'chikorita.11.png',
#  'chikorita.12.png',
#  'chikorita.13.png',
#  'chikorita.14.png',
#  'chikorita.15.png',
#  'chikorita.16.png',
#  'chikorita.17.png',
#  'chikorita.18.png',
#  'chikorita.19.png',
#  'chikorita.20.png',
#  'charizard.0.png',
#  'charizard.1.png',
#  'charizard.2.png',
#  'charizard.3.png',
#  'charizard.4.png',
#  'charizard.5.png',
#  'charizard.6.png',
#  'charizard.7.png',
#  'charizard.8.png',
#  'charizard.9.png',
#  'charizard.10.png',
#  'charizard.11.png',
#  'charizard.12.png',
#  'charizard.13.png',
#  'charizard.14.png',
#  'charizard.15.png',
#  'charizard.16.png',
#  'charizard.17.png',
#  'charizard.18.png',
#  'charizard.19.png',
#  'charizard.20.png',
#  'chespin.0.png',
#  'chespin.1.png',
#  'chespin.2.png',
#  'chespin.3.png',
#  'chespin.4.png',
#  'chespin.5.png',
#  'chespin.6.png',
#  'chespin.7.png',
#  'chespin.8.png',
#  'chespin.9.png',
#  'chespin.10.png',
#  'chespin.11.png',
#  'chespin.12.png',
#  'chespin.13.png',
#  'chespin.14.png',
#  'chespin.15.png',
#  'chespin.16.png',
#  'chespin.17.png',
#  'chespin.18.png',
#  'chespin.19.png',
#  'chespin.20.png',
#  'bellsprout.0.png',
#  'bellsprout.1.png',
#  'bellsprout.2.png',
#  'bellsprout.3.png',
#  'bellsprout.4.png',
#  'bellsprout.5.png',
#  'bellsprout.6.png',
#  'bellsprout.7.png',
#  'bellsprout.8.png',
#  'bellsprout.9.png',
#  'bellsprout.10.png',
#  'bellsprout.11.png',
#  'bellsprout.12.png',
#  'bellsprout.13.png',
#  'bellsprout.14.png',
#  'bellsprout.15.png',
#  'bellsprout.16.png',
#  'bellsprout.17.png',
#  'bellsprout.18.png',
#  'bellsprout.19.png',
#  'bellsprout.20.png',
#  'clamperl.0.png',
#  'clamperl.1.png',
#  'clamperl.2.png',
#  'clamperl.3.png',
#  'clamperl.4.png',
#  'clamperl.5.png',
#  'clamperl.6.png',
#  'clamperl.7.png',
#  'clamperl.8.png',
#  'clamperl.9.png',
#  'clamperl.10.png',
#  'clamperl.11.png',
#  'clamperl.12.png',
#  'clamperl.13.png',
#  'clamperl.14.png',
#  'clamperl.15.png',
#  'clamperl.16.png',
#  'clamperl.17.png',
#  'clamperl.18.png',
#  'clamperl.19.png',
#  'clamperl.20.png',
#  'budew.0.png',
#  'budew.1.png',
#  'budew.2.png',
#  'budew.3.png',
#  'budew.4.png',
#  'budew.5.png',
#  'budew.6.png',
#  'budew.7.png',
#  'budew.8.png',
#  'budew.9.png',
#  'budew.10.png',
#  'budew.11.png',
#  'budew.12.png',
#  'budew.13.png',
#  'budew.14.png',
#  'budew.15.png',
#  'budew.16.png',
#  'budew.17.png',
#  'budew.18.png',
#  'budew.19.png',
#  'budew.20.png',
#  'bergmite.0.png',
#  'bergmite.1.png',
#  'bergmite.2.png',
#  'bergmite.3.png',
#  'bergmite.4.png',
#  'bergmite.5.png',
#  'bergmite.6.png',
#  'bergmite.7.png',
#  'bergmite.8.png',
#  'bergmite.9.png',
#  'bergmite.10.png',
#  'bergmite.11.png',
#  'bergmite.12.png',
#  'bergmite.13.png',
#  'bergmite.14.png',
#  'bergmite.15.png',
#  'bergmite.16.png',
#  'bergmite.17.png',
#  'bergmite.18.png',
#  'bergmite.19.png',
#  'bergmite.20.png',
#  'carvanha.0.png',
#  'carvanha.1.png',
#  'carvanha.2.png',
#  'carvanha.3.png',
#  'carvanha.4.png',
#  'carvanha.5.png',
#  'carvanha.6.png',
#  'carvanha.7.png',
#  'carvanha.8.png',
#  'carvanha.9.png',
#  'carvanha.10.png',
#  'carvanha.11.png',
#  'carvanha.12.png',
#  'carvanha.13.png',
#  'carvanha.14.png',
#  'carvanha.15.png',
#  'carvanha.16.png',
#  'carvanha.17.png',
#  'carvanha.18.png',
#  'carvanha.19.png',
#  'carvanha.20.png',
#  'blitzle.0.png',
#  'blitzle.1.png',
#  'blitzle.2.png',
#  'blitzle.3.png',
#  'blitzle.4.png',
#  'blitzle.5.png',
#  'blitzle.6.png',
#  'blitzle.7.png',
#  'blitzle.8.png',
#  'blitzle.9.png',
#  'blitzle.10.png',
#  'blitzle.11.png',
#  'blitzle.12.png',
#  'blitzle.13.png',
#  'blitzle.14.png',
#  'blitzle.15.png',
#  'blitzle.16.png',
#  'blitzle.17.png',
#  'blitzle.18.png',
#  'blitzle.19.png',
#  'blitzle.20.png',
#  'chimchar.0.png',
#  'chimchar.1.png',
#  'chimchar.2.png',
#  'chimchar.3.png',
#  'chimchar.4.png',
#  'chimchar.5.png',
#  'chimchar.6.png',
#  'chimchar.7.png',
#  'chimchar.8.png',
#  'chimchar.9.png',
#  'chimchar.10.png',
#  'chimchar.11.png',
#  'chimchar.12.png',
#  'chimchar.13.png',
#  'chimchar.14.png',
#  'chimchar.15.png',
#  'chimchar.16.png',
#  'chimchar.17.png',
#  'chimchar.18.png',
#  'chimchar.19.png',
#  'chimchar.20.png',
#  'chimecho.0.png',
#  'chimecho.1.png',
#  'chimecho.2.png',
#  'chimecho.3.png',
#  'chimecho.4.png',
#  'chimecho.5.png',
#  'chimecho.6.png',
#  'chimecho.7.png',
#  'chimecho.8.png',
#  'chimecho.9.png',
#  'chimecho.10.png',
#  'chimecho.11.png',
#  'chimecho.12.png',
#  'chimecho.13.png',
#  'chimecho.14.png',
#  'chimecho.15.png',
#  'chimecho.16.png',
#  'chimecho.17.png',
#  'chimecho.18.png',
#  'chimecho.19.png',
#  'chimecho.20.png',
#  'cacturne.0.png',
#  'cacturne.1.png',
#  'cacturne.2.png',
#  'cacturne.3.png',
#  'cacturne.4.png',
#  'cacturne.5.png',
#  'cacturne.6.png',
#  'cacturne.7.png',
#  'cacturne.8.png',
#  'cacturne.9.png',
#  'cacturne.10.png',
#  'cacturne.11.png',
#  'cacturne.12.png',
#  'cacturne.13.png',
#  'cacturne.14.png',
#  'cacturne.15.png',
#  'cacturne.16.png',
#  'cacturne.17.png',
#  'cacturne.18.png',
#  'cacturne.19.png',
#  'cacturne.20.png',
#  'binacle.0.png',
#  'binacle.1.png',
#  'binacle.2.png',
#  'binacle.3.png',
#  'binacle.4.png',
#  'binacle.5.png',
#  'binacle.6.png',
#  'binacle.7.png',
#  'binacle.8.png',
#  'binacle.9.png',
#  'binacle.10.png',
#  'binacle.11.png',
#  'binacle.12.png',
#  'binacle.13.png',
#  'binacle.14.png',
#  'binacle.15.png',
#  'binacle.16.png',
#  'binacle.17.png',
#  'binacle.18.png',
#  'binacle.19.png',
#  'binacle.20.png',
#  'camerupt.0.png',
#  'camerupt.1.png',
#  'camerupt.2.png',
#  'camerupt.3.png',
#  'camerupt.4.png',
#  'camerupt.5.png',
#  'camerupt.6.png',
#  'camerupt.7.png',
#  'camerupt.8.png',
#  'camerupt.9.png',
#  'camerupt.10.png',
#  'camerupt.11.png',
#  'camerupt.12.png',
#  'camerupt.13.png',
#  'camerupt.14.png',
#  'camerupt.15.png',
#  'camerupt.16.png',
#  'camerupt.17.png',
#  'camerupt.18.png',
#  'camerupt.19.png',
#  'camerupt.20.png',
#  'carracosta.0.png',
#  'carracosta.1.png',
#  'carracosta.2.png',
#  'carracosta.3.png',
#  'carracosta.4.png',
#  'carracosta.5.png',
#  'carracosta.6.png',
#  'carracosta.7.png',
#  'carracosta.8.png',
#  'carracosta.9.png',
#  'carracosta.10.png',
#  'carracosta.11.png',
#  'carracosta.12.png',
#  'carracosta.13.png',
#  'carracosta.14.png',
#  'carracosta.15.png',
#  'carracosta.16.png',
#  'carracosta.17.png',
#  'carracosta.18.png',
#  'carracosta.19.png',
#  'carracosta.20.png',
#  'boldore.0.png',
#  'boldore.1.png',
#  'boldore.2.png',
#  'boldore.3.png',
#  'boldore.4.png',
#  'boldore.5.png',
#  'boldore.6.png',
#  'boldore.7.png',
#  'boldore.8.png',
#  'boldore.9.png',
#  'boldore.10.png',
#  'boldore.11.png',
#  'boldore.12.png',
#  'boldore.13.png',
#  'boldore.14.png',
#  'boldore.15.png',
#  'boldore.16.png',
#  'boldore.17.png',
#  'boldore.18.png',
#  'boldore.19.png',
#  'boldore.20.png',
#  'machamp.0.png',
#  'machamp.1.png',
#  'machamp.2.png',
#  'machamp.3.png',
#  'machamp.4.png',
#  'machamp.5.png',
#  'machamp.6.png',
#  'machamp.7.png',
#  'machamp.8.png',
#  'machamp.9.png',
#  'machamp.10.png',
#  'machamp.11.png',
#  'machamp.12.png',
#  'machamp.13.png',
#  'machamp.14.png',
#  'machamp.15.png',
#  'machamp.16.png',
#  'machamp.17.png',
#  'machamp.18.png',
#  'machamp.19.png',
#  'machamp.20.png',
#  'bruxish.0.png',
#  'bruxish.1.png',
#  'bruxish.2.png',
#  'bruxish.3.png',
#  'bruxish.4.png',
#  'bruxish.5.png',
#  'bruxish.6.png',
#  'bruxish.7.png',
#  'bruxish.8.png',
#  'bruxish.9.png',
#  'bruxish.10.png',
#  'bruxish.11.png',
#  'bruxish.12.png',
#  'bruxish.13.png',
#  'bruxish.14.png',
#  'bruxish.15.png',
#  'bruxish.16.png',
#  'bruxish.17.png',
#  'bruxish.18.png',
#  'bruxish.19.png',
#  'bruxish.20.png',
#  'cinccino.0.png',
#  'cinccino.1.png',
#  'cinccino.2.png',
#  'cinccino.3.png',
#  'cinccino.4.png',
#  'cinccino.5.png',
#  'cinccino.6.png',
#  'cinccino.7.png',
#  'cinccino.8.png',
#  'cinccino.9.png',
#  'cinccino.10.png',
#  'cinccino.11.png',
#  'cinccino.12.png',
#  'cinccino.13.png',
#  'cinccino.14.png',
#  'cinccino.15.png',
#  'cinccino.16.png',
#  'cinccino.17.png',
#  'cinccino.18.png',
#  'cinccino.19.png',
#  'cinccino.20.png',
#  'marowak.0.png',
#  'marowak.1.png',
#  'marowak.2.png',
#  'marowak.3.png',
#  'marowak.4.png',
#  'marowak.5.png',
#  'marowak.6.png',
#  'marowak.7.png',
#  'marowak.8.png',
#  'marowak.9.png',
#  'marowak.10.png',
#  'marowak.11.png',
#  'marowak.12.png',
#  ...]

# %%
len(filenames)
# Out:
# 16863

# %%
cat
# Out:
# ['conkeldurr',
#  'conkeldurr',
#  'conkeldurr',
#  'conkeldurr',
#  'conkeldurr',
#  'conkeldurr',
#  'conkeldurr',
#  'conkeldurr',
#  'conkeldurr',
#  'conkeldurr',
#  'conkeldurr',
#  'conkeldurr',
#  'conkeldurr',
#  'conkeldurr',
#  'conkeldurr',
#  'conkeldurr',
#  'conkeldurr',
#  'conkeldurr',
#  'conkeldurr',
#  'conkeldurr',
#  'conkeldurr',
#  'azelf',
#  'azelf',
#  'azelf',
#  'azelf',
#  'azelf',
#  'azelf',
#  'azelf',
#  'azelf',
#  'azelf',
#  'azelf',
#  'azelf',
#  'azelf',
#  'azelf',
#  'azelf',
#  'azelf',
#  'azelf',
#  'azelf',
#  'azelf',
#  'azelf',
#  'azelf',
#  'azelf',
#  'azurill',
#  'azurill',
#  'azurill',
#  'azurill',
#  'azurill',
#  'azurill',
#  'azurill',
#  'azurill',
#  'azurill',
#  'azurill',
#  'azurill',
#  'azurill',
#  'azurill',
#  'azurill',
#  'azurill',
#  'azurill',
#  'azurill',
#  'azurill',
#  'azurill',
#  'azurill',
#  'azurill',
#  'bagon',
#  'bagon',
#  'bagon',
#  'bagon',
#  'bagon',
#  'bagon',
#  'bagon',
#  'bagon',
#  'bagon',
#  'bagon',
#  'bagon',
#  'bagon',
#  'bagon',
#  'bagon',
#  'bagon',
#  'bagon',
#  'bagon',
#  'bagon',
#  'bagon',
#  'bagon',
#  'bagon',
#  'azumarill',
#  'azumarill',
#  'azumarill',
#  'azumarill',
#  'azumarill',
#  'azumarill',
#  'azumarill',
#  'azumarill',
#  'azumarill',
#  'azumarill',
#  'azumarill',
#  'azumarill',
#  'azumarill',
#  'azumarill',
#  'azumarill',
#  'azumarill',
#  'azumarill',
#  'azumarill',
#  'azumarill',
#  'azumarill',
#  'azumarill',
#  'baltoy',
#  'baltoy',
#  'baltoy',
#  'baltoy',
#  'baltoy',
#  'baltoy',
#  'baltoy',
#  'baltoy',
#  'baltoy',
#  'baltoy',
#  'baltoy',
#  'baltoy',
#  'baltoy',
#  'baltoy',
#  'baltoy',
#  'baltoy',
#  'baltoy',
#  'baltoy',
#  'baltoy',
#  'baltoy',
#  'baltoy',
#  'barbaracle',
#  'barbaracle',
#  'barbaracle',
#  'barbaracle',
#  'barbaracle',
#  'barbaracle',
#  'barbaracle',
#  'barbaracle',
#  'barbaracle',
#  'barbaracle',
#  'barbaracle',
#  'barbaracle',
#  'barbaracle',
#  'barbaracle',
#  'barbaracle',
#  'barbaracle',
#  'barbaracle',
#  'barbaracle',
#  'barbaracle',
#  'barbaracle',
#  'barbaracle',
#  'frillish',
#  'frillish',
#  'frillish',
#  'frillish',
#  'frillish',
#  'frillish',
#  'frillish',
#  'frillish',
#  'frillish',
#  'frillish',
#  'frillish',
#  'frillish',
#  'frillish',
#  'frillish',
#  'frillish',
#  'frillish',
#  'frillish',
#  'frillish',
#  'frillish',
#  'frillish',
#  'frillish',
#  'abra',
#  'abra',
#  'abra',
#  'abra',
#  'abra',
#  'abra',
#  'abra',
#  'abra',
#  'abra',
#  'abra',
#  'abra',
#  'abra',
#  'abra',
#  'abra',
#  'abra',
#  'abra',
#  'abra',
#  'abra',
#  'abra',
#  'abra',
#  'abra',
#  'accelgor',
#  'accelgor',
#  'accelgor',
#  'accelgor',
#  'accelgor',
#  'accelgor',
#  'accelgor',
#  'accelgor',
#  'accelgor',
#  'accelgor',
#  'accelgor',
#  'accelgor',
#  'accelgor',
#  'accelgor',
#  'accelgor',
#  'accelgor',
#  'accelgor',
#  'accelgor',
#  'accelgor',
#  'accelgor',
#  'accelgor',
#  'absol',
#  'absol',
#  'absol',
#  'absol',
#  'absol',
#  'absol',
#  'absol',
#  'absol',
#  'absol',
#  'absol',
#  'absol',
#  'absol',
#  'absol',
#  'absol',
#  'absol',
#  'absol',
#  'absol',
#  'absol',
#  'absol',
#  'absol',
#  'absol',
#  'anorith',
#  'anorith',
#  'anorith',
#  'anorith',
#  'anorith',
#  'anorith',
#  'anorith',
#  'anorith',
#  'anorith',
#  'anorith',
#  'anorith',
#  'anorith',
#  'anorith',
#  'anorith',
#  'anorith',
#  'anorith',
#  'anorith',
#  'anorith',
#  'anorith',
#  'anorith',
#  'anorith',
#  'aegislash-blade',
#  'aegislash-blade',
#  'aegislash-blade',
#  'aegislash-blade',
#  'aegislash-blade',
#  'aegislash-blade',
#  'aegislash-blade',
#  'aegislash-blade',
#  'aegislash-blade',
#  'aegislash-blade',
#  'aegislash-blade',
#  'aegislash-blade',
#  'aegislash-blade',
#  'aegislash-blade',
#  'aegislash-blade',
#  'aegislash-blade',
#  'aegislash-blade',
#  'aegislash-blade',
#  'aegislash-blade',
#  'aegislash-blade',
#  'aegislash-blade',
#  'ampharos',
#  'ampharos',
#  'ampharos',
#  'ampharos',
#  'ampharos',
#  'ampharos',
#  'ampharos',
#  'ampharos',
#  'ampharos',
#  'ampharos',
#  'ampharos',
#  'ampharos',
#  'ampharos',
#  'ampharos',
#  'ampharos',
#  'ampharos',
#  'ampharos',
#  'ampharos',
#  'ampharos',
#  'ampharos',
#  'ampharos',
#  'amoonguss',
#  'amoonguss',
#  'amoonguss',
#  'amoonguss',
#  'amoonguss',
#  'amoonguss',
#  'amoonguss',
#  'amoonguss',
#  'amoonguss',
#  'amoonguss',
#  'amoonguss',
#  'amoonguss',
#  'amoonguss',
#  'amoonguss',
#  'amoonguss',
#  'amoonguss',
#  'amoonguss',
#  'amoonguss',
#  'amoonguss',
#  'amoonguss',
#  'amoonguss',
#  'araquanid',
#  'araquanid',
#  'araquanid',
#  'araquanid',
#  'araquanid',
#  'araquanid',
#  'araquanid',
#  'araquanid',
#  'araquanid',
#  'araquanid',
#  'araquanid',
#  'araquanid',
#  'araquanid',
#  'araquanid',
#  'araquanid',
#  'araquanid',
#  'araquanid',
#  'araquanid',
#  'araquanid',
#  'araquanid',
#  'araquanid',
#  'aerodactyl',
#  'aerodactyl',
#  'aerodactyl',
#  'aerodactyl',
#  'aerodactyl',
#  'aerodactyl',
#  'aerodactyl',
#  'aerodactyl',
#  'aerodactyl',
#  'aerodactyl',
#  'aerodactyl',
#  'aerodactyl',
#  'aerodactyl',
#  'aerodactyl',
#  'aerodactyl',
#  'aerodactyl',
#  'aerodactyl',
#  'aerodactyl',
#  'aerodactyl',
#  'aerodactyl',
#  'aerodactyl',
#  'arbok',
#  'arbok',
#  'arbok',
#  'arbok',
#  'arbok',
#  'arbok',
#  'arbok',
#  'arbok',
#  'arbok',
#  'arbok',
#  'arbok',
#  'arbok',
#  'arbok',
#  'arbok',
#  'arbok',
#  'arbok',
#  'arbok',
#  'arbok',
#  'arbok',
#  'arbok',
#  'arbok',
#  'ambipom',
#  'ambipom',
#  'ambipom',
#  'ambipom',
#  'ambipom',
#  'ambipom',
#  'ambipom',
#  'ambipom',
#  'ambipom',
#  'ambipom',
#  'ambipom',
#  'ambipom',
#  'ambipom',
#  'ambipom',
#  'ambipom',
#  'ambipom',
#  'ambipom',
#  'ambipom',
#  'ambipom',
#  'ambipom',
#  'ambipom',
#  'aromatisse',
#  'aromatisse',
#  'aromatisse',
#  'aromatisse',
#  'aromatisse',
#  'aromatisse',
#  'aromatisse',
#  'aromatisse',
#  'aromatisse',
#  'aromatisse',
#  'aromatisse',
#  'aromatisse',
#  'aromatisse',
#  'aromatisse',
#  'aromatisse',
#  'aromatisse',
#  'aromatisse',
#  'aromatisse',
#  'aromatisse',
#  'aromatisse',
#  'aromatisse',
#  'ariados',
#  'ariados',
#  'ariados',
#  'ariados',
#  'ariados',
#  'ariados',
#  'ariados',
#  'ariados',
#  'ariados',
#  'ariados',
#  'ariados',
#  'ariados',
#  'ariados',
#  'ariados',
#  'ariados',
#  'ariados',
#  'ariados',
#  'ariados',
#  'ariados',
#  'ariados',
#  'ariados',
#  'archeops',
#  'archeops',
#  'archeops',
#  'archeops',
#  'archeops',
#  'archeops',
#  'archeops',
#  'archeops',
#  'archeops',
#  'archeops',
#  'archeops',
#  'archeops',
#  'archeops',
#  'archeops',
#  'archeops',
#  'archeops',
#  'archeops',
#  'archeops',
#  'archeops',
#  'archeops',
#  'archeops',
#  'armaldo',
#  'armaldo',
#  'armaldo',
#  'armaldo',
#  'armaldo',
#  'armaldo',
#  'armaldo',
#  'armaldo',
#  'armaldo',
#  'armaldo',
#  'armaldo',
#  'armaldo',
#  'armaldo',
#  'armaldo',
#  'armaldo',
#  'armaldo',
#  'armaldo',
#  'armaldo',
#  'armaldo',
#  'armaldo',
#  'armaldo',
#  'gourgeist-average',
#  'gourgeist-average',
#  'gourgeist-average',
#  'gourgeist-average',
#  'gourgeist-average',
#  'gourgeist-average',
#  'gourgeist-average',
#  'gourgeist-average',
#  'gourgeist-average',
#  'gourgeist-average',
#  'gourgeist-average',
#  'gourgeist-average',
#  'gourgeist-average',
#  'gourgeist-average',
#  'gourgeist-average',
#  'gourgeist-average',
#  'gourgeist-average',
#  'gourgeist-average',
#  'gourgeist-average',
#  'gourgeist-average',
#  'gourgeist-average',
#  'graveler',
#  'graveler',
#  'graveler',
#  'graveler',
#  'graveler',
#  'graveler',
#  'graveler',
#  'graveler',
#  'graveler',
#  'graveler',
#  'graveler',
#  'graveler',
#  'graveler',
#  'graveler',
#  'graveler',
#  'graveler',
#  'graveler',
#  'graveler',
#  'graveler',
#  'graveler',
#  'graveler',
#  'greninja',
#  'greninja',
#  'greninja',
#  'greninja',
#  'greninja',
#  'greninja',
#  'greninja',
#  'greninja',
#  'greninja',
#  'greninja',
#  'greninja',
#  'greninja',
#  'greninja',
#  'greninja',
#  'greninja',
#  'greninja',
#  'greninja',
#  'greninja',
#  'greninja',
#  'greninja',
#  'greninja',
#  'herdier',
#  'herdier',
#  'herdier',
#  'herdier',
#  'herdier',
#  'herdier',
#  'herdier',
#  'herdier',
#  'herdier',
#  'herdier',
#  'herdier',
#  'herdier',
#  'herdier',
#  'herdier',
#  'herdier',
#  'herdier',
#  'herdier',
#  'herdier',
#  'herdier',
#  'herdier',
#  'herdier',
#  'axew',
#  'axew',
#  'axew',
#  'axew',
#  'axew',
#  'axew',
#  'axew',
#  'axew',
#  'axew',
#  'axew',
#  'axew',
#  'axew',
#  'axew',
#  'axew',
#  'axew',
#  'axew',
#  'axew',
#  'axew',
#  'axew',
#  'axew',
#  'axew',
#  'chikorita',
#  'chikorita',
#  'chikorita',
#  'chikorita',
#  'chikorita',
#  'chikorita',
#  'chikorita',
#  'chikorita',
#  'chikorita',
#  'chikorita',
#  'chikorita',
#  'chikorita',
#  'chikorita',
#  'chikorita',
#  'chikorita',
#  'chikorita',
#  'chikorita',
#  'chikorita',
#  'chikorita',
#  'chikorita',
#  'chikorita',
#  'charizard',
#  'charizard',
#  'charizard',
#  'charizard',
#  'charizard',
#  'charizard',
#  'charizard',
#  'charizard',
#  'charizard',
#  'charizard',
#  'charizard',
#  'charizard',
#  'charizard',
#  'charizard',
#  'charizard',
#  'charizard',
#  'charizard',
#  'charizard',
#  'charizard',
#  'charizard',
#  'charizard',
#  'chespin',
#  'chespin',
#  'chespin',
#  'chespin',
#  'chespin',
#  'chespin',
#  'chespin',
#  'chespin',
#  'chespin',
#  'chespin',
#  'chespin',
#  'chespin',
#  'chespin',
#  'chespin',
#  'chespin',
#  'chespin',
#  'chespin',
#  'chespin',
#  'chespin',
#  'chespin',
#  'chespin',
#  'bellsprout',
#  'bellsprout',
#  'bellsprout',
#  'bellsprout',
#  'bellsprout',
#  'bellsprout',
#  'bellsprout',
#  'bellsprout',
#  'bellsprout',
#  'bellsprout',
#  'bellsprout',
#  'bellsprout',
#  'bellsprout',
#  'bellsprout',
#  'bellsprout',
#  'bellsprout',
#  'bellsprout',
#  'bellsprout',
#  'bellsprout',
#  'bellsprout',
#  'bellsprout',
#  'clamperl',
#  'clamperl',
#  'clamperl',
#  'clamperl',
#  'clamperl',
#  'clamperl',
#  'clamperl',
#  'clamperl',
#  'clamperl',
#  'clamperl',
#  'clamperl',
#  'clamperl',
#  'clamperl',
#  'clamperl',
#  'clamperl',
#  'clamperl',
#  'clamperl',
#  'clamperl',
#  'clamperl',
#  'clamperl',
#  'clamperl',
#  'budew',
#  'budew',
#  'budew',
#  'budew',
#  'budew',
#  'budew',
#  'budew',
#  'budew',
#  'budew',
#  'budew',
#  'budew',
#  'budew',
#  'budew',
#  'budew',
#  'budew',
#  'budew',
#  'budew',
#  'budew',
#  'budew',
#  'budew',
#  'budew',
#  'bergmite',
#  'bergmite',
#  'bergmite',
#  'bergmite',
#  'bergmite',
#  'bergmite',
#  'bergmite',
#  'bergmite',
#  'bergmite',
#  'bergmite',
#  'bergmite',
#  'bergmite',
#  'bergmite',
#  'bergmite',
#  'bergmite',
#  'bergmite',
#  'bergmite',
#  'bergmite',
#  'bergmite',
#  'bergmite',
#  'bergmite',
#  'carvanha',
#  'carvanha',
#  'carvanha',
#  'carvanha',
#  'carvanha',
#  'carvanha',
#  'carvanha',
#  'carvanha',
#  'carvanha',
#  'carvanha',
#  'carvanha',
#  'carvanha',
#  'carvanha',
#  'carvanha',
#  'carvanha',
#  'carvanha',
#  'carvanha',
#  'carvanha',
#  'carvanha',
#  'carvanha',
#  'carvanha',
#  'blitzle',
#  'blitzle',
#  'blitzle',
#  'blitzle',
#  'blitzle',
#  'blitzle',
#  'blitzle',
#  'blitzle',
#  'blitzle',
#  'blitzle',
#  'blitzle',
#  'blitzle',
#  'blitzle',
#  'blitzle',
#  'blitzle',
#  'blitzle',
#  'blitzle',
#  'blitzle',
#  'blitzle',
#  'blitzle',
#  'blitzle',
#  'chimchar',
#  'chimchar',
#  'chimchar',
#  'chimchar',
#  'chimchar',
#  'chimchar',
#  'chimchar',
#  'chimchar',
#  'chimchar',
#  'chimchar',
#  'chimchar',
#  'chimchar',
#  'chimchar',
#  'chimchar',
#  'chimchar',
#  'chimchar',
#  'chimchar',
#  'chimchar',
#  'chimchar',
#  'chimchar',
#  'chimchar',
#  'chimecho',
#  'chimecho',
#  'chimecho',
#  'chimecho',
#  'chimecho',
#  'chimecho',
#  'chimecho',
#  'chimecho',
#  'chimecho',
#  'chimecho',
#  'chimecho',
#  'chimecho',
#  'chimecho',
#  'chimecho',
#  'chimecho',
#  'chimecho',
#  'chimecho',
#  'chimecho',
#  'chimecho',
#  'chimecho',
#  'chimecho',
#  'cacturne',
#  'cacturne',
#  'cacturne',
#  'cacturne',
#  'cacturne',
#  'cacturne',
#  'cacturne',
#  'cacturne',
#  'cacturne',
#  'cacturne',
#  'cacturne',
#  'cacturne',
#  'cacturne',
#  'cacturne',
#  'cacturne',
#  'cacturne',
#  'cacturne',
#  'cacturne',
#  'cacturne',
#  'cacturne',
#  'cacturne',
#  'binacle',
#  'binacle',
#  'binacle',
#  'binacle',
#  'binacle',
#  'binacle',
#  'binacle',
#  'binacle',
#  'binacle',
#  'binacle',
#  'binacle',
#  'binacle',
#  'binacle',
#  'binacle',
#  'binacle',
#  'binacle',
#  'binacle',
#  'binacle',
#  'binacle',
#  'binacle',
#  'binacle',
#  'camerupt',
#  'camerupt',
#  'camerupt',
#  'camerupt',
#  'camerupt',
#  'camerupt',
#  'camerupt',
#  'camerupt',
#  'camerupt',
#  'camerupt',
#  'camerupt',
#  'camerupt',
#  'camerupt',
#  'camerupt',
#  'camerupt',
#  'camerupt',
#  'camerupt',
#  'camerupt',
#  'camerupt',
#  'camerupt',
#  'camerupt',
#  'carracosta',
#  'carracosta',
#  'carracosta',
#  'carracosta',
#  'carracosta',
#  'carracosta',
#  'carracosta',
#  'carracosta',
#  'carracosta',
#  'carracosta',
#  'carracosta',
#  'carracosta',
#  'carracosta',
#  'carracosta',
#  'carracosta',
#  'carracosta',
#  'carracosta',
#  'carracosta',
#  'carracosta',
#  'carracosta',
#  'carracosta',
#  'boldore',
#  'boldore',
#  'boldore',
#  'boldore',
#  'boldore',
#  'boldore',
#  'boldore',
#  'boldore',
#  'boldore',
#  'boldore',
#  'boldore',
#  'boldore',
#  'boldore',
#  'boldore',
#  'boldore',
#  'boldore',
#  'boldore',
#  'boldore',
#  'boldore',
#  'boldore',
#  'boldore',
#  'machamp',
#  'machamp',
#  'machamp',
#  'machamp',
#  'machamp',
#  'machamp',
#  'machamp',
#  'machamp',
#  'machamp',
#  'machamp',
#  'machamp',
#  'machamp',
#  'machamp',
#  'machamp',
#  'machamp',
#  'machamp',
#  'machamp',
#  'machamp',
#  'machamp',
#  'machamp',
#  'machamp',
#  'bruxish',
#  'bruxish',
#  'bruxish',
#  'bruxish',
#  'bruxish',
#  'bruxish',
#  'bruxish',
#  'bruxish',
#  'bruxish',
#  'bruxish',
#  'bruxish',
#  'bruxish',
#  'bruxish',
#  'bruxish',
#  'bruxish',
#  'bruxish',
#  'bruxish',
#  'bruxish',
#  'bruxish',
#  'bruxish',
#  'bruxish',
#  'cinccino',
#  'cinccino',
#  'cinccino',
#  'cinccino',
#  'cinccino',
#  'cinccino',
#  'cinccino',
#  'cinccino',
#  'cinccino',
#  'cinccino',
#  'cinccino',
#  'cinccino',
#  'cinccino',
#  'cinccino',
#  'cinccino',
#  'cinccino',
#  'cinccino',
#  'cinccino',
#  'cinccino',
#  'cinccino',
#  'cinccino',
#  'marowak',
#  'marowak',
#  'marowak',
#  'marowak',
#  'marowak',
#  'marowak',
#  'marowak',
#  'marowak',
#  'marowak',
#  'marowak',
#  'marowak',
#  'marowak',
#  'marowak',
#  ...]

# %%
len(cat)
# Out:
# 16863

# %%
import pandas as pd
df = pd.DataFrame({
    'filename': filenames,
    'category': cat
})

# %%
df
# Out:
#                filename    category
# 0      conkeldurr.0.png  conkeldurr
# 1      conkeldurr.1.png  conkeldurr
# 2      conkeldurr.2.png  conkeldurr
# 3      conkeldurr.3.png  conkeldurr
# 4      conkeldurr.4.png  conkeldurr
# ...                 ...         ...
# 16858   larvesta.16.png    larvesta
# 16859   larvesta.17.png    larvesta
# 16860   larvesta.18.png    larvesta
# 16861   larvesta.19.png    larvesta
# 16862   larvesta.20.png    larvesta
#
# [16863 rows x 2 columns]

# %%
df['category'].value_counts().plot.bar()

# %%
from keras.utils import load_img
import random

# %%
print(len(categories))
# Out:
# 803

# %%
os.listdir()
# Out:
# ['conkeldurr',
#  'azelf',
#  'azurill',
#  'bagon',
#  'azumarill',
#  'baltoy',
#  'barbaracle',
#  'frillish',
#  'abra',
#  'accelgor',
#  'absol',
#  'anorith',
#  'aegislash-blade',
#  'ampharos',
#  'amoonguss',
#  'araquanid',
#  'aerodactyl',
#  'arbok',
#  'ambipom',
#  'aromatisse',
#  'ariados',
#  'archeops',
#  'armaldo',
#  'gourgeist-average',
#  'graveler',
#  'greninja',
#  'herdier',
#  'axew',
#  'chikorita',
#  'charizard',
#  'chespin',
#  'bellsprout',
#  'clamperl',
#  'budew',
#  'bergmite',
#  'carvanha',
#  'blitzle',
#  'chimchar',
#  'chimecho',
#  'cacturne',
#  'binacle',
#  'camerupt',
#  'carracosta',
#  'boldore',
#  'machamp',
#  'bruxish',
#  'cinccino',
#  'marowak',
#  'diglett',
#  'dewpider',
#  'chingling',
#  'blaziken',
#  'cherrim',
#  'mew',
#  'chansey',
#  'cascoon',
#  'lycanroc-midday',
#  'bidoof',
#  'blissey',
#  'bibarel',
#  'charmeleon',
#  'celesteela',
#  'drilbur',
#  'charjabug',
#  'chesnaught',
#  'dewott',
#  'chatot',
#  'dragonair',
#  'bewear',
#  'chinchou',
#  'drampa',
#  'dragalge',
#  'carnivine',
#  'dodrio',
#  'ditto',
#  'drifloon',
#  'dhelmise',
#  'dragonite',
#  'dratini',
#  'ducklett',
#  'musharna',
#  'drowzee',
#  'dugtrio',
#  'drapion',
#  'druddigon',
#  'dustox',
#  'elekid',
#  'duosion',
#  'dusknoir',
#  'durant',
#  'dusclops',
#  'dwebble',
#  'duskull',
#  'eelektrik',
#  'eelektross',
#  'elgyem',
#  'escavalier',
#  'empoleon',
#  'espeon',
#  'emboar',
#  'entei',
#  'excadrill',
#  'exeggcute',
#  'exeggutor',
#  'feebas',
#  'exploud',
#  'fearow',
#  'fennekin',
#  'feraligatr',
#  'ferroseed',
#  'finneon',
#  'ferrothorn',
#  'flaaffy',
#  'flabebe',
#  'flareon',
#  'fletchinder',
#  'fletchling',
#  'floatzel',
#  'floette',
#  'florges',
#  'flygon',
#  'fomantis',
#  'foongus',
#  'forretress',
#  'fraxure',
#  'froakie',
#  'frogadier',
#  'froslass',
#  'furret',
#  'furfrou',
#  'gabite',
#  'gallade',
#  'galvantula',
#  'garbodor',
#  'garchomp',
#  'gardevoir',
#  'gastly',
#  'gastrodon',
#  'genesect',
#  'gengar',
#  'geodude',
#  'gible',
#  'gigalith',
#  'girafarig',
#  'giratina-altered',
#  'glameow',
#  'glaceon',
#  'glalie',
#  'gligar',
#  'gliscor',
#  'abomasnow',
#  'gloom',
#  'gogoat',
#  'golbat',
#  'goldeen',
#  'aggron',
#  'aipom',
#  'alomomola',
#  'altaria',
#  'alakazam',
#  'arcanine',
#  'amaura',
#  'arceus',
#  'archen',
#  'aron',
#  'articuno',
#  'audino',
#  'avalugg',
#  'aurorus',
#  'golduck',
#  'goomy',
#  'goodra',
#  'gorebyss',
#  'golisopod',
#  'golett',
#  'gothitelle',
#  'gothorita',
#  'granbull',
#  'grimer',
#  'grotle',
#  'groudon',
#  'growlithe',
#  'grubbin',
#  'grovyle',
#  'grumpig',
#  'gulpin',
#  'gumshoos',
#  'gurdurr',
#  'guzzlord',
#  'gyarados',
#  'hakamo-o',
#  'happiny',
#  'hariyama',
#  'haunter',
#  'hawlucha',
#  'heatmor',
#  'heliolisk',
#  'heatran',
#  'heracross',
#  'helioptile',
#  'hippopotas',
#  'hippowdon',
#  'hitmonchan',
#  'hitmonlee',
#  'hitmontop',
#  'honedge',
#  'hoppip',
#  'hoopa-confined',
#  'horsea',
#  'ho-oh',
#  'houndour',
#  'houndoom',
#  'huntail',
#  'hypno',
#  'hydreigon',
#  'igglybuff',
#  'illumise',
#  'incineroar',
#  'infernape',
#  'inkay',
#  'ivysaur',
#  'jellicent',
#  'jigglypuff',
#  'jirachi',
#  'jolteon',
#  'joltik',
#  'jumpluff',
#  'jynx',
#  'kabuto',
#  'kabutops',
#  'kadabra',
#  'kakuna',
#  'kangaskhan',
#  'karrablast',
#  'kartana',
#  'kecleon',
#  'keldeo-ordinary',
#  'kingdra',
#  'kingler',
#  'kirlia',
#  'klang',
#  'klefki',
#  'klink',
#  'klinklang',
#  'koffing',
#  'komala',
#  'kommo-o',
#  'krabby',
#  'kricketot',
#  'kricketune',
#  'krokorok',
#  'krookodile',
#  'kyogre',
#  'kyurem',
#  'lairon',
#  'lampent',
#  'lanturn',
#  'landorus-incarnate',
#  'lapras',
#  'larvitar',
#  'latias',
#  'latios',
#  'leafeon',
#  'leavanny',
#  'ledian',
#  'ledyba',
#  'lickilicky',
#  'lickitung',
#  'liepard',
#  'lileep',
#  'linoone',
#  'litleo',
#  'lillipup',
#  'lilligant',
#  'litten',
#  'litwick',
#  'lombre',
#  'lopunny',
#  'lotad',
#  'banette',
#  'barboach',
#  'basculin-red-striped',
#  'bastiodon',
#  'bayleef',
#  'beartic',
#  'beautifly',
#  'beedrill',
#  'beheeyem',
#  'beldum',
#  'loudred',
#  'bellossom',
#  'lucario',
#  'bisharp',
#  'blacephalon',
#  'blastoise',
#  'bonsly',
#  'ludicolo',
#  'bouffalant',
#  'bounsweet',
#  'braixen',
#  'braviary',
#  'breloom',
#  'brionne',
#  'bronzong',
#  'bronzor',
#  'lugia',
#  'lumineon',
#  'lunala',
#  'lurantis',
#  'lunatone',
#  'luvdisc',
#  'luxray',
#  'luxio',
#  'bulbasaur',
#  'buizel',
#  'buneary',
#  'bunnelby',
#  'burmy',
#  'butterfree',
#  'buzzwole',
#  'cacnea',
#  'machoke',
#  'machop',
#  'magby',
#  'magcargo',
#  'magearna',
#  'carbink',
#  'magikarp',
#  'magmar',
#  'castform',
#  'caterpie',
#  'celebi',
#  'magmortar',
#  'magnemite',
#  'makuhita',
#  'magnezone',
#  'magneton',
#  'malamar',
#  'mamoswine',
#  'manaphy',
#  'manectric',
#  'mandibuzz',
#  'mankey',
#  'mantine',
#  'mantyke',
#  'maractus',
#  'mareanie',
#  'mareep',
#  'marill',
#  'marshadow',
#  'marshtomp',
#  'masquerain',
#  'chandelure',
#  'charmander',
#  'cherubi',
#  'medicham',
#  'mawile',
#  'meditite',
#  'meganium',
#  'melmetal',
#  'meloetta-aria',
#  'meltan',
#  'meowstic-male',
#  'meowth',
#  'mesprit',
#  'metagross',
#  'metang',
#  'metapod',
#  'clauncher',
#  'clawitzer',
#  'claydol',
#  'clefable',
#  'clefairy',
#  'cleffa',
#  'cloyster',
#  'cobalion',
#  'cofagrigus',
#  'combee',
#  'comfey',
#  'combusken',
#  'corphish',
#  'corsola',
#  'cosmoem',
#  'cosmog',
#  'cottonee',
#  'crabominable',
#  'crabrawler',
#  'cradily',
#  'cranidos',
#  'crawdaunt',
#  'cresselia',
#  'croagunk',
#  'croconaw',
#  'crobat',
#  'crustle',
#  'cryogonal',
#  'cubchoo',
#  'cutiefly',
#  'cubone',
#  'cyndaquil',
#  'darkrai',
#  'darmanitan-standard',
#  'dartrix',
#  'darumaka',
#  'decidueye',
#  'dedenne',
#  'deerling',
#  'deino',
#  'delcatty',
#  'delibird',
#  'delphox',
#  'deoxys-normal',
#  'dewgong',
#  'dialga',
#  'diancie',
#  'diggersby',
#  'mienfoo',
#  'mewtwo',
#  'mienshao',
#  'mightyena',
#  'milotic',
#  'miltank',
#  'mime-jr',
#  'mimikyu',
#  'minccino',
#  'minior-meteor',
#  'minun',
#  'misdreavus',
#  'mismagius',
#  'moltres',
#  'doduo',
#  'donphan',
#  'doublade',
#  'monferno',
#  'morelull',
#  'mothim',
#  'mr-mime',
#  'mudbray',
#  'mudkip',
#  'mudsdale',
#  'muk',
#  'munchlax',
#  'munna',
#  'murkrow',
#  'drifblim',
#  'naganadel',
#  'natu',
#  'necrozma',
#  'nidoking',
#  'nidoqueen',
#  'nidoran-f',
#  'nidoran-m',
#  'nidorina',
#  'nidorino',
#  'nihilego',
#  'nincada',
#  'ninetales',
#  'ninjask',
#  'noctowl',
#  'noibat',
#  'noivern',
#  'nosepass',
#  'numel',
#  'nuzleaf',
#  'octillery',
#  'oddish',
#  'omanyte',
#  'omastar',
#  'onix',
#  'oranguru',
#  'oricorio-baile',
#  'oshawott',
#  'pachirisu',
#  'palkia',
#  'palossand',
#  'palpitoad',
#  'pancham',
#  'panpour',
#  'pangoro',
#  'pansage',
#  'pansear',
#  'paras',
#  'parasect',
#  'passimian',
#  'patrat',
#  'pawniard',
#  'pelipper',
#  'persian',
#  'phanpy',
#  'petilil',
#  'phantump',
#  'pheromosa',
#  'pichu',
#  'phione',
#  'pidgeot',
#  'pidgeotto',
#  'pidgey',
#  'pidove',
#  'pikachu',
#  'pignite',
#  'pikipek',
#  'piloswine',
#  'pineco',
#  'pinsir',
#  'piplup',
#  'plusle',
#  'politoed',
#  'poliwag',
#  'poipole',
#  'poliwhirl',
#  'poliwrath',
#  'ponyta',
#  'poochyena',
#  'popplio',
#  'porygon',
#  'porygon2',
#  'porygon-z',
#  'primarina',
#  'primeape',
#  'prinplup',
#  'probopass',
#  'psyduck',
#  'pumpkaboo-average',
#  'pupitar',
#  'purrloin',
#  'purugly',
#  'pyroar',
#  'pyukumuku',
#  'quagsire',
#  'quilava',
#  'quilladin',
#  'qwilfish',
#  'raichu',
#  'raikou',
#  'ralts',
#  'rampardos',
#  'rapidash',
#  'raticate',
#  'rattata',
#  'rayquaza',
#  'regice',
#  'regigigas',
#  'regirock',
#  'registeel',
#  'relicanth',
#  'remoraid',
#  'reuniclus',
#  'reshiram',
#  'rhyhorn',
#  'rhydon',
#  'rhyperior',
#  'ribombee',
#  'riolu',
#  'rockruff',
#  'roggenrola',
#  'roselia',
#  'roserade',
#  'rotom',
#  'rowlet',
#  'rufflet',
#  'sableye',
#  'salamence',
#  'salandit',
#  'salazzle',
#  'samurott',
#  'sandshrew',
#  'sandile',
#  'dunsparce',
#  'eevee',
#  'ekans',
#  'electabuzz',
#  'electivire',
#  'electrode',
#  'electrike',
#  'emolga',
#  'sandslash',
#  'sandygast',
#  'sawk',
#  'sawsbuck',
#  'scatterbug',
#  'scizor',
#  'sceptile',
#  'scrafty',
#  'scraggy',
#  'scyther',
#  'seadra',
#  'sealeo',
#  'seaking',
#  'seedot',
#  'seel',
#  'seismitoad',
#  'sentret',
#  'serperior',
#  'servine',
#  'seviper',
#  'sewaddle',
#  'sharpedo',
#  'shaymin-land',
#  'shedinja',
#  'shelgon',
#  'shellos',
#  'shellder',
#  'shieldon',
#  'shelmet',
#  'shiftry',
#  'shiinotic',
#  'shinx',
#  'shroomish',
#  'shuckle',
#  'shuppet',
#  'sigilyph',
#  'silcoon',
#  'silvally',
#  'simipour',
#  'simisage',
#  'simisear',
#  'skarmory',
#  'skiploom',
#  'skiddo',
#  'skorupi',
#  'skitty',
#  'skrelp',
#  'skuntank',
#  'slaking',
#  'slakoth',
#  'sliggoo',
#  'slowbro',
#  'slowking',
#  'slowpoke',
#  'slugma',
#  'slurpuff',
#  'smoochum',
#  'sneasel',
#  'smeargle',
#  'snivy',
#  'snorunt',
#  'snorlax',
#  'snover',
#  'snubbull',
#  'solgaleo',
#  'solosis',
#  'solrock',
#  'spearow',
#  'spewpa',
#  'spheal',
#  'spinarak',
#  'spiritomb',
#  'spinda',
#  'spoink',
#  'spritzee',
#  'squirtle',
#  'stakataka',
#  'stantler',
#  'staraptor',
#  'staravia',
#  'starly',
#  'starmie',
#  'staryu',
#  'steelix',
#  'steenee',
#  'stoutland',
#  'stufful',
#  'stunfisk',
#  'stunky',
#  'sudowoodo',
#  'suicune',
#  'sunflora',
#  'sunkern',
#  'surskit',
#  'swablu',
#  'swadloon',
#  'swalot',
#  'swampert',
#  'swellow',
#  'swinub',
#  'swirlix',
#  'swanna',
#  'swoobat',
#  'sylveon',
#  'taillow',
#  'talonflame',
#  'tangela',
#  'tangrowth',
#  'tapu-bulu',
#  'tapu-fini',
#  'tapu-lele',
#  'tapu-koko',
#  'tauros',
#  'tentacool',
#  'teddiursa',
#  'tentacruel',
#  'tepig',
#  'terrakion',
#  'throh',
#  'thundurus-incarnate',
#  'timburr',
#  'tirtouga',
#  'togedemaru',
#  'togekiss',
#  'togetic',
#  'torchic',
#  'torkoal',
#  'tornadus-incarnate',
#  'torracat',
#  'torterra',
#  'totodile',
#  'toucannon',
#  'toxapex',
#  'toxicroak',
#  'tranquill',
#  'trevenant',
#  'treecko',
#  'tropius',
#  'trubbish',
#  'trumbeak',
#  'tsareena',
#  'turtonator',
#  'turtwig',
#  'tympole',
#  'type-null',
#  'tynamo',
#  'typhlosion',
#  'tyranitar',
#  'tyrantrum',
#  'tyrogue',
#  'tyrunt',
#  'umbreon',
#  'unown',
#  'unfezant',
#  'ursaring',
#  'uxie',
#  'vanillish',
#  'vanillite',
#  'vanilluxe',
#  'vaporeon',
#  'venipede',
#  'venonat',
#  'venomoth',
#  'vespiquen',
#  'venusaur',
#  'vibrava',
#  'victini',
#  'victreebel',
#  'vigoroth',
#  'vikavolt',
#  'virizion',
#  'vivillon',
#  'volbeat',
#  'volcanion',
#  'voltorb',
#  'vullaby',
#  'vulpix',
#  'wailmer',
#  'wailord',
#  'wartortle',
#  'watchog',
#  'weavile',
#  'weedle',
#  'weepinbell',
#  'weezing',
#  'whirlipede',
#  'whiscash',
#  'whismur',
#  'whimsicott',
#  'wigglytuff',
#  'wimpod',
#  'wishiwashi-solo',
#  'wingull',
#  'wobbuffet',
#  'wooper',
#  'woobat',
#  'wurmple',
#  'wormadam-plant',
#  'xerneas',
#  'xurkitree',
#  'wynaut',
#  'xatu',
#  'yanmega',
#  'yungoos',
#  'zebstrika',
#  'yamask',
#  'yveltal',
#  'zangoose',
#  'zapdos',
#  'zekrom',
#  'zeraora',
#  'zigzagoon',
#  'yanma',
#  'zorua',
#  'farfetchd',
#  'golem',
#  'gothita',
#  'haxorus',
#  'hoothoot',
#  'zoroark',
#  'zubat',
#  'zweilous',
#  'zygarde-50',
#  'espurr',
#  'golurk',
#  'honchkrow',
#  'jangmo-o',
#  'larvesta']

# %%
# %cd data
# Out:
# /content/drive/MyDrive/data

# %%
abss=os.getcwd()
abss
# Out:
# '/content/drive/MyDrive/data'

# %%
for i in os.listdir(curr):
    path = os.path.join(curr, i)
    names=os.listdir(path)
    for j in names:
#         print(j)
        img=Image.open(path+"/"+j)
        img = img.convert('RGB')
        img=np.array(img)
        img = Image.fromarray(img)
        img.save(j)

# %%
os.listdir()
# Out:
# ['conkeldurr.0.png',
#  'conkeldurr.1.png',
#  'conkeldurr.2.png',
#  'conkeldurr.3.png',
#  'conkeldurr.4.png',
#  'conkeldurr.5.png',
#  'conkeldurr.6.png',
#  'conkeldurr.7.png',
#  'conkeldurr.8.png',
#  'conkeldurr.9.png',
#  'conkeldurr.10.png',
#  'conkeldurr.11.png',
#  'conkeldurr.12.png',
#  'conkeldurr.13.png',
#  'conkeldurr.14.png',
#  'conkeldurr.15.png',
#  'conkeldurr.16.png',
#  'conkeldurr.17.png',
#  'conkeldurr.18.png',
#  'conkeldurr.19.png',
#  'conkeldurr.20.png',
#  'azelf.0.png',
#  'azelf.1.png',
#  'azelf.2.png',
#  'azelf.3.png',
#  'azelf.4.png',
#  'azelf.5.png',
#  'azelf.6.png',
#  'azelf.7.png',
#  'azelf.8.png',
#  'azelf.9.png',
#  'azelf.10.png',
#  'azelf.11.png',
#  'azelf.12.png',
#  'azelf.13.png',
#  'azelf.14.png',
#  'azelf.15.png',
#  'azelf.16.png',
#  'azelf.17.png',
#  'azelf.18.png',
#  'azelf.19.png',
#  'azelf.20.png',
#  'azurill.0.png',
#  'azurill.1.png',
#  'azurill.2.png',
#  'azurill.3.png',
#  'azurill.4.png',
#  'azurill.5.png',
#  'azurill.6.png',
#  'azurill.7.png',
#  'azurill.8.png',
#  'azurill.9.png',
#  'azurill.10.png',
#  'azurill.11.png',
#  'azurill.12.png',
#  'azurill.13.png',
#  'azurill.14.png',
#  'azurill.15.png',
#  'azurill.16.png',
#  'azurill.17.png',
#  'azurill.18.png',
#  'azurill.19.png',
#  'azurill.20.png',
#  'bagon.0.png',
#  'bagon.1.png',
#  'bagon.2.png',
#  'bagon.3.png',
#  'bagon.4.png',
#  'bagon.5.png',
#  'bagon.6.png',
#  'bagon.7.png',
#  'bagon.8.png',
#  'bagon.9.png',
#  'bagon.10.png',
#  'bagon.11.png',
#  'bagon.12.png',
#  'bagon.13.png',
#  'bagon.14.png',
#  'bagon.15.png',
#  'bagon.16.png',
#  'bagon.17.png',
#  'bagon.18.png',
#  'bagon.19.png',
#  'bagon.20.png',
#  'azumarill.0.png',
#  'azumarill.1.png',
#  'azumarill.2.png',
#  'azumarill.3.png',
#  'azumarill.4.png',
#  'azumarill.5.png',
#  'azumarill.6.png',
#  'azumarill.7.png',
#  'azumarill.8.png',
#  'azumarill.9.png',
#  'azumarill.10.png',
#  'azumarill.11.png',
#  'azumarill.12.png',
#  'azumarill.13.png',
#  'azumarill.14.png',
#  'azumarill.15.png',
#  'azumarill.16.png',
#  'azumarill.17.png',
#  'azumarill.18.png',
#  'azumarill.19.png',
#  'azumarill.20.png',
#  'baltoy.0.png',
#  'baltoy.1.png',
#  'baltoy.2.png',
#  'baltoy.3.png',
#  'baltoy.4.png',
#  'baltoy.5.png',
#  'baltoy.6.png',
#  'baltoy.7.png',
#  'baltoy.8.png',
#  'baltoy.9.png',
#  'baltoy.10.png',
#  'baltoy.11.png',
#  'baltoy.12.png',
#  'baltoy.13.png',
#  'baltoy.14.png',
#  'baltoy.15.png',
#  'baltoy.16.png',
#  'baltoy.17.png',
#  'baltoy.18.png',
#  'baltoy.19.png',
#  'baltoy.20.png',
#  'barbaracle.0.png',
#  'barbaracle.1.png',
#  'barbaracle.2.png',
#  'barbaracle.3.png',
#  'barbaracle.4.png',
#  'barbaracle.5.png',
#  'barbaracle.6.png',
#  'barbaracle.7.png',
#  'barbaracle.8.png',
#  'barbaracle.9.png',
#  'barbaracle.10.png',
#  'barbaracle.11.png',
#  'barbaracle.12.png',
#  'barbaracle.13.png',
#  'barbaracle.14.png',
#  'barbaracle.15.png',
#  'barbaracle.16.png',
#  'barbaracle.17.png',
#  'barbaracle.18.png',
#  'barbaracle.19.png',
#  'barbaracle.20.png',
#  'frillish.0.png',
#  'frillish.1.png',
#  'frillish.2.png',
#  'frillish.3.png',
#  'frillish.4.png',
#  'frillish.5.png',
#  'frillish.6.png',
#  'frillish.7.png',
#  'frillish.8.png',
#  'frillish.9.png',
#  'frillish.10.png',
#  'frillish.11.png',
#  'frillish.12.png',
#  'frillish.13.png',
#  'frillish.14.png',
#  'frillish.15.png',
#  'frillish.16.png',
#  'frillish.17.png',
#  'frillish.18.png',
#  'frillish.19.png',
#  'frillish.20.png',
#  'abra.0.png',
#  'abra.1.png',
#  'abra.2.png',
#  'abra.3.png',
#  'abra.4.png',
#  'abra.5.png',
#  'abra.6.png',
#  'abra.7.png',
#  'abra.8.png',
#  'abra.9.png',
#  'abra.10.png',
#  'abra.11.png',
#  'abra.12.png',
#  'abra.13.png',
#  'abra.14.png',
#  'abra.15.png',
#  'abra.16.png',
#  'abra.17.png',
#  'abra.18.png',
#  'abra.19.png',
#  'abra.20.png',
#  'accelgor.0.png',
#  'accelgor.1.png',
#  'accelgor.2.png',
#  'accelgor.3.png',
#  'accelgor.4.png',
#  'accelgor.5.png',
#  'accelgor.6.png',
#  'accelgor.7.png',
#  'accelgor.8.png',
#  'accelgor.9.png',
#  'accelgor.10.png',
#  'accelgor.11.png',
#  'accelgor.12.png',
#  'accelgor.13.png',
#  'accelgor.14.png',
#  'accelgor.15.png',
#  'accelgor.16.png',
#  'accelgor.17.png',
#  'accelgor.18.png',
#  'accelgor.19.png',
#  'accelgor.20.png',
#  'absol.0.png',
#  'absol.1.png',
#  'absol.2.png',
#  'absol.3.png',
#  'absol.4.png',
#  'absol.5.png',
#  'absol.6.png',
#  'absol.7.png',
#  'absol.8.png',
#  'absol.9.png',
#  'absol.10.png',
#  'absol.11.png',
#  'absol.12.png',
#  'absol.13.png',
#  'absol.14.png',
#  'absol.15.png',
#  'absol.16.png',
#  'absol.17.png',
#  'absol.18.png',
#  'absol.19.png',
#  'absol.20.png',
#  'anorith.0.png',
#  'anorith.1.png',
#  'anorith.2.png',
#  'anorith.3.png',
#  'anorith.4.png',
#  'anorith.5.png',
#  'anorith.6.png',
#  'anorith.7.png',
#  'anorith.8.png',
#  'anorith.9.png',
#  'anorith.10.png',
#  'anorith.11.png',
#  'anorith.12.png',
#  'anorith.13.png',
#  'anorith.14.png',
#  'anorith.15.png',
#  'anorith.16.png',
#  'anorith.17.png',
#  'anorith.18.png',
#  'anorith.19.png',
#  'anorith.20.png',
#  'aegislash-blade.0.png',
#  'aegislash-blade.1.png',
#  'aegislash-blade.2.png',
#  'aegislash-blade.3.png',
#  'aegislash-blade.4.png',
#  'aegislash-blade.5.png',
#  'aegislash-blade.6.png',
#  'aegislash-blade.7.png',
#  'aegislash-blade.8.png',
#  'aegislash-blade.9.png',
#  'aegislash-blade.10.png',
#  'aegislash-blade.11.png',
#  'aegislash-blade.12.png',
#  'aegislash-blade.13.png',
#  'aegislash-blade.14.png',
#  'aegislash-blade.15.png',
#  'aegislash-blade.16.png',
#  'aegislash-blade.17.png',
#  'aegislash-blade.18.png',
#  'aegislash-blade.19.png',
#  'aegislash-blade.20.png',
#  'ampharos.0.png',
#  'ampharos.1.png',
#  'ampharos.2.png',
#  'ampharos.3.png',
#  'ampharos.4.png',
#  'ampharos.5.png',
#  'ampharos.6.png',
#  'ampharos.7.png',
#  'ampharos.8.png',
#  'ampharos.9.png',
#  'ampharos.10.png',
#  'ampharos.11.png',
#  'ampharos.12.png',
#  'ampharos.13.png',
#  'ampharos.14.png',
#  'ampharos.15.png',
#  'ampharos.16.png',
#  'ampharos.17.png',
#  'ampharos.18.png',
#  'ampharos.19.png',
#  'ampharos.20.png',
#  'amoonguss.0.png',
#  'amoonguss.1.png',
#  'amoonguss.2.png',
#  'amoonguss.3.png',
#  'amoonguss.4.png',
#  'amoonguss.5.png',
#  'amoonguss.6.png',
#  'amoonguss.7.png',
#  'amoonguss.8.png',
#  'amoonguss.9.png',
#  'amoonguss.10.png',
#  'amoonguss.11.png',
#  'amoonguss.12.png',
#  'amoonguss.13.png',
#  'amoonguss.14.png',
#  'amoonguss.15.png',
#  'amoonguss.16.png',
#  'amoonguss.17.png',
#  'amoonguss.18.png',
#  'amoonguss.19.png',
#  'amoonguss.20.png',
#  'araquanid.0.png',
#  'araquanid.1.png',
#  'araquanid.2.png',
#  'araquanid.3.png',
#  'araquanid.4.png',
#  'araquanid.5.png',
#  'araquanid.6.png',
#  'araquanid.7.png',
#  'araquanid.8.png',
#  'araquanid.9.png',
#  'araquanid.10.png',
#  'araquanid.11.png',
#  'araquanid.12.png',
#  'araquanid.13.png',
#  'araquanid.14.png',
#  'araquanid.15.png',
#  'araquanid.16.png',
#  'araquanid.17.png',
#  'araquanid.18.png',
#  'araquanid.19.png',
#  'araquanid.20.png',
#  'aerodactyl.0.png',
#  'aerodactyl.1.png',
#  'aerodactyl.2.png',
#  'aerodactyl.3.png',
#  'aerodactyl.4.png',
#  'aerodactyl.5.png',
#  'aerodactyl.6.png',
#  'aerodactyl.7.png',
#  'aerodactyl.8.png',
#  'aerodactyl.9.png',
#  'aerodactyl.10.png',
#  'aerodactyl.11.png',
#  'aerodactyl.12.png',
#  'aerodactyl.13.png',
#  'aerodactyl.14.png',
#  'aerodactyl.15.png',
#  'aerodactyl.16.png',
#  'aerodactyl.17.png',
#  'aerodactyl.18.png',
#  'aerodactyl.19.png',
#  'aerodactyl.20.png',
#  'arbok.0.png',
#  'arbok.1.png',
#  'arbok.2.png',
#  'arbok.3.png',
#  'arbok.4.png',
#  'arbok.5.png',
#  'arbok.6.png',
#  'arbok.7.png',
#  'arbok.8.png',
#  'arbok.9.png',
#  'arbok.10.png',
#  'arbok.11.png',
#  'arbok.12.png',
#  'arbok.13.png',
#  'arbok.14.png',
#  'arbok.15.png',
#  'arbok.16.png',
#  'arbok.17.png',
#  'arbok.18.png',
#  'arbok.19.png',
#  'arbok.20.png',
#  'ambipom.0.png',
#  'ambipom.1.png',
#  'ambipom.2.png',
#  'ambipom.3.png',
#  'ambipom.4.png',
#  'ambipom.5.png',
#  'ambipom.6.png',
#  'ambipom.7.png',
#  'ambipom.8.png',
#  'ambipom.9.png',
#  'ambipom.10.png',
#  'ambipom.11.png',
#  'ambipom.12.png',
#  'ambipom.13.png',
#  'ambipom.14.png',
#  'ambipom.15.png',
#  'ambipom.16.png',
#  'ambipom.17.png',
#  'ambipom.18.png',
#  'ambipom.19.png',
#  'ambipom.20.png',
#  'aromatisse.0.png',
#  'aromatisse.1.png',
#  'aromatisse.2.png',
#  'aromatisse.3.png',
#  'aromatisse.4.png',
#  'aromatisse.5.png',
#  'aromatisse.6.png',
#  'aromatisse.7.png',
#  'aromatisse.8.png',
#  'aromatisse.9.png',
#  'aromatisse.10.png',
#  'aromatisse.11.png',
#  'aromatisse.12.png',
#  'aromatisse.13.png',
#  'aromatisse.14.png',
#  'aromatisse.15.png',
#  'aromatisse.16.png',
#  'aromatisse.17.png',
#  'aromatisse.18.png',
#  'aromatisse.19.png',
#  'aromatisse.20.png',
#  'ariados.0.png',
#  'ariados.1.png',
#  'ariados.2.png',
#  'ariados.3.png',
#  'ariados.4.png',
#  'ariados.5.png',
#  'ariados.6.png',
#  'ariados.7.png',
#  'ariados.8.png',
#  'ariados.9.png',
#  'ariados.10.png',
#  'ariados.11.png',
#  'ariados.12.png',
#  'ariados.13.png',
#  'ariados.14.png',
#  'ariados.15.png',
#  'ariados.16.png',
#  'ariados.17.png',
#  'ariados.18.png',
#  'ariados.19.png',
#  'ariados.20.png',
#  'archeops.0.png',
#  'archeops.1.png',
#  'archeops.2.png',
#  'archeops.3.png',
#  'archeops.4.png',
#  'archeops.5.png',
#  'archeops.6.png',
#  'archeops.7.png',
#  'archeops.8.png',
#  'archeops.9.png',
#  'archeops.10.png',
#  'archeops.11.png',
#  'archeops.12.png',
#  'archeops.13.png',
#  'archeops.14.png',
#  'archeops.15.png',
#  'archeops.16.png',
#  'archeops.17.png',
#  'archeops.18.png',
#  'archeops.19.png',
#  'archeops.20.png',
#  'armaldo.0.png',
#  'armaldo.1.png',
#  'armaldo.2.png',
#  'armaldo.3.png',
#  'armaldo.4.png',
#  'armaldo.5.png',
#  'armaldo.6.png',
#  'armaldo.7.png',
#  'armaldo.8.png',
#  'armaldo.9.png',
#  'armaldo.10.png',
#  'armaldo.11.png',
#  'armaldo.12.png',
#  'armaldo.13.png',
#  'armaldo.14.png',
#  'armaldo.15.png',
#  'armaldo.16.png',
#  'armaldo.17.png',
#  'armaldo.18.png',
#  'armaldo.19.png',
#  'armaldo.20.png',
#  'gourgeist-average.0.png',
#  'gourgeist-average.1.png',
#  'gourgeist-average.2.png',
#  'gourgeist-average.3.png',
#  'gourgeist-average.4.png',
#  'gourgeist-average.5.png',
#  'gourgeist-average.6.png',
#  'gourgeist-average.7.png',
#  'gourgeist-average.8.png',
#  'gourgeist-average.9.png',
#  'gourgeist-average.10.png',
#  'gourgeist-average.11.png',
#  'gourgeist-average.12.png',
#  'gourgeist-average.13.png',
#  'gourgeist-average.14.png',
#  'gourgeist-average.15.png',
#  'gourgeist-average.16.png',
#  'gourgeist-average.17.png',
#  'gourgeist-average.18.png',
#  'gourgeist-average.19.png',
#  'gourgeist-average.20.png',
#  'graveler.0.png',
#  'graveler.1.png',
#  'graveler.2.png',
#  'graveler.3.png',
#  'graveler.4.png',
#  'graveler.5.png',
#  'graveler.6.png',
#  'graveler.7.png',
#  'graveler.8.png',
#  'graveler.9.png',
#  'graveler.10.png',
#  'graveler.11.png',
#  'graveler.12.png',
#  'graveler.13.png',
#  'graveler.14.png',
#  'graveler.15.png',
#  'graveler.16.png',
#  'graveler.17.png',
#  'graveler.18.png',
#  'graveler.19.png',
#  'graveler.20.png',
#  'greninja.0.png',
#  'greninja.1.png',
#  'greninja.2.png',
#  'greninja.3.png',
#  'greninja.4.png',
#  'greninja.5.png',
#  'greninja.6.png',
#  'greninja.7.png',
#  'greninja.8.png',
#  'greninja.9.png',
#  'greninja.10.png',
#  'greninja.11.png',
#  'greninja.12.png',
#  'greninja.13.png',
#  'greninja.14.png',
#  'greninja.15.png',
#  'greninja.16.png',
#  'greninja.17.png',
#  'greninja.18.png',
#  'greninja.19.png',
#  'greninja.20.png',
#  'herdier.0.png',
#  'herdier.1.png',
#  'herdier.2.png',
#  'herdier.3.png',
#  'herdier.4.png',
#  'herdier.5.png',
#  'herdier.6.png',
#  'herdier.7.png',
#  'herdier.8.png',
#  'herdier.9.png',
#  'herdier.10.png',
#  'herdier.11.png',
#  'herdier.12.png',
#  'herdier.13.png',
#  'herdier.14.png',
#  'herdier.15.png',
#  'herdier.16.png',
#  'herdier.17.png',
#  'herdier.18.png',
#  'herdier.19.png',
#  'herdier.20.png',
#  'axew.0.png',
#  'axew.1.png',
#  'axew.2.png',
#  'axew.3.png',
#  'axew.4.png',
#  'axew.5.png',
#  'axew.6.png',
#  'axew.7.png',
#  'axew.8.png',
#  'axew.9.png',
#  'axew.10.png',
#  'axew.11.png',
#  'axew.12.png',
#  'axew.13.png',
#  'axew.14.png',
#  'axew.15.png',
#  'axew.16.png',
#  'axew.17.png',
#  'axew.18.png',
#  'axew.19.png',
#  'axew.20.png',
#  'chikorita.0.png',
#  'chikorita.1.png',
#  'chikorita.2.png',
#  'chikorita.3.png',
#  'chikorita.4.png',
#  'chikorita.5.png',
#  'chikorita.6.png',
#  'chikorita.7.png',
#  'chikorita.8.png',
#  'chikorita.9.png',
#  'chikorita.10.png',
#  'chikorita.11.png',
#  'chikorita.12.png',
#  'chikorita.13.png',
#  'chikorita.14.png',
#  'chikorita.15.png',
#  'chikorita.16.png',
#  'chikorita.17.png',
#  'chikorita.18.png',
#  'chikorita.19.png',
#  'chikorita.20.png',
#  'charizard.0.png',
#  'charizard.1.png',
#  'charizard.2.png',
#  'charizard.3.png',
#  'charizard.4.png',
#  'charizard.5.png',
#  'charizard.6.png',
#  'charizard.7.png',
#  'charizard.8.png',
#  'charizard.9.png',
#  'charizard.10.png',
#  'charizard.11.png',
#  'charizard.12.png',
#  'charizard.13.png',
#  'charizard.14.png',
#  'charizard.15.png',
#  'charizard.16.png',
#  'charizard.17.png',
#  'charizard.18.png',
#  'charizard.19.png',
#  'charizard.20.png',
#  'chespin.0.png',
#  'chespin.1.png',
#  'chespin.2.png',
#  'chespin.3.png',
#  'chespin.4.png',
#  'chespin.5.png',
#  'chespin.6.png',
#  'chespin.7.png',
#  'chespin.8.png',
#  'chespin.9.png',
#  'chespin.10.png',
#  'chespin.11.png',
#  'chespin.12.png',
#  'chespin.13.png',
#  'chespin.14.png',
#  'chespin.15.png',
#  'chespin.16.png',
#  'chespin.17.png',
#  'chespin.18.png',
#  'chespin.19.png',
#  'chespin.20.png',
#  'bellsprout.0.png',
#  'bellsprout.1.png',
#  'bellsprout.2.png',
#  'bellsprout.3.png',
#  'bellsprout.4.png',
#  'bellsprout.5.png',
#  'bellsprout.6.png',
#  'bellsprout.7.png',
#  'bellsprout.8.png',
#  'bellsprout.9.png',
#  'bellsprout.10.png',
#  'bellsprout.11.png',
#  'bellsprout.12.png',
#  'bellsprout.13.png',
#  'bellsprout.14.png',
#  'bellsprout.15.png',
#  'bellsprout.16.png',
#  'bellsprout.17.png',
#  'bellsprout.18.png',
#  'bellsprout.19.png',
#  'bellsprout.20.png',
#  'clamperl.0.png',
#  'clamperl.1.png',
#  'clamperl.2.png',
#  'clamperl.3.png',
#  'clamperl.4.png',
#  'clamperl.5.png',
#  'clamperl.6.png',
#  'clamperl.7.png',
#  'clamperl.8.png',
#  'clamperl.9.png',
#  'clamperl.10.png',
#  'clamperl.11.png',
#  'clamperl.12.png',
#  'clamperl.13.png',
#  'clamperl.14.png',
#  'clamperl.15.png',
#  'clamperl.16.png',
#  'clamperl.17.png',
#  'clamperl.18.png',
#  'clamperl.19.png',
#  'clamperl.20.png',
#  'budew.0.png',
#  'budew.1.png',
#  'budew.2.png',
#  'budew.3.png',
#  'budew.4.png',
#  'budew.5.png',
#  'budew.6.png',
#  'budew.7.png',
#  'budew.8.png',
#  'budew.9.png',
#  'budew.10.png',
#  'budew.11.png',
#  'budew.12.png',
#  'budew.13.png',
#  'budew.14.png',
#  'budew.15.png',
#  'budew.16.png',
#  'budew.17.png',
#  'budew.18.png',
#  'budew.19.png',
#  'budew.20.png',
#  'bergmite.0.png',
#  'bergmite.1.png',
#  'bergmite.2.png',
#  'bergmite.3.png',
#  'bergmite.4.png',
#  'bergmite.5.png',
#  'bergmite.6.png',
#  'bergmite.7.png',
#  'bergmite.8.png',
#  'bergmite.9.png',
#  'bergmite.10.png',
#  'bergmite.11.png',
#  'bergmite.12.png',
#  'bergmite.13.png',
#  'bergmite.14.png',
#  'bergmite.15.png',
#  'bergmite.16.png',
#  'bergmite.17.png',
#  'bergmite.18.png',
#  'bergmite.19.png',
#  'bergmite.20.png',
#  'carvanha.0.png',
#  'carvanha.1.png',
#  'carvanha.2.png',
#  'carvanha.3.png',
#  'carvanha.4.png',
#  'carvanha.5.png',
#  'carvanha.6.png',
#  'carvanha.7.png',
#  'carvanha.8.png',
#  'carvanha.9.png',
#  'carvanha.10.png',
#  'carvanha.11.png',
#  'carvanha.12.png',
#  'carvanha.13.png',
#  'carvanha.14.png',
#  'carvanha.15.png',
#  'carvanha.16.png',
#  'carvanha.17.png',
#  'carvanha.18.png',
#  'carvanha.19.png',
#  'carvanha.20.png',
#  'blitzle.0.png',
#  'blitzle.1.png',
#  'blitzle.2.png',
#  'blitzle.3.png',
#  'blitzle.4.png',
#  'blitzle.5.png',
#  'blitzle.6.png',
#  'blitzle.7.png',
#  'blitzle.8.png',
#  'blitzle.9.png',
#  'blitzle.10.png',
#  'blitzle.11.png',
#  'blitzle.12.png',
#  'blitzle.13.png',
#  'blitzle.14.png',
#  'blitzle.15.png',
#  'blitzle.16.png',
#  'blitzle.17.png',
#  'blitzle.18.png',
#  'blitzle.19.png',
#  'blitzle.20.png',
#  'chimchar.0.png',
#  'chimchar.1.png',
#  'chimchar.2.png',
#  'chimchar.3.png',
#  'chimchar.4.png',
#  'chimchar.5.png',
#  'chimchar.6.png',
#  'chimchar.7.png',
#  'chimchar.8.png',
#  'chimchar.9.png',
#  'chimchar.10.png',
#  'chimchar.11.png',
#  'chimchar.12.png',
#  'chimchar.13.png',
#  'chimchar.14.png',
#  'chimchar.15.png',
#  'chimchar.16.png',
#  'chimchar.17.png',
#  'chimchar.18.png',
#  'chimchar.19.png',
#  'chimchar.20.png',
#  'chimecho.0.png',
#  'chimecho.1.png',
#  'chimecho.2.png',
#  'chimecho.3.png',
#  'chimecho.4.png',
#  'chimecho.5.png',
#  'chimecho.6.png',
#  'chimecho.7.png',
#  'chimecho.8.png',
#  'chimecho.9.png',
#  'chimecho.10.png',
#  'chimecho.11.png',
#  'chimecho.12.png',
#  'chimecho.13.png',
#  'chimecho.14.png',
#  'chimecho.15.png',
#  'chimecho.16.png',
#  'chimecho.17.png',
#  'chimecho.18.png',
#  'chimecho.19.png',
#  'chimecho.20.png',
#  'cacturne.0.png',
#  'cacturne.1.png',
#  'cacturne.2.png',
#  'cacturne.3.png',
#  'cacturne.4.png',
#  'cacturne.5.png',
#  'cacturne.6.png',
#  'cacturne.7.png',
#  'cacturne.8.png',
#  'cacturne.9.png',
#  'cacturne.10.png',
#  'cacturne.11.png',
#  'cacturne.12.png',
#  'cacturne.13.png',
#  'cacturne.14.png',
#  'cacturne.15.png',
#  'cacturne.16.png',
#  'cacturne.17.png',
#  'cacturne.18.png',
#  'cacturne.19.png',
#  'cacturne.20.png',
#  'binacle.0.png',
#  'binacle.1.png',
#  'binacle.2.png',
#  'binacle.3.png',
#  'binacle.4.png',
#  'binacle.5.png',
#  'binacle.6.png',
#  'binacle.7.png',
#  'binacle.8.png',
#  'binacle.9.png',
#  'binacle.10.png',
#  'binacle.11.png',
#  'binacle.12.png',
#  'binacle.13.png',
#  'binacle.14.png',
#  'binacle.15.png',
#  'binacle.16.png',
#  'binacle.17.png',
#  'binacle.18.png',
#  'binacle.19.png',
#  'binacle.20.png',
#  'camerupt.0.png',
#  'camerupt.1.png',
#  'camerupt.2.png',
#  'camerupt.3.png',
#  'camerupt.4.png',
#  'camerupt.5.png',
#  'camerupt.6.png',
#  'camerupt.7.png',
#  'camerupt.8.png',
#  'camerupt.9.png',
#  'camerupt.10.png',
#  'camerupt.11.png',
#  'camerupt.12.png',
#  'camerupt.13.png',
#  'camerupt.14.png',
#  'camerupt.15.png',
#  'camerupt.16.png',
#  'camerupt.17.png',
#  'camerupt.18.png',
#  'camerupt.19.png',
#  'camerupt.20.png',
#  'carracosta.0.png',
#  'carracosta.1.png',
#  'carracosta.2.png',
#  'carracosta.3.png',
#  'carracosta.4.png',
#  'carracosta.5.png',
#  'carracosta.6.png',
#  'carracosta.7.png',
#  'carracosta.8.png',
#  'carracosta.9.png',
#  'carracosta.10.png',
#  'carracosta.11.png',
#  'carracosta.12.png',
#  'carracosta.13.png',
#  'carracosta.14.png',
#  'carracosta.15.png',
#  'carracosta.16.png',
#  'carracosta.17.png',
#  'carracosta.18.png',
#  'carracosta.19.png',
#  'carracosta.20.png',
#  'boldore.0.png',
#  'boldore.1.png',
#  'boldore.2.png',
#  'boldore.3.png',
#  'boldore.4.png',
#  'boldore.5.png',
#  'boldore.6.png',
#  'boldore.7.png',
#  'boldore.8.png',
#  'boldore.9.png',
#  'boldore.10.png',
#  'boldore.11.png',
#  'boldore.12.png',
#  'boldore.13.png',
#  'boldore.14.png',
#  'boldore.15.png',
#  'boldore.16.png',
#  'boldore.17.png',
#  'boldore.18.png',
#  'boldore.19.png',
#  'boldore.20.png',
#  'machamp.0.png',
#  'machamp.1.png',
#  'machamp.2.png',
#  'machamp.3.png',
#  'machamp.4.png',
#  'machamp.5.png',
#  'machamp.6.png',
#  'machamp.7.png',
#  'machamp.8.png',
#  'machamp.9.png',
#  'machamp.10.png',
#  'machamp.11.png',
#  'machamp.12.png',
#  'machamp.13.png',
#  'machamp.14.png',
#  'machamp.15.png',
#  'machamp.16.png',
#  'machamp.17.png',
#  'machamp.18.png',
#  'machamp.19.png',
#  'machamp.20.png',
#  'bruxish.0.png',
#  'bruxish.1.png',
#  'bruxish.2.png',
#  'bruxish.3.png',
#  'bruxish.4.png',
#  'bruxish.5.png',
#  'bruxish.6.png',
#  'bruxish.7.png',
#  'bruxish.8.png',
#  'bruxish.9.png',
#  'bruxish.10.png',
#  'bruxish.11.png',
#  'bruxish.12.png',
#  'bruxish.13.png',
#  'bruxish.14.png',
#  'bruxish.15.png',
#  'bruxish.16.png',
#  'bruxish.17.png',
#  'bruxish.18.png',
#  'bruxish.19.png',
#  'bruxish.20.png',
#  'cinccino.0.png',
#  'cinccino.1.png',
#  'cinccino.2.png',
#  'cinccino.3.png',
#  'cinccino.4.png',
#  'cinccino.5.png',
#  'cinccino.6.png',
#  'cinccino.7.png',
#  'cinccino.8.png',
#  'cinccino.9.png',
#  'cinccino.10.png',
#  'cinccino.11.png',
#  'cinccino.12.png',
#  'cinccino.13.png',
#  'cinccino.14.png',
#  'cinccino.15.png',
#  'cinccino.16.png',
#  'cinccino.17.png',
#  'cinccino.18.png',
#  'cinccino.19.png',
#  'cinccino.20.png',
#  'marowak.0.png',
#  'marowak.1.png',
#  'marowak.2.png',
#  'marowak.3.png',
#  'marowak.4.png',
#  'marowak.5.png',
#  'marowak.6.png',
#  'marowak.7.png',
#  'marowak.8.png',
#  'marowak.9.png',
#  'marowak.10.png',
#  'marowak.11.png',
#  'marowak.12.png',
#  ...]

# %%
from keras.models import Sequential
from keras.layers import Conv2D,BatchNormalization, MaxPooling2D, Dropout, Flatten, Dense, Activation,GlobalMaxPooling2D
from keras import applications
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers
from keras.applications.mobilenet import MobileNet
from keras.models import Model

image_size = 120
input_shape = (image_size, image_size, 3)

epochs = 30
batch_size = 200

pre_trained_model = MobileNet(input_shape=input_shape, include_top=False, weights="imagenet")
    
for layer in pre_trained_model.layers:
    layer.trainable = False

# for layer in pre_trained_model.layers:
#     layer.trainable = True
    
# last_layer = pre_trained_model.get_layer('block5_pool')
last_output = pre_trained_model.output
print(last_output)
# Flatten the output layer to 1 dimension
x = GlobalMaxPooling2D()(last_output)
x=BatchNormalization()(x)
x = Dense(512, activation='relu')(x)
# Add a dropout rate of 0.5
# x = Dropout(0.5)(x)
x = Dense(256, activation='relu')(x)
x = Dense(128, activation='relu')(x)

x = Dense(640, activation='relu')(x)
x = Dense(1000, activation='relu')(x)
x = Dense(800, activation='relu')(x)

x = Dense(803, activation='softmax')(x)

model = Model(pre_trained_model.input, x)

model.compile(loss='categorical_crossentropy',
              optimizer='Adam',
              metrics=['accuracy'])

model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# KerasTensor(type_spec=TensorSpec(shape=(None, 3, 3, 1024), dtype=tf.float32, name=None), name='conv_pw_13_relu/Relu6:0', description="created by layer 'conv_pw_13_relu'")
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 120, 120, 3)]     0
#
#  conv1 (Conv2D)              (None, 60, 60, 32)        864
#
#  conv1_bn (BatchNormalizatio  (None, 60, 60, 32)       128
#  n)
#
#  conv1_relu (ReLU)           (None, 60, 60, 32)        0
#
#  conv_dw_1 (DepthwiseConv2D)  (None, 60, 60, 32)       288
#
#  conv_dw_1_bn (BatchNormaliz  (None, 60, 60, 32)       128
#  ation)
#
#  conv_dw_1_relu (ReLU)       (None, 60, 60, 32)        0
#
#  conv_pw_1 (Conv2D)          (None, 60, 60, 64)        2048
#
#  conv_pw_1_bn (BatchNormaliz  (None, 60, 60, 64)       256
#  ation)
#
#  conv_pw_1_relu (ReLU)       (None, 60, 60, 64)        0
#
#  conv_pad_2 (ZeroPadding2D)  (None, 61, 61, 64)        0
#
#  conv_dw_2 (DepthwiseConv2D)  (None, 30, 30, 64)       576
#
#  conv_dw_2_bn (BatchNormaliz  (None, 30, 30, 64)       256
#  ation)
#
#  conv_dw_2_relu (ReLU)       (None, 30, 30, 64)        0
#
#  conv_pw_2 (Conv2D)          (None, 30, 30, 128)       8192
#
#  conv_pw_2_bn (BatchNormaliz  (None, 30, 30, 128)      512
#  ation)
#
#  conv_pw_2_relu (ReLU)       (None, 30, 30, 128)       0
#
#  conv_dw_3 (DepthwiseConv2D)  (None, 30, 30, 128)      1152
#
#  conv_dw_3_bn (BatchNormaliz  (None, 30, 30, 128)      512
#  ation)
#
#  conv_dw_3_relu (ReLU)       (None, 30, 30, 128)       0
#
#  conv_pw_3 (Conv2D)          (None, 30, 30, 128)       16384
#
#  conv_pw_3_bn (BatchNormaliz  (None, 30, 30, 128)      512
#  ation)
#
#  conv_pw_3_relu (ReLU)       (None, 30, 30, 128)       0
#
#  conv_pad_4 (ZeroPadding2D)  (None, 31, 31, 128)       0
#
#  conv_dw_4 (DepthwiseConv2D)  (None, 15, 15, 128)      1152
#
#  conv_dw_4_bn (BatchNormaliz  (None, 15, 15, 128)      512
#  ation)
#
#  conv_dw_4_relu (ReLU)       (None, 15, 15, 128)       0
#
#  conv_pw_4 (Conv2D)          (None, 15, 15, 256)       32768
#
#  conv_pw_4_bn (BatchNormaliz  (None, 15, 15, 256)      1024
#  ation)
#
#  conv_pw_4_relu (ReLU)       (None, 15, 15, 256)       0
#
#  conv_dw_5 (DepthwiseConv2D)  (None, 15, 15, 256)      2304
#
#  conv_dw_5_bn (BatchNormaliz  (None, 15, 15, 256)      1024
#  ation)
#
#  conv_dw_5_relu (ReLU)       (None, 15, 15, 256)       0
#
#  conv_pw_5 (Conv2D)          (None, 15, 15, 256)       65536
#
#  conv_pw_5_bn (BatchNormaliz  (None, 15, 15, 256)      1024
#  ation)
#
#  conv_pw_5_relu (ReLU)       (None, 15, 15, 256)       0
#
#  conv_pad_6 (ZeroPadding2D)  (None, 16, 16, 256)       0
#
#  conv_dw_6 (DepthwiseConv2D)  (None, 7, 7, 256)        2304
#
#  conv_dw_6_bn (BatchNormaliz  (None, 7, 7, 256)        1024
#  ation)
#
#  conv_dw_6_relu (ReLU)       (None, 7, 7, 256)         0
#
#  conv_pw_6 (Conv2D)          (None, 7, 7, 512)         131072
#
#  conv_pw_6_bn (BatchNormaliz  (None, 7, 7, 512)        2048
#  ation)
#
#  conv_pw_6_relu (ReLU)       (None, 7, 7, 512)         0
#
#  conv_dw_7 (DepthwiseConv2D)  (None, 7, 7, 512)        4608
#
#  conv_dw_7_bn (BatchNormaliz  (None, 7, 7, 512)        2048
#  ation)
#
#  conv_dw_7_relu (ReLU)       (None, 7, 7, 512)         0
#
#  conv_pw_7 (Conv2D)          (None, 7, 7, 512)         262144
#
#  conv_pw_7_bn (BatchNormaliz  (None, 7, 7, 512)        2048
#  ation)
#
#  conv_pw_7_relu (ReLU)       (None, 7, 7, 512)         0
#
#  conv_dw_8 (DepthwiseConv2D)  (None, 7, 7, 512)        4608
#
#  conv_dw_8_bn (BatchNormaliz  (None, 7, 7, 512)        2048
#  ation)
#
#  conv_dw_8_relu (ReLU)       (None, 7, 7, 512)         0
#
#  conv_pw_8 (Conv2D)          (None, 7, 7, 512)         262144
#
#  conv_pw_8_bn (BatchNormaliz  (None, 7, 7, 512)        2048
#  ation)
#
#  conv_pw_8_relu (ReLU)       (None, 7, 7, 512)         0
#
#  conv_dw_9 (DepthwiseConv2D)  (None, 7, 7, 512)        4608
#
#  conv_dw_9_bn (BatchNormaliz  (None, 7, 7, 512)        2048
#  ation)
#
#  conv_dw_9_relu (ReLU)       (None, 7, 7, 512)         0
#
#  conv_pw_9 (Conv2D)          (None, 7, 7, 512)         262144
#
#  conv_pw_9_bn (BatchNormaliz  (None, 7, 7, 512)        2048
#  ation)
#
#  conv_pw_9_relu (ReLU)       (None, 7, 7, 512)         0
#
#  conv_dw_10 (DepthwiseConv2D  (None, 7, 7, 512)        4608
#  )
#
#  conv_dw_10_bn (BatchNormali  (None, 7, 7, 512)        2048
#  zation)
#
#  conv_dw_10_relu (ReLU)      (None, 7, 7, 512)         0
#
#  conv_pw_10 (Conv2D)         (None, 7, 7, 512)         262144
#
#  conv_pw_10_bn (BatchNormali  (None, 7, 7, 512)        2048
#  zation)
#
#  conv_pw_10_relu (ReLU)      (None, 7, 7, 512)         0
#
#  conv_dw_11 (DepthwiseConv2D  (None, 7, 7, 512)        4608
#  )
#
#  conv_dw_11_bn (BatchNormali  (None, 7, 7, 512)        2048
#  zation)
#
#  conv_dw_11_relu (ReLU)      (None, 7, 7, 512)         0
#
#  conv_pw_11 (Conv2D)         (None, 7, 7, 512)         262144
#
#  conv_pw_11_bn (BatchNormali  (None, 7, 7, 512)        2048
#  zation)
#
#  conv_pw_11_relu (ReLU)      (None, 7, 7, 512)         0
#
#  conv_pad_12 (ZeroPadding2D)  (None, 8, 8, 512)        0
#
#  conv_dw_12 (DepthwiseConv2D  (None, 3, 3, 512)        4608
#  )
#
#  conv_dw_12_bn (BatchNormali  (None, 3, 3, 512)        2048
#  zation)
#
#  conv_dw_12_relu (ReLU)      (None, 3, 3, 512)         0
#
#  conv_pw_12 (Conv2D)         (None, 3, 3, 1024)        524288
#
#  conv_pw_12_bn (BatchNormali  (None, 3, 3, 1024)       4096
#  zation)
#
#  conv_pw_12_relu (ReLU)      (None, 3, 3, 1024)        0
#
#  conv_dw_13 (DepthwiseConv2D  (None, 3, 3, 1024)       9216
#  )
#
#  conv_dw_13_bn (BatchNormali  (None, 3, 3, 1024)       4096
#  zation)
#
#  conv_dw_13_relu (ReLU)      (None, 3, 3, 1024)        0
#
#  conv_pw_13 (Conv2D)         (None, 3, 3, 1024)        1048576
#
#  conv_pw_13_bn (BatchNormali  (None, 3, 3, 1024)       4096
#  zation)
#
#  conv_pw_13_relu (ReLU)      (None, 3, 3, 1024)        0
#
#  global_max_pooling2d_1 (Glo  (None, 1024)             0
#  balMaxPooling2D)
#
#  batch_normalization_1 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dense_7 (Dense)             (None, 512)               524800
#
#  dense_8 (Dense)             (None, 256)               131328
#
#  dense_9 (Dense)             (None, 128)               32896
#
#  dense_10 (Dense)            (None, 640)               82560
#
#  dense_11 (Dense)            (None, 1000)              641000
#
#  dense_12 (Dense)            (None, 800)               800800
#
#  dense_13 (Dense)            (None, 803)               643203
#
# =================================================================
# Total params: 6,089,547
# Trainable params: 2,858,635
# Non-trainable params: 3,230,912
# _________________________________________________________________

# %%
from sklearn.model_selection import train_test_split
train_df, validate_df = train_test_split(df, test_size=0.3,shuffle=True)
# train_df=df
train_df = train_df.reset_index()
validate_df = validate_df.reset_index()

# validate_df = validate_df.sample(n=100).reset_index() # use for fast testing code purpose
# train_df = train_df.sample(n=1800).reset_index() # use for fast testing code purpose

total_train = train_df.shape[0]
total_validate = validate_df.shape[0]

# %%
df
# Out:
#                filename    category
# 0      conkeldurr.0.png  conkeldurr
# 1      conkeldurr.1.png  conkeldurr
# 2      conkeldurr.2.png  conkeldurr
# 3      conkeldurr.3.png  conkeldurr
# 4      conkeldurr.4.png  conkeldurr
# ...                 ...         ...
# 16858   larvesta.16.png    larvesta
# 16859   larvesta.17.png    larvesta
# 16860   larvesta.18.png    larvesta
# 16861   larvesta.19.png    larvesta
# 16862   larvesta.20.png    larvesta
#
# [16863 rows x 2 columns]

# %%
train_df
# Out:
#        index           filename    category
# 0      15252      umbreon.6.png     umbreon
# 1      12297      seadra.12.png      seadra
# 2       3729    granbull.12.png    granbull
# 3       1268   charmeleon.8.png  charmeleon
# 4       5934   bastiodon.12.png   bastiodon
# ...      ...                ...         ...
# 11799   4157     heatran.20.png     heatran
# 11800  16702        zubat.7.png       zubat
# 11801  10340        pichu.8.png       pichu
# 11802   2601  forretress.18.png  forretress
# 11803  10659     poliwag.12.png     poliwag
#
# [11804 rows x 3 columns]

# %%
validate_df
# Out:
#       index           filename    category
# 0     11469    reuniclus.3.png   reuniclus
# 1      8968   misdreavus.1.png  misdreavus
# 2      6695  butterfree.17.png  butterfree
# 3      6866     carbink.20.png     carbink
# 4      5727    lillipup.15.png    lillipup
# ...     ...                ...         ...
# 5054   3768       grotle.9.png      grotle
# 5055   7751    clawitzer.2.png   clawitzer
# 5056  12853     silvally.1.png    silvally
# 5057  11923   dunsparce.16.png   dunsparce
# 5058    404   aromatisse.5.png  aromatisse
#
# [5059 rows x 3 columns]

# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(
    rotation_range=15,
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    width_shift_range=0.1,
    height_shift_range=0.1
)

train_generator = train_datagen.flow_from_dataframe(
    train_df, 
    abss, 
    x_col='filename',
    y_col='category',
    class_mode='categorical',
    target_size=(image_size, image_size),
    batch_size=batch_size
)
validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df, 
    abss, 
    x_col='filename',
    y_col='category',
    class_mode='categorical',
    target_size=(image_size, image_size),
    batch_size=batch_size
)
# Out:
# Found 11804 validated image filenames belonging to 803 classes.
# Found 5059 validated image filenames belonging to 803 classes.

# %%
history = model.fit(
    train_generator,
    epochs=3,
    validation_data=validation_generator,
    validation_steps=total_validate//batch_size,
    steps_per_epoch=total_train//batch_size)
# Out:
# Epoch 1/3
# 59/59 [==============================] - 66s 1s/step - loss: 0.1055 - accuracy: 0.9687 - val_loss: 0.1408 - val_accuracy: 0.9650
# Epoch 2/3
# 59/59 [==============================] - 63s 1s/step - loss: 0.1418 - accuracy: 0.9630 - val_loss: 0.5673 - val_accuracy: 0.8768
# Epoch 3/3
# 59/59 [==============================] - 62s 1s/step - loss: 0.2417 - accuracy: 0.9342 - val_loss: 0.1784 - val_accuracy: 0.9514

# %%
# %cd imgs
# Out:
# /content/drive/MyDrive/imgs

# %%
model.save('/content/model')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 27). These functions will not be directly callable after loading.

# %%
l1=[]
for i in os.listdir():
    img=Image.open(i)
    img=np.array(img)
    l1.append(image_list)
print(len(l1))
# Out:
# 803

# %%
curr = os.getcwd()
curr
# Out:
# '/content/drive/MyDrive/imgs'

# %%
filenames1=[]
cat1=[]
for i in os.listdir(curr):
    # path = os.path.join(curr, i)
      filenames1.append(i)
      cat1.append(i.split(".")[0])

# %%
cat1
# Out:
# ['conkeldurr',
#  'azelf',
#  'azurill',
#  'bagon',
#  'azumarill',
#  'baltoy',
#  'barbaracle',
#  'frillish',
#  'abra',
#  'accelgor',
#  'absol',
#  'anorith',
#  'aegislash-blade',
#  'ampharos',
#  'amoonguss',
#  'araquanid',
#  'aerodactyl',
#  'arbok',
#  'ambipom',
#  'aromatisse',
#  'ariados',
#  'archeops',
#  'armaldo',
#  'gourgeist-average',
#  'graveler',
#  'greninja',
#  'herdier',
#  'axew',
#  'chikorita',
#  'charizard',
#  'chespin',
#  'bellsprout',
#  'clamperl',
#  'budew',
#  'bergmite',
#  'carvanha',
#  'blitzle',
#  'chimchar',
#  'chimecho',
#  'cacturne',
#  'binacle',
#  'camerupt',
#  'carracosta',
#  'boldore',
#  'machamp',
#  'bruxish',
#  'cinccino',
#  'marowak',
#  'diglett',
#  'dewpider',
#  'chingling',
#  'blaziken',
#  'cherrim',
#  'mew',
#  'chansey',
#  'cascoon',
#  'lycanroc-midday',
#  'bidoof',
#  'blissey',
#  'bibarel',
#  'charmeleon',
#  'celesteela',
#  'drilbur',
#  'charjabug',
#  'chesnaught',
#  'dewott',
#  'chatot',
#  'dragonair',
#  'bewear',
#  'chinchou',
#  'drampa',
#  'dragalge',
#  'carnivine',
#  'dodrio',
#  'ditto',
#  'drifloon',
#  'dhelmise',
#  'dragonite',
#  'dratini',
#  'ducklett',
#  'musharna',
#  'drowzee',
#  'dugtrio',
#  'drapion',
#  'druddigon',
#  'dustox',
#  'elekid',
#  'duosion',
#  'dusknoir',
#  'durant',
#  'dusclops',
#  'dwebble',
#  'duskull',
#  'eelektrik',
#  'eelektross',
#  'elgyem',
#  'escavalier',
#  'empoleon',
#  'espeon',
#  'emboar',
#  'entei',
#  'excadrill',
#  'exeggcute',
#  'exeggutor',
#  'feebas',
#  'exploud',
#  'fearow',
#  'fennekin',
#  'feraligatr',
#  'ferroseed',
#  'finneon',
#  'ferrothorn',
#  'flaaffy',
#  'flabebe',
#  'flareon',
#  'fletchinder',
#  'fletchling',
#  'floatzel',
#  'floette',
#  'florges',
#  'flygon',
#  'fomantis',
#  'foongus',
#  'forretress',
#  'fraxure',
#  'froakie',
#  'frogadier',
#  'froslass',
#  'furret',
#  'furfrou',
#  'gabite',
#  'gallade',
#  'galvantula',
#  'garbodor',
#  'garchomp',
#  'gardevoir',
#  'gastly',
#  'gastrodon',
#  'genesect',
#  'gengar',
#  'geodude',
#  'gible',
#  'gigalith',
#  'girafarig',
#  'giratina-altered',
#  'glameow',
#  'glaceon',
#  'glalie',
#  'gligar',
#  'gliscor',
#  'abomasnow',
#  'gloom',
#  'gogoat',
#  'golbat',
#  'goldeen',
#  'aggron',
#  'aipom',
#  'alomomola',
#  'altaria',
#  'alakazam',
#  'arcanine',
#  'amaura',
#  'arceus',
#  'archen',
#  'aron',
#  'articuno',
#  'audino',
#  'avalugg',
#  'aurorus',
#  'golduck',
#  'goomy',
#  'goodra',
#  'gorebyss',
#  'golisopod',
#  'golett',
#  'gothitelle',
#  'gothorita',
#  'granbull',
#  'grimer',
#  'grotle',
#  'groudon',
#  'growlithe',
#  'grubbin',
#  'grovyle',
#  'grumpig',
#  'gulpin',
#  'gumshoos',
#  'gurdurr',
#  'guzzlord',
#  'gyarados',
#  'hakamo-o',
#  'happiny',
#  'hariyama',
#  'haunter',
#  'hawlucha',
#  'heatmor',
#  'heliolisk',
#  'heatran',
#  'heracross',
#  'helioptile',
#  'hippopotas',
#  'hippowdon',
#  'hitmonchan',
#  'hitmonlee',
#  'hitmontop',
#  'honedge',
#  'hoppip',
#  'hoopa-confined',
#  'horsea',
#  'ho-oh',
#  'houndour',
#  'houndoom',
#  'huntail',
#  'hypno',
#  'hydreigon',
#  'igglybuff',
#  'illumise',
#  'incineroar',
#  'infernape',
#  'inkay',
#  'ivysaur',
#  'jellicent',
#  'jigglypuff',
#  'jirachi',
#  'jolteon',
#  'joltik',
#  'jumpluff',
#  'jynx',
#  'kabuto',
#  'kabutops',
#  'kadabra',
#  'kakuna',
#  'kangaskhan',
#  'karrablast',
#  'kartana',
#  'kecleon',
#  'keldeo-ordinary',
#  'kingdra',
#  'kingler',
#  'kirlia',
#  'klang',
#  'klefki',
#  'klink',
#  'klinklang',
#  'koffing',
#  'komala',
#  'kommo-o',
#  'krabby',
#  'kricketot',
#  'kricketune',
#  'krokorok',
#  'krookodile',
#  'kyogre',
#  'kyurem',
#  'lairon',
#  'lampent',
#  'lanturn',
#  'landorus-incarnate',
#  'lapras',
#  'larvitar',
#  'latias',
#  'latios',
#  'leafeon',
#  'leavanny',
#  'ledian',
#  'ledyba',
#  'lickilicky',
#  'lickitung',
#  'liepard',
#  'lileep',
#  'linoone',
#  'litleo',
#  'lillipup',
#  'lilligant',
#  'litten',
#  'litwick',
#  'lombre',
#  'lopunny',
#  'lotad',
#  'banette',
#  'barboach',
#  'basculin-red-striped',
#  'bastiodon',
#  'bayleef',
#  'beartic',
#  'beautifly',
#  'beedrill',
#  'beheeyem',
#  'beldum',
#  'loudred',
#  'bellossom',
#  'lucario',
#  'bisharp',
#  'blacephalon',
#  'blastoise',
#  'bonsly',
#  'ludicolo',
#  'bouffalant',
#  'bounsweet',
#  'braixen',
#  'braviary',
#  'breloom',
#  'brionne',
#  'bronzong',
#  'bronzor',
#  'lugia',
#  'lumineon',
#  'lunala',
#  'lurantis',
#  'lunatone',
#  'luvdisc',
#  'luxray',
#  'luxio',
#  'bulbasaur',
#  'buizel',
#  'buneary',
#  'bunnelby',
#  'burmy',
#  'butterfree',
#  'buzzwole',
#  'cacnea',
#  'machoke',
#  'machop',
#  'magby',
#  'magcargo',
#  'magearna',
#  'carbink',
#  'magikarp',
#  'magmar',
#  'castform',
#  'caterpie',
#  'celebi',
#  'magmortar',
#  'magnemite',
#  'makuhita',
#  'magnezone',
#  'magneton',
#  'malamar',
#  'mamoswine',
#  'manaphy',
#  'manectric',
#  'mandibuzz',
#  'mankey',
#  'mantine',
#  'mantyke',
#  'maractus',
#  'mareanie',
#  'mareep',
#  'marill',
#  'marshadow',
#  'marshtomp',
#  'masquerain',
#  'chandelure',
#  'charmander',
#  'cherubi',
#  'medicham',
#  'mawile',
#  'meditite',
#  'meganium',
#  'melmetal',
#  'meloetta-aria',
#  'meltan',
#  'meowstic-male',
#  'meowth',
#  'mesprit',
#  'metagross',
#  'metang',
#  'metapod',
#  'clauncher',
#  'clawitzer',
#  'claydol',
#  'clefable',
#  'clefairy',
#  'cleffa',
#  'cloyster',
#  'cobalion',
#  'cofagrigus',
#  'combee',
#  'comfey',
#  'combusken',
#  'corphish',
#  'corsola',
#  'cosmoem',
#  'cosmog',
#  'cottonee',
#  'crabominable',
#  'crabrawler',
#  'cradily',
#  'cranidos',
#  'crawdaunt',
#  'cresselia',
#  'croagunk',
#  'croconaw',
#  'crobat',
#  'crustle',
#  'cryogonal',
#  'cubchoo',
#  'cutiefly',
#  'cubone',
#  'cyndaquil',
#  'darkrai',
#  'darmanitan-standard',
#  'dartrix',
#  'darumaka',
#  'decidueye',
#  'dedenne',
#  'deerling',
#  'deino',
#  'delcatty',
#  'delibird',
#  'delphox',
#  'deoxys-normal',
#  'dewgong',
#  'dialga',
#  'diancie',
#  'diggersby',
#  'mienfoo',
#  'mewtwo',
#  'mienshao',
#  'mightyena',
#  'milotic',
#  'miltank',
#  'mime-jr',
#  'mimikyu',
#  'minccino',
#  'minior-meteor',
#  'minun',
#  'misdreavus',
#  'mismagius',
#  'moltres',
#  'doduo',
#  'donphan',
#  'doublade',
#  'monferno',
#  'morelull',
#  'mothim',
#  'mr-mime',
#  'mudbray',
#  'mudkip',
#  'mudsdale',
#  'muk',
#  'munchlax',
#  'munna',
#  'murkrow',
#  'drifblim',
#  'naganadel',
#  'natu',
#  'necrozma',
#  'nidoking',
#  'nidoqueen',
#  'nidoran-f',
#  'nidoran-m',
#  'nidorina',
#  'nidorino',
#  'nihilego',
#  'nincada',
#  'ninetales',
#  'ninjask',
#  'noctowl',
#  'noibat',
#  'noivern',
#  'nosepass',
#  'numel',
#  'nuzleaf',
#  'octillery',
#  'oddish',
#  'omanyte',
#  'omastar',
#  'onix',
#  'oranguru',
#  'oricorio-baile',
#  'oshawott',
#  'pachirisu',
#  'palkia',
#  'palossand',
#  'palpitoad',
#  'pancham',
#  'panpour',
#  'pangoro',
#  'pansage',
#  'pansear',
#  'paras',
#  'parasect',
#  'passimian',
#  'patrat',
#  'pawniard',
#  'pelipper',
#  'persian',
#  'phanpy',
#  'petilil',
#  'phantump',
#  'pheromosa',
#  'pichu',
#  'phione',
#  'pidgeot',
#  'pidgeotto',
#  'pidgey',
#  'pidove',
#  'pikachu',
#  'pignite',
#  'pikipek',
#  'piloswine',
#  'pineco',
#  'pinsir',
#  'piplup',
#  'plusle',
#  'politoed',
#  'poliwag',
#  'poipole',
#  'poliwhirl',
#  'poliwrath',
#  'ponyta',
#  'poochyena',
#  'popplio',
#  'porygon',
#  'porygon2',
#  'porygon-z',
#  'primarina',
#  'primeape',
#  'prinplup',
#  'probopass',
#  'psyduck',
#  'pumpkaboo-average',
#  'pupitar',
#  'purrloin',
#  'purugly',
#  'pyroar',
#  'pyukumuku',
#  'quagsire',
#  'quilava',
#  'quilladin',
#  'qwilfish',
#  'raichu',
#  'raikou',
#  'ralts',
#  'rampardos',
#  'rapidash',
#  'raticate',
#  'rattata',
#  'rayquaza',
#  'regice',
#  'regigigas',
#  'regirock',
#  'registeel',
#  'relicanth',
#  'remoraid',
#  'reuniclus',
#  'reshiram',
#  'rhyhorn',
#  'rhydon',
#  'rhyperior',
#  'ribombee',
#  'riolu',
#  'rockruff',
#  'roggenrola',
#  'roselia',
#  'roserade',
#  'rotom',
#  'rowlet',
#  'rufflet',
#  'sableye',
#  'salamence',
#  'salandit',
#  'salazzle',
#  'samurott',
#  'sandshrew',
#  'sandile',
#  'dunsparce',
#  'eevee',
#  'ekans',
#  'electabuzz',
#  'electivire',
#  'electrode',
#  'electrike',
#  'emolga',
#  'sandslash',
#  'sandygast',
#  'sawk',
#  'sawsbuck',
#  'scatterbug',
#  'scizor',
#  'sceptile',
#  'scrafty',
#  'scraggy',
#  'scyther',
#  'seadra',
#  'sealeo',
#  'seaking',
#  'seedot',
#  'seel',
#  'seismitoad',
#  'sentret',
#  'serperior',
#  'servine',
#  'seviper',
#  'sewaddle',
#  'sharpedo',
#  'shaymin-land',
#  'shedinja',
#  'shelgon',
#  'shellos',
#  'shellder',
#  'shieldon',
#  'shelmet',
#  'shiftry',
#  'shiinotic',
#  'shinx',
#  'shroomish',
#  'shuckle',
#  'shuppet',
#  'sigilyph',
#  'silcoon',
#  'silvally',
#  'simipour',
#  'simisage',
#  'simisear',
#  'skarmory',
#  'skiploom',
#  'skiddo',
#  'skorupi',
#  'skitty',
#  'skrelp',
#  'skuntank',
#  'slaking',
#  'slakoth',
#  'sliggoo',
#  'slowbro',
#  'slowking',
#  'slowpoke',
#  'slugma',
#  'slurpuff',
#  'smoochum',
#  'sneasel',
#  'smeargle',
#  'snivy',
#  'snorunt',
#  'snorlax',
#  'snover',
#  'snubbull',
#  'solgaleo',
#  'solosis',
#  'solrock',
#  'spearow',
#  'spewpa',
#  'spheal',
#  'spinarak',
#  'spiritomb',
#  'spinda',
#  'spoink',
#  'spritzee',
#  'squirtle',
#  'stakataka',
#  'stantler',
#  'staraptor',
#  'staravia',
#  'starly',
#  'starmie',
#  'staryu',
#  'steelix',
#  'steenee',
#  'stoutland',
#  'stufful',
#  'stunfisk',
#  'stunky',
#  'sudowoodo',
#  'suicune',
#  'sunflora',
#  'sunkern',
#  'surskit',
#  'swablu',
#  'swadloon',
#  'swalot',
#  'swampert',
#  'swellow',
#  'swinub',
#  'swirlix',
#  'swanna',
#  'swoobat',
#  'sylveon',
#  'taillow',
#  'talonflame',
#  'tangela',
#  'tangrowth',
#  'tapu-bulu',
#  'tapu-fini',
#  'tapu-lele',
#  'tapu-koko',
#  'tauros',
#  'tentacool',
#  'teddiursa',
#  'tentacruel',
#  'tepig',
#  'terrakion',
#  'throh',
#  'thundurus-incarnate',
#  'timburr',
#  'tirtouga',
#  'togedemaru',
#  'togekiss',
#  'togetic',
#  'torchic',
#  'torkoal',
#  'tornadus-incarnate',
#  'torracat',
#  'torterra',
#  'totodile',
#  'toucannon',
#  'toxapex',
#  'toxicroak',
#  'tranquill',
#  'trevenant',
#  'treecko',
#  'tropius',
#  'trubbish',
#  'trumbeak',
#  'tsareena',
#  'turtonator',
#  'turtwig',
#  'tympole',
#  'type-null',
#  'tynamo',
#  'typhlosion',
#  'tyranitar',
#  'tyrantrum',
#  'tyrogue',
#  'tyrunt',
#  'umbreon',
#  'unown',
#  'unfezant',
#  'ursaring',
#  'uxie',
#  'vanillish',
#  'vanillite',
#  'vanilluxe',
#  'vaporeon',
#  'venipede',
#  'venonat',
#  'venomoth',
#  'vespiquen',
#  'venusaur',
#  'vibrava',
#  'victini',
#  'victreebel',
#  'vigoroth',
#  'vikavolt',
#  'virizion',
#  'vivillon',
#  'volbeat',
#  'volcanion',
#  'voltorb',
#  'vullaby',
#  'vulpix',
#  'wailmer',
#  'wailord',
#  'wartortle',
#  'watchog',
#  'weavile',
#  'weedle',
#  'weepinbell',
#  'weezing',
#  'whirlipede',
#  'whiscash',
#  'whismur',
#  'whimsicott',
#  'wigglytuff',
#  'wimpod',
#  'wishiwashi-solo',
#  'wingull',
#  'wobbuffet',
#  'wooper',
#  'woobat',
#  'wurmple',
#  'wormadam-plant',
#  'xerneas',
#  'xurkitree',
#  'wynaut',
#  'xatu',
#  'yanmega',
#  'yungoos',
#  'zebstrika',
#  'yamask',
#  'yveltal',
#  'zangoose',
#  'zapdos',
#  'zekrom',
#  'zeraora',
#  'zigzagoon',
#  'yanma',
#  'zorua',
#  'farfetchd',
#  'golem',
#  'gothita',
#  'haxorus',
#  'hoothoot',
#  'zoroark',
#  'zubat',
#  'zweilous',
#  'zygarde-50',
#  'espurr',
#  'golurk',
#  'honchkrow',
#  'jangmo-o',
#  'larvesta']

# %%
def plot_model_history(model_history, acc='accuracy', val_acc='val_accuracy'):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    axs[0].plot(range(1,len(model_history.history[acc])+1),model_history.history[acc])
    axs[0].plot(range(1,len(model_history.history[val_acc])+1),model_history.history[val_acc])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history[acc])+1),len(model_history.history[acc])/10)
    axs[0].legend(['train', 'val'], loc='best')
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()
    
plot_model_history(history)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   from ipykernel import kernelapp as app

# %%
tdf = pd.DataFrame({
    'filename': filenames1,
    'category': cat1
})

# %%
tdf
# Out:
#            filename    category
# 0    conkeldurr.png  conkeldurr
# 1         azelf.png       azelf
# 2       azurill.png     azurill
# 3         bagon.png       bagon
# 4     azumarill.png   azumarill
# ..              ...         ...
# 798      espurr.png      espurr
# 799      golurk.png      golurk
# 800   honchkrow.png   honchkrow
# 801    jangmo-o.jpg    jangmo-o
# 802    larvesta.png    larvesta
#
# [803 rows x 2 columns]

# %%
abss=os.getcwd()
abss
# Out:
# '/content/drive/MyDrive/imgs'

# %%
test_generator = train_datagen.flow_from_dataframe(
    tdf, 
    abss, 
    x_col='filename',
    y_col='category',
    class_mode='categorical',
    target_size=(image_size, image_size),
    batch_size=batch_size
)
# Out:
# Found 803 validated image filenames belonging to 803 classes.

# %%
y=model.evaluate(test_generator)
# Out:
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# 5/5 [==============================] - 4s 709ms/step - loss: 1.4429 - accuracy: 0.8157

# %%
y
# Out:
# [1.442881464958191, 0.8156911730766296]

# %%
model.save('/content/model/model_2.h5')

# %%
# !pip install tensorflowjs
# !tensorflowjs_converter --input_format keras
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflowjs
#   Downloading tensorflowjs-4.0.0-py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 1.8 MB/s
# Requirement already satisfied: jax>=0.3.16 in /usr/local/lib/python3.7/dist-packages (from tensorflowjs) (0.3.23)
# Requirement already satisfied: six<2,>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflowjs) (1.15.0)
# Collecting packaging~=20.9
#   Downloading packaging-20.9-py2.py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 6.9 MB/s
# Collecting tensorflow<3,>=2.10.0
#   Downloading tensorflow-2.10.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (578.0 MB)
#      |████████████████████████████████| 578.0 MB 15 kB/s
# Requirement already satisfied: tensorflow-hub<0.13,>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflowjs) (0.12.0)
# Requirement already satisfied: importlib_resources>=5.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflowjs) (5.10.0)
# Collecting tensorflow-decision-forests>=1.0.1
#   Downloading tensorflow_decision_forests-1.0.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
#      |████████████████████████████████| 16.0 MB 44.8 MB/s
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflowjs) (3.19.6)
# Collecting flax>=0.5.3
#   Downloading flax-0.6.2-py3-none-any.whl (189 kB)
#      |████████████████████████████████| 189 kB 71.3 MB/s
# Collecting tensorstore
#   Downloading tensorstore-0.1.28-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#      |████████████████████████████████| 8.3 MB 50.1 MB/s
# Collecting optax
#   Downloading optax-0.1.3-py3-none-any.whl (145 kB)
#      |████████████████████████████████| 145 kB 73.1 MB/s
# Collecting rich>=11.1
#   Downloading rich-12.6.0-py3-none-any.whl (237 kB)
#      |████████████████████████████████| 237 kB 73.3 MB/s
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from flax>=0.5.3->tensorflowjs) (3.2.2)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.7/dist-packages (from flax>=0.5.3->tensorflowjs) (1.0.4)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from flax>=0.5.3->tensorflowjs) (4.1.1)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.7/dist-packages (from flax>=0.5.3->tensorflowjs) (6.0)
# Requirement already satisfied: numpy>=1.12 in /usr/local/lib/python3.7/dist-packages (from flax>=0.5.3->tensorflowjs) (1.21.6)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib_resources>=5.9.0->tensorflowjs) (3.10.0)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.7/dist-packages (from jax>=0.3.16->tensorflowjs) (1.7.3)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from jax>=0.3.16->tensorflowjs) (1.3.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.7/dist-packages (from jax>=0.3.16->tensorflowjs) (0.9.0)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.7/dist-packages (from jax>=0.3.16->tensorflowjs) (3.3.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging~=20.9->tensorflowjs) (3.0.9)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from rich>=11.1->flax>=0.5.3->tensorflowjs) (2.6.1)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 7.0 MB/s
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (1.1.2)
# Collecting tensorboard<2.11,>=2.10
#   Downloading tensorboard-2.10.1-py3-none-any.whl (5.9 MB)
#      |████████████████████████████████| 5.9 MB 55.2 MB/s
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (0.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (0.27.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (0.4.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (14.0.6)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (3.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (2.1.0)
# Collecting keras<2.11,>=2.10.0
#   Downloading keras-2.10.0-py2.py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 49.9 MB/s
# Collecting flatbuffers>=2.0
#   Downloading flatbuffers-22.10.26-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (1.14.1)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (1.6.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (1.50.0)
# Collecting tensorflow-estimator<2.11,>=2.10.0
#   Downloading tensorflow_estimator-2.10.0-py2.py3-none-any.whl (438 kB)
#      |████████████████████████████████| 438 kB 74.6 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (57.4.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow<3,>=2.10.0->tensorflowjs) (0.38.3)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow<3,>=2.10.0->tensorflowjs) (1.5.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<3,>=2.10.0->tensorflowjs) (2.14.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<3,>=2.10.0->tensorflowjs) (3.4.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<3,>=2.10.0->tensorflowjs) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<3,>=2.10.0->tensorflowjs) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<3,>=2.10.0->tensorflowjs) (2.23.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<3,>=2.10.0->tensorflowjs) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<3,>=2.10.0->tensorflowjs) (0.6.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<3,>=2.10.0->tensorflowjs) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<3,>=2.10.0->tensorflowjs) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<3,>=2.10.0->tensorflowjs) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow<3,>=2.10.0->tensorflowjs) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow<3,>=2.10.0->tensorflowjs) (4.13.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<3,>=2.10.0->tensorflowjs) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow<3,>=2.10.0->tensorflowjs) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow<3,>=2.10.0->tensorflowjs) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow<3,>=2.10.0->tensorflowjs) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow<3,>=2.10.0->tensorflowjs) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow<3,>=2.10.0->tensorflowjs) (3.2.2)
# Collecting wurlitzer
#   Downloading wurlitzer-3.0.2-py3-none-any.whl (7.3 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from tensorflow-decision-forests>=1.0.1->tensorflowjs) (1.3.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->flax>=0.5.3->tensorflowjs) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->flax>=0.5.3->tensorflowjs) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->flax>=0.5.3->tensorflowjs) (0.11.0)
# Requirement already satisfied: jaxlib>=0.1.37 in /usr/local/lib/python3.7/dist-packages (from optax->flax>=0.5.3->tensorflowjs) (0.3.22+cuda11.cudnn805)
# Collecting chex>=0.0.4
#   Downloading chex-0.1.5-py3-none-any.whl (85 kB)
#      |████████████████████████████████| 85 kB 4.4 MB/s
# Requirement already satisfied: dm-tree>=0.1.5 in /usr/local/lib/python3.7/dist-packages (from chex>=0.0.4->optax->flax>=0.5.3->tensorflowjs) (0.1.7)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from chex>=0.0.4->optax->flax>=0.5.3->tensorflowjs) (0.12.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->tensorflow-decision-forests>=1.0.1->tensorflowjs) (2022.6)
# Installing collected packages: tensorflow-estimator, tensorboard, packaging, keras, flatbuffers, commonmark, chex, wurlitzer, tensorstore, tensorflow, rich, optax, tensorflow-decision-forests, flax, tensorflowjs
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.9.0
#     Uninstalling tensorflow-estimator-2.9.0:
#       Successfully uninstalled tensorflow-estimator-2.9.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.9.1
#     Uninstalling tensorboard-2.9.1:
#       Successfully uninstalled tensorboard-2.9.1
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
#   Attempting uninstall: keras
#     Found existing installation: keras 2.9.0
#     Uninstalling keras-2.9.0:
#       Successfully uninstalled keras-2.9.0
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 1.12
#     Uninstalling flatbuffers-1.12:
#       Successfully uninstalled flatbuffers-1.12
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.9.2
#     Uninstalling tensorflow-2.9.2:
#       Successfully uninstalled tensorflow-2.9.2
# Successfully installed chex-0.1.5 commonmark-0.9.1 flatbuffers-22.10.26 flax-0.6.2 keras-2.10.0 optax-0.1.3 packaging-20.9 rich-12.6.0 tensorboard-2.10.1 tensorflow-2.10.0 tensorflow-decision-forests-1.0.1 tensorflow-estimator-2.10.0 tensorflowjs-4.0.0 tensorstore-0.1.28 wurlitzer-3.0.2
